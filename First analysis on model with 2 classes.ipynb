# %%
#seach for organic tweets and save them in one list
from collections import Counter
import csv
tweets=[]
positive_tweets = 0
negative_tweets = 0
other_tweets = 0

with open( 'D:\AllSamplesPositiveandNeutral.csv', "rb" ) as theFile:
    reader = csv.DictReader( theFile )
    for row in reader:
        if row['sent']== '1':
            positive_tweets += 1
        elif row['sent']== '-1':
            negative_tweets += 1
        else:
            other_tweets += 1
        
        tweets.append(row) 
print 'We have', len(tweets), 'sampled tweets'
print positive_tweets, 'are positive'
print negative_tweets, 'are negative'
print other_tweets, 'are nothing'
# Out:
# We have 2000 sampled tweets
# 676 are positive
# 0 are negative
# 1324 are nothing

# %%
# Create label vector (y) that show the class labels of each tweet
#print the count of each class label
from collections import Counter
import numpy as np
y = np.array([int(t['sent']) for t in tweets])#savind labels of the class in y
print 'label counts=', Counter(y)
# Out:
# label counts= Counter({0: 1324, 1: 676})

# %%
# %pylab inline
# What is the distribution of scores?
from collections import Counter
import matplotlib.pyplot as plt

counts = Counter(y).values()
vals = [1,2]

plt.bar(vals, counts)
plt.xticks(vals)
plt.xlabel('sentiment')
plt.ylabel('count')
plt.title('1:Other, 2:Positive')
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
"""Best tokenization configuration: lower=True, punct=True,url=False,mention=True
8312 unique terms in vocabulary
acc= 0.814"""

import re
def tokenize1(string, lowercase=True, keep_punctuation=True,collapse_urls=False, collapse_mentions=True):
    if not string:
        return []
    if lowercase:
        string = string.lower()
    tokens = []
    if collapse_urls:
        string = re.sub('http\S+', 'THIS_IS_A_URL', string)
    if collapse_mentions:
        string = re.sub('@\S+', 'THIS_IS_A_MENTION', string)
    if keep_punctuation:
        tokens = string.split()
    else:
        tokens = re.sub('\W+', ' ', string).split()
    return tokens

def tweet2tokens(tweet, lowercase=True,keep_punctuation=True,collapse_urls=True, collapse_mentions=True):
    #print('tweet:', tweet)
    tokens = tokenize1(tweet['text'], lowercase, keep_punctuation, collapse_urls, collapse_mentions)
    return tokens

# %%
# Let's tokenize all tweets.
tokens_list = [tweet2tokens(t, lowercase=True,keep_punctuation=False,collapse_urls=True, collapse_mentions=True) for t in tweets]

# %%
tokens_list[1]
# Out:
# ['THIS_IS_A_MENTION',
#  'anything',
#  'that',
#  'attracts',
#  'people',
#  'away',
#  'from',
#  'tobacco',
#  'cigarettes',
#  'is',
#  'a',
#  'good',
#  'thing',
#  'inc',
#  'ecig',
#  'flavours',
#  'euecigban']

# %%
for t in range(len(tokens_list)):
    print tokens_list[t]
    break
# Out:
# ['vaping', 'kush', 'gt', 'smoking', 'kush']

# %%
for t in tweets:
    print t['text']
    break
# Out:
# Vaping kush&gt;Smoking kush

# %%
#use after pre processing 
# Create feature vectors (X)
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(decode_error='ignore')# CountVectorizer(decode_error='ignore',lowercase =False)
X = vectorizer.fit_transform(t['text'] for t in tweets)
print 'default - vectorized %d tweets. found %d terms.' % (X.shape[0], X.shape[1])
# Out:
# default - vectorized 2000 tweets. found 7370 terms.

# %%
#use after pre processing 
# Create feature vectors (X)
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(decode_error='ignore', lowercase=False)
X = vectorizer.fit_transform(t['text'] for t in tweets)
print 'no lower case vectorized %d tweets. found %d terms.' % (X.shape[0], X.shape[1])
# Out:
# no lower case vectorized 2000 tweets. found 8439 terms.

# %%
#use after pre processing 
# Create feature vectors (X)
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(decode_error='ignore', lowercase=True, stop_words='english')# CountVectorizer(decode_error='ignore',lowercase =False)
X = vectorizer.fit_transform(t['text'] for t in tweets)
print 'lower case, stop words - vectorized %d tweets. found %d terms.' % (X.shape[0], X.shape[1])
# Out:
# lower case, stop words - vectorized 2000 tweets. found 7140 terms.

# %%
tweets_text=[]
for t in tweets:
    tweets_text.append(t['text'])
    
for t in tweets_text:
    print t
    break
# Out:
# Vaping kush&gt;Smoking kush

# %%
# Create feature vectors (X)
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(decode_error='ignore', ngram_range=(1, 1),max_df=1.0, min_df=2, tokenizer=tokenize1,binary=False)#lowercase, url's, mentions
X = vectorizer.fit_transform(t['text'] for t in tweets)
print 'vectorized %d tweet. found %d terms.' % (X.shape[0], X.shape[1])
# Out:
# vectorized 2000 tweet. found 2159 terms.

# %%
print vectorizer.vocabulary_.items()[:20]
# Out:
# [(u"friend's", 866), (u'straight', 1788), (u'her.', 979), (u'#suryaray', 80), (u'whose', 2087), (u'#euecigban', 44), (u'here', 980), (u'china', 499), (u'kids', 1118), (u"i'd", 1044), (u"i'm", 1046), (u'music', 1324), (u'care', 464), (u'until', 1971), (u'thuis', 1899), (u'glass', 908), (u'http://t.co/rgylakkdpq', 1028), (u'wana', 2044), (u'want', 2046), (u'absolute', 231)]

# %%
# What are the most frequent terms?
# Sum columns:
col_sums = X.sum(axis=0).tolist()[0]
# Sort sums in descending order, and return the indices
top_indices = np.argsort(col_sums)[::-1]
print 'top_indices=', top_indices
vocab = np.array(vectorizer.get_feature_names())
top_terms = vocab[top_indices]
print 'top_terms:\n', '\n'.join('%s %d' % (term, count) for term, count in zip(top_terms, top_indices)[:10])
# Out:
# top_indices= [ 226 1859 1621 ..., 1642  587  379]
# top_terms:
# THIS_IS_A_MENTION 226
# the 1859
# rt 1621
# to 1910
# i 1043
# a 227
# electronic 756
# my 1327
# in 1060
# and 292

# %%
from sklearn.cross_validation import cross_val_score
from sklearn.cross_validation import KFold
from sklearn.linear_model import LogisticRegression

def do_cv(X, y, nfolds=10):
    cv = KFold(len(y), nfolds)
    return np.mean(cross_val_score(LogisticRegression(), X, y, cv=cv))
  
print do_cv(X, y)
# Out:
# 0.796

# %%
# Fit a LogisticRegression model
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X, y)

# Compute accuracy
def accuracy(truth, predicted):
    return (1. * len([1 for tr, pr in zip(truth, predicted) if tr == pr]) / len(truth))

predicted = model.predict(X)
print 'accuracy on training data=%.3f' % accuracy(y, predicted)


# 5 Cross-validation accuracy
from sklearn.cross_validation import KFold

cv = KFold(len(y), 10)
accuracies = []
print 'Fitting in the labeled data:'
#print 'Train set:',X[train_ind].shape[0], '\f Test set:', X[test_ind].shape[0]
for train_ind, test_ind in cv:
    model.fit(X[train_ind], y[train_ind])
    
    predictions = model.predict(X[test_ind])
    accuracies.append(accuracy(y[test_ind], predictions))
    
print 'Average 5-fold cross validation accuracy=%.2f (std=%.2f)' % (np.mean(accuracies), np.std(accuracies))
# Out:
# accuracy on training data=0.868
# Fitting in the labeled data:
# Average 5-fold cross validation accuracy=0.80 (std=0.03)

# %%
p=0
n=0
o=0
for i in model.predict(X):
    if i==1:
        p+=1
    elif i==-1:
        n+=1
    else:
        o+=1

print n
print o
print p
print len(model.predict(X))
# Out:
# 0
# 1520
# 480
# 2000

# %%
from sklearn.metrics import confusion_matrix as sk_confusion_matrix
import pandas as pd


y_pred = model.predict(X)

def confusion_matrix(y_test, y_pred):
    cm = sk_confusion_matrix(y, y_pred)
    cm = pd.DataFrame(data=cm, columns=[0,1], index=[0,1])
    cm.columns.name = 'Predicted'
    cm.index.name = 'Expected'
    error_rate = (y_pred != y).mean()
    print('error rate: %.2f' % error_rate)
    return cm
    
confusion_matrix(y, y_pred)
# Out:
# error rate: 0.14
# Predicted     0    1
# Expected
# 0          1277   47
# 1           243  433

# %%
#precision, recall and F1 measures for both classes
from sklearn.metrics import precision_recall_fscore_support
y_true = y
y_pred = model.predict(X)
print '1',precision_recall_fscore_support(y_true, y_pred)
# Out:
# 1 (array([ 0.84013158,  0.90208333]), array([ 0.96450151,  0.64053254]), array([ 0.89803094,  0.74913495]), array([1324,  676], dtype=int64))

# %%
#confusion matrix again
y_pred = model.predict(X)
def create_conf_matrix(expected, predicted, n_classes):
    m = [[0] * n_classes for i in range(n_classes)]
    for pred, exp in zip(predicted, expected):#combining predicted and expected values like (1,0) and 
        m[pred][exp] += 1 #adding to those same positions a count
    return m

print create_conf_matrix(y, y_pred,2)
# Out:
# [[1277, 243], [47, 433]]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

def tokenizing(tweets, vectorizer):
    X = vectorizer.fit_transform(t['text'] for t in tweets)
    print 'X dimensions=', X.shape
    return X

# %%
# How does using ngrams help?
import matplotlib.pyplot as plt

def compare_ngrams(tweets, y):
    accuracies = []
    ngrams = [(1,1), (1,2), (2,2), (1,3), (2, 3), (3,3)]
    for ngram in ngrams:
        print ngram
        accuracies.append(do_cv(tokenizing(tweets, TfidfVectorizer(decode_error='ignore', ngram_range=ngram, tokenizer=tokenize1)), y))
    plt.figure()
    plt.plot(accuracies, 'bo-')
    plt.xticks(range(len(ngrams)), ngrams)
    plt.xlabel('ngrams')
    plt.ylabel('accuracy')
    plt.show()
        
compare_ngrams(tweets, y)
# Out:
# (1, 1)
# X dimensions= (2000, 8267)
# (1, 2)
# X dimensions= (2000, 27959)
# (2, 2)
# X dimensions= (2000, 19692)
# (1, 3)
# X dimensions= (2000, 50619)
# (2, 3)
# X dimensions= (2000, 42352)
# (3, 3)
# X dimensions= (2000, 22660)

# %%
def compare_mindDF(tweets, y):
    accuracies = []
    for freq in range(20):
        accuracies.append(do_cv(tokenizing(tweets, TfidfVectorizer(decode_error='ignore', tokenizer=tokenize1,ngram_range=(1,1),
                                                                   min_df=freq)), y))
    plt.figure()
    plt.plot(accuracies, 'bo-')
    plt.xticks(range(20))
    plt.xlabel('minDF')
    plt.ylabel('accuracy')
    plt.show()
        
compare_mindDF(tweets, y)
# Out:
# X dimensions= (2000, 8267)
# X dimensions= (2000, 8267)
# X dimensions= (2000, 2159)
# X dimensions= (2000, 1266)
# X dimensions= (2000, 884)
# X dimensions= (2000, 702)
# X dimensions= (2000, 567)
# X dimensions= (2000, 476)
# X dimensions= (2000, 419)
# X dimensions= (2000, 366)
# X dimensions= (2000, 328)
# X dimensions= (2000, 293)
# X dimensions= (2000, 265)
# X dimensions= (2000, 246)
# X dimensions= (2000, 225)
# X dimensions= (2000, 215)
# X dimensions= (2000, 204)
# X dimensions= (2000, 196)
# X dimensions= (2000, 189)
# X dimensions= (2000, 180)

# %%
# How does filtering common words affect accuracy?
import matplotlib.pyplot as plt

def compare_maxdf(tweets, y):
    accuracies = []
    maxdfs = [1., .1, .05, .04, .03, .02, .01, .005, .001]
    for freq in maxdfs:
        print freq
        accuracies.append(do_cv(tokenizing(tweets, TfidfVectorizer(decode_error='ignore',max_df=freq, tokenizer=tokenize1, 
                                                                   ngram_range=(1,1))), y))
    plt.figure()
    plt.plot(maxdfs, accuracies, 'bo-')
    plt.xlabel('maxdf (fraction)')
    plt.ylabel('accuracy')
    plt.show()
        
compare_maxdf(tweets, y)
# Out:
# 1.0
# X dimensions= (2000, 8267)
# 0.1
# X dimensions= (2000, 8251)
# 0.05
# X dimensions= (2000, 8230)
# 0.04
# X dimensions= (2000, 8221)
# 0.03
# X dimensions= (2000, 8209)
# 0.02
# X dimensions= (2000, 8182)
# 0.01
# X dimensions= (2000, 8109)
# 0.005
# X dimensions= (2000, 7974)
# 0.001
# X dimensions= (2000, 7001)

# %%
# Does binary/freq help?
def compare_binary(tweets, y):
    accuracies = []
    choices = [True, False]
    for choice in choices:
        print choice
        accuracies.append(do_cv(tokenizing(tweets, TfidfVectorizer(decode_error='ignore',binary=choice, 
                                                                   min_df=3, ngram_range=(1,1), max_df=1.0, tokenizer=tokenize1)), y))
    plt.figure()
    plt.plot(accuracies, 'bo-')
    plt.xticks([0,1], [str(c) for c in choices])
    plt.xlabel('binary')
    plt.ylabel('accuracy')
    plt.show()
        
compare_binary(tweets, y)
# Out:
# True
# X dimensions= (2000, 1266)
# False
# X dimensions= (2000, 1266)

# %%
# Does idf help?
def compare_idf(tweets, y):
    accuracies = []
    choices = [True, False]
    for choice in choices:
        print choice
        accuracies.append(do_cv(tokenizing(tweets, TfidfVectorizer(decode_error='ignore',use_idf=choice, 
                                                                   binary=False, min_df=3, ngram_range=(1,1), max_df=1.)), y))
    plt.figure()
    plt.plot(accuracies, 'bo-')
    plt.xticks([0,1], [str(c) for c in choices])
    plt.xlabel('binary')
    plt.ylabel('use idf?')
    plt.show()
        
compare_idf(tweets, y)
# Out:
# True
# X dimensions= (2000, 1285)
# False
# X dimensions= (2000, 1285)

# %%
# Do stop words help?
def compare_stopwords(tweets, y):
    accuracies = []
    choices = [None, 'english']
    for choice in choices:
        print choice
        accuracies.append(do_cv(tokenizing(tweets, TfidfVectorizer(decode_error='ignore',stop_words=choice,
                                                                 use_idf=False, binary=False, min_df=3, ngram_range=(1,1),
                                                                   tokenizer=tokenize1, max_df=1.0)), y))
    plt.figure()
    plt.plot(accuracies, 'bo-')
    plt.xticks([0,1], [str(c) for c in choices])
    plt.xlabel('binary')
    plt.ylabel('use stopwords')
    plt.show()
        
compare_stopwords(tweets, y)
# Out:
# None
# X dimensions= (2000, 1266)
# english
# X dimensions= (2000, 1095)

# %%
# Do GridSearch on all parameters.
from sklearn.grid_search import GridSearchCV
from sklearn.pipeline import Pipeline
from pprint import pprint

pipeline = Pipeline([
    ('vect', TfidfVectorizer(decode_error='ignore',tokenizer=tokenize1)),
    ('clf', LogisticRegression()),
])

parameters = {
    'vect__min_df': (1, 2, 3, 4, 5),
    'vect__ngram_range': ((1, 1), (1, 2), (1, 3)),  # unigrams or bigrams or trigrams
    'vect__use_idf': (True, False),
    'vect__max_df':(1., .1, .05, .04, .03),
    'vect__tokenizer':(None, tokenize1)
}

data = [t['text'] for t in tweets]
grid_search = GridSearchCV(pipeline, parameters, verbose=1, cv=KFold(len(y), 10))

print "Performing grid search..."
print "pipeline:", [name for name, _ in pipeline.steps]
print "parameters:"
pprint(parameters)
grid_search.fit(data, y)
print "done."

print("Best score: %0.3f" % grid_search.best_score_)
print("Best parameters set:")
best_parameters = grid_search.best_estimator_.get_params()
for param_name in sorted(parameters.keys()):
    print("\t%s: %r" % (param_name, best_parameters[param_name]))
# Out:
# [Parallel(n_jobs=1)]: Done   1 jobs       | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  50 jobs       | elapsed:    5.0s
# [Parallel(n_jobs=1)]: Done 200 jobs       | elapsed:   32.0s
# [Parallel(n_jobs=1)]: Done 450 jobs       | elapsed:  1.2min
# [Parallel(n_jobs=1)]: Done 800 jobs       | elapsed:  2.2min
# [Parallel(n_jobs=1)]: Done 1250 jobs       | elapsed:  3.4min
# [Parallel(n_jobs=1)]: Done 1800 jobs       | elapsed:  5.0min
# [Parallel(n_jobs=1)]: Done 2450 jobs       | elapsed:  6.9min
# Performing grid search...
# pipeline: ['vect', 'clf']
# parameters:
# {'vect__max_df': (1.0, 0.1, 0.05, 0.04, 0.03),
#  'vect__min_df': (1, 2, 3, 4, 5),
#  'vect__ngram_range': ((1, 1), (1, 2), (1, 3)),
#  'vect__tokenizer': (None, <function tokenize1 at 0x000000000A6C0588>),
#  'vect__use_idf': (True, False)}
# Fitting 10 folds for each of 300 candidates, totalling 3000 fits
# done.
# Best score: 0.811
# Best parameters set:
# 	vect__max_df: 1.0
# 	vect__min_df: 5
# 	vect__ngram_range: (1, 2)
# 	vect__tokenizer: <function tokenize1 at 0x000000000A6C0588>
# 	vect__use_idf: True
# [Parallel(n_jobs=1)]: Done 3000 out of 3000 | elapsed:  8.6min finished

# %%
# What are the top weighted features?

# Get the learned coefficients for the Positive class.
coef = model.coef_[0]
print coef
# Sort them in descending order.
top_coef_ind = np.argsort(coef)[::-1]
print '..',top_coef_ind
# Get the names of those features.
top_coef_terms = vocab[top_coef_ind]
print top_coef_terms
# Get the weights of those features
top_coef = coef[top_coef_ind]
# Print the top 10.
print 'top weighted terms for positive class:\n', \
    '\n'.join('%s %.2f' % (term, weight) for term, weight in zip(top_coef_terms, top_coef)[:10])
# Out:
# [ 0.29896459 -0.31448959 -0.26120278 ...,  0.29551016 -0.57675899
#   0.16124726]
# .. [1327 1043 2004 ..., 1598  708  131]
# [u'my' u'i' u'vaping' ..., u'retail' u'e-cigarettes' u'-']
# top weighted terms for positive class:
# my 5.82
# i 4.80
# vaping 2.12
# me 1.75
# green 1.58
# i'm 1.45
# got 1.42
# #vaping 1.41
# :) 1.37
# #euecigban 1.23

# %%
import numpy as np

vocabWords = []
coefValues = []
test = []

print X[1].data
print X[1].indices

for x in range(0,1999):#for each tweet in X
    for i in X[x].indices:#for each word in that tweet
        coefValues.append(model.coef_[0][i])#get the model coeficient from logistic regression for each term 
    #for each coeficient, and tfidf value for that tweet make a dot product and keeps in a vector
    test.append([(p*q,value,term) for p,q,value,term in zip(coefValues, X[x].data,X[x].indices,vocab[X[x].indices])])
    
    
for t in range(len(test)):#print final result of dot product 
    print 'tweet #', t, tweets[t]['text'], '\n', test[t], '\n'
# Out:
# [ 0.25444149  0.19751064  0.39440937  0.3675561   0.25089621  0.13920938
#   0.16232971  0.18156627  0.26997356  0.22313658  0.32610819  0.24150268
#   0.19919297  0.35797176  0.09370196]
# [  44  726 1061 1876  916  227 1080  520 1911  868  326 1464 1855  300  226]
# tweet # 0 Vaping kush&gt;Smoking kush
# [(2.1172212658564091, 2004, u'vaping')]
#
# tweet # 1 @LindaMcAvanMEP anything that attracts people away from tobacco cigarettes is a good thing, inc. ecig flavours. #EUecigBAN
# [(0.53870893833715483, 44, u'#euecigban'), (0.24335124751721976, 726, u'ecig'), (0.36359394748701601, 1061, u'inc.'), (-0.051396717107651903, 1876, u'thing,'), (-0.033470734325959234, 916, u'good'), (0.10638652524611776, 227, u'a'), (0.058755975153847111, 1080, u'is'), (-0.1282419824648689, 520, u'cigarettes'), (-0.291521293671824, 1911, u'tobacco'), (-0.095076892707958174, 868, u'from'), (-0.093994603118286432, 326, u'away'), (0.0016231341498278641, 1464, u'people'), (-0.17917244191910081, 1855, u'that'), (-0.064201372207550012, 300, u'anything'), (-0.052680790774980231, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 2 I bought a Ecig today
# [(1.24456211016128, 1913, u'today'), (0.7242581663109362, 409, u'bought'), (0.26198913473208185, 1043, u'i'), (-0.054593983085825734, 726, u'ecig'), (-0.036709811196001974, 227, u'a')]
#
# tweet # 3 Oh no I'm secondhand ecig high from a man in tennis shoes
# [(0.42498131387723809, 1060, u'in'), (0.54436000125860851, 1241, u'man'), (0.4252640876641115, 989, u'high'), (-0.041791441316554982, 1046, u"i'm"), (-0.039468324652534428, 1366, u'no'), (0.33764573839517725, 1402, u'oh'), (0.092126603395881176, 726, u'ecig'), (-0.12670800555761552, 227, u'a'), (-0.31049909134507414, 868, u'from')]
#
# tweet # 4 testing le syafiq ikmal's electric cigarette T.T rasa mcm ubat antibiotic tho.
# [(1.0404267509487231, 1885, u'tho.'), (0.60546401394569038, 1257, u'mcm'), (0.45301719493265319, 1559, u'rasa'), (-0.029092199155881335, 512, u'cigarette'), (-0.034574897855062993, 752, u'electric'), (0.31051164310710677, 1151, u'le')]
#
# tweet # 5 RT @Vapor4Life: Read this blog post for tips on troubleshooting ecigs! http://t.co/N3ezGFb08w
# [(0.92558506218179037, 737, u'ecigs!'), (0.2536017873516983, 1408, u'on'), (0.40301342517271105, 1909, u'tips'), (-0.025495461368282953, 853, u'for'), (-0.051734303342920021, 1497, u'post'), (0.31134697114135057, 391, u'blog'), (0.07795218274409256, 1882, u'this'), (-0.27390661566354457, 1565, u'read'), (-0.14579836031400642, 1621, u'rt'), (-0.044254328470078839, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 6 An electric cigarette commercial! Thinking of you @Christian_Abbey �??
# [(0.92948355241669134, 204, u'??'), (0.33673148438482725, 2141, u'you'), (0.24474455989154678, 1395, u'of'), (-0.085714971769596443, 1881, u'thinking'), (-0.037156446150705708, 288, u'an'), (0.20623510349799315, 512, u'cigarette'), (0.12168119000369311, 752, u'electric'), (-0.10696000171297018, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 7 This kid was hitting an e-cig during class. I look over and smokes coming out his nose.
# [(0.69459497940111981, 1371, u'nose.'), (0.28949361094274217, 994, u'his'), (0.18306469347082646, 1436, u'out'), (-0.041467942150415715, 560, u'coming'), (-0.035748356518844684, 1733, u'smokes'), (0.10068901832964966, 292, u'and'), (0.086720364647791523, 1440, u'over'), (-0.17417471912859042, 1205, u'look'), (-0.33434585267771877, 539, u'class.'), (-0.13546465103698047, 694, u'during'), (-0.045342668647892187, 698, u'e-cig'), (0.0020339262214677861, 997, u'hitting'), (-0.18789589036934964, 2049, u'was'), (-0.050588917431065056, 1117, u'kid'), (-0.083808313240912882, 288, u'an'), (-0.12180284169798261, 1882, u'this'), (0.012387392393631277, 1043, u'i')]
#
# tweet # 8 My new baby. Stop smoking, start vaping :) http://t.co/HjdE74lk
# [(0.72901509898490391, 195, u':)'), (0.45133226081152372, 1766, u'start'), (0.43464834537711305, 1738, u'smoking,'), (-0.046109395844251791, 1780, u'stop'), (-0.065406317306311593, 332, u'baby.'), (0.19858077475819388, 1346, u'new'), (0.072195604535866445, 1327, u'my'), (-0.18491084717561676, 2004, u'vaping')]
#
# tweet # 9 @MajorXIII ask me for anything ecig related thats what I know
# [(0.64037497980657476, 1130, u'know'), (0.33742879401525772, 2076, u'what'), (0.39172704678443643, 1858, u'thats'), (-0.059419073669623776, 1588, u'related'), (-0.031014028884117219, 1259, u'me'), (0.28349698644368054, 310, u'ask'), (0.066703584163221905, 853, u'for'), (-0.11376619740361081, 1043, u'i'), (-0.23893865951145551, 726, u'ecig'), (-0.17088338981944393, 300, u'anything'), (-0.030257758593179293, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 10 @DhesiBahaRaja wahh bestnya tgk Dr bring up psl e-cig lagi. Thanks Dr! We owe you a lot.
# [(0.96562691237108322, 1214, u'lot.'), (0.36427812612077409, 2059, u'we'), (0.34763782586015313, 1854, u'thanks'), (-0.06377564451973243, 1141, u'lagi.'), (-0.038359335639702057, 1973, u'up'), (0.29751018462346884, 419, u'bring'), (0.076123309866062541, 698, u'e-cig'), (-0.13811915434587224, 2141, u'you'), (-0.17382547488254077, 227, u'a'), (-0.046168820463553369, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 11 DALLAS E CIG Evic Venders: ... http://t.co/WZtLbSS9 RETAIL STORES
# [(0.88655334288322518, 1784, u'stores'), (0.41275881462457537, 1598, u'retail'), (0.29448688472166212, 136, u'...'), (-0.079627214489745746, 787, u'evic'), (-0.037326175444401852, 505, u'cig'), (0.21119501837206514, 697, u'e'), (0.13123766898900199, 613, u'dallas')]
#
# tweet # 12 @Kelbyjohnson14 Try the new E-cigarette. . Worth a try anyway.
# [(0.91242731517469045, 2115, u'worth'), (0.42028777193956879, 134, u'.'), (0.3664703120346734, 706, u'e-cigarette.'), (-0.020155015445341734, 1859, u'the'), (-0.087106918442155429, 1940, u'try'), (0.18151002844098901, 1346, u'new'), (0.057251555033681574, 227, u'a'), (-0.075198380586970162, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 13 In me beveiligingspakkie met Sport &amp; Bewegen tas bij me, jatok van alle markten thuis.
# [(0.77809334576834432, 1251, u'markten'), (0.49205031419855733, 270, u'alle'), (0.35662334349998026, 1991, u'van'), (-0.065424076123530142, 1260, u'me,'), (-0.036957578857537338, 110, u'&amp;'), (0.31081315048555758, 1278, u'met'), (0.08909900457596244, 1259, u'me'), (-0.13050788401033883, 1060, u'in')]
#
# tweet # 14 RT @TowerOfVape: Morning #vaping shows @TVN Live 8:30A Kisses &amp; Kerosene @Case1320 &amp; @Myzy36 11A  Out To Lunch w/Diana #vape #va ...
# [(0.60411452364329266, 86, u'#vape'), (0.16101421071509184, 1910, u'to'), (0.31770398898852875, 1192, u'live'), (-0.049307064114699761, 1698, u'shows'), (-0.035263952808317608, 97, u'#vaping'), (0.27668805788759154, 1312, u'morning'), (0.1665276731186113, 110, u'&amp;'), (-0.14803271394499301, 136, u'...'), (-0.24419385094846902, 1436, u'out'), (-0.051127384672099027, 1621, u'rt'), (-0.10641393698318549, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 15 Arr�te de vaper esp�ce de.... De mec accro � la vap' http://t.co/2LSm7w5q
# [(0.8370073673722942, 1138, u'la'), (0.54713051160002979, 1996, u'vaper'), (0.74124089734385745, 625, u'de')]
#
# tweet # 16 Merci � @dressinghomme qui parle d'AlterSmoke: nombreuses saveurs, plein de qualit�s par rapport au #tabac http://t.co/RBrnJK12 #ecig
# [(0.6311722660312884, 26, u'#ecig'), (0.52786124161444714, 321, u'au'), (0.4281626528826501, 1447, u'par'), (-0.058706535292798304, 1545, u'qui'), (-0.061959868872647761, 1274, u'merci'), (0.24966305922414139, 625, u'de'), (0.041531230782185562, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 17 my mom tries to convince my dad to switch to e-cigs like daily
# [(0.69972722832198064, 611, u'daily'), (0.26101268125271626, 1179, u'like'), (0.20144068851338337, 712, u'e-cigs'), (-0.049581215090472766, 1815, u'switch'), (-0.051278960341591441, 608, u'dad'), (0.30546832138629876, 580, u'convince'), (0.11239822356396506, 1304, u'mom'), (-0.28489814182407219, 1910, u'to'), (-0.3511844192644189, 1327, u'my')]
#
# tweet # 18 RT @jaymer: @RepJimLyons?�Stop #H3639 by @jeffrey_sanchez , Millions have quit smoking with the #Ecig. #H3639 promotes #cigarettes and #canc�??
# [(0.56292829046742854, 22, u'#cigarettes'), (0.3611837948715319, 1524, u'promotes'), (0.25576047941535462, 27, u'#ecig.'), (-0.021491628034793483, 2097, u'with'), (-0.020574757315064345, 1735, u'smoking'), (0.15652759479847839, 1548, u'quit'), (0.064867279703227518, 955, u'have'), (-0.18133440928102199, 1287, u'millions'), (-0.27434277923364681, 130, u','), (-0.08691492442929255, 439, u'by'), (-0.17753149939394264, 56, u'#h3639'), (0.00071436416724059084, 1859, u'the'), (-0.11480045545346071, 292, u'and'), (-0.018305299956730386, 1621, u'rt'), (-0.1324201630260072, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 19 RT @DrStrangeLOL: On a le droit de dire d'une musulmane voil??e qui fume la cigarette ??lectronique qu'elle est ?� voile et ?� vapeur ?
# [(0.63100816675041249, 2003, u'vapeur'), (0.29181399394844509, 776, u'et'), (0.54246745969209287, 203, u'?'), (-0.03696901330363056, 775, u'est'), (-0.038234895284543165, 223, u'??lectronique'), (0.22776493913191212, 876, u'fume'), (0.093773074770617124, 1545, u'qui'), (-0.14001794242338844, 1138, u'la'), (-0.21768806074180627, 625, u'de'), (-0.059790487581644278, 1408, u'on'), (-0.026531600290178769, 1621, u'rt'), (0.00084804859532126495, 512, u'cigarette'), (-0.22165647164308819, 1151, u'le'), (-0.018866248201859007, 227, u'a'), (-0.039808315150478883, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 20 #vapor #smoking  #vaping - Vapor Joes - Daily Vaping Deals: Boge ViVi Nova - $6.99 Free Shipping http://t.co/E41xVkHw  - #ecig #VapeDeal
# [(0.54528603504119288, 89, u'#vapedeal'), (0.29571790263239905, 1683, u'shipping'), (0.17901446458003131, 861, u'free'), (-0.03601387646391252, 1377, u'nova'), (-0.034358109488998312, 2026, u'vivi'), (0.19682319045129504, 400, u'boge'), (0.084608443165091432, 627, u'deals:'), (-0.16510290629127813, 1103, u'joes'), (-0.19401126029447816, 2010, u'vapor'), (-0.23094858019193157, 131, u'-'), (-0.058992071511740754, 78, u'#smoking'), (0.0013755769709206465, 98, u'#vapor'), (-0.19154455509810742, 611, u'daily'), (-0.02851123421233177, 26, u'#ecig'), (-0.098520303865630071, 97, u'#vaping'), (-0.099670081858354548, 2004, u'vaping')]
#
# tweet # 21 I left my e cig in my room .. greeat ..
# [(1.5599865791735206, 135, u'..'), (0.39707373043453853, 1617, u'room'), (0.33962061413038536, 1158, u'left'), (-0.026119963581043792, 505, u'cig'), (-0.024612465747762404, 697, u'e'), (0.24581280114034398, 1327, u'my'), (0.056509059699140891, 1060, u'in'), (-0.10178114954424691, 1043, u'i')]
#
# tweet # 22 @NewYorkEDM do you know if e-cigarettes are allowed in? Or do i need to sneak it
# [(0.46504350714367459, 1086, u'it'), (0.37601094119350348, 1342, u'need'), (0.25419600693660832, 1426, u'or'), (-0.055636850200727318, 271, u'allowed'), (-0.028324302903055609, 304, u'are'), (0.17658798930685324, 708, u'e-cigarettes'), (0.086689443838955535, 1052, u'if'), (-0.37129871944867188, 665, u'do'), (-0.16291749735779601, 1910, u'to'), (-0.13081924480193405, 1130, u'know'), (-0.055430700501498016, 2141, u'you'), (0.0010988792399295045, 1043, u'i'), (-0.095849986133068749, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 23 In a rather... quaint theater in Connecticut, there's a dude smoking an electric cigarette in the theater. This place is amazing.
# [(0.79052667181399949, 1476, u'place'), (0.46003762534093179, 691, u'dude'), (0.34420700453738529, 1869, u"there's"), (-0.027468846898858104, 1735, u'smoking'), (-0.018060236371167659, 1859, u'the'), (0.14055592893345245, 288, u'an'), (0.075053523627070615, 1882, u'this'), (-0.12586572751089725, 512, u'cigarette'), (-0.23971016690575631, 752, u'electric'), (-0.21248790252808158, 1060, u'in'), (-0.085641716848112726, 227, u'a'), (0.001164330137388838, 1080, u'is')]
#
# tweet # 24 Nuovo Argomento Small battery &amp; Ego ? Chi mi consiglia un buon PCC tipo emini ma pi� economico?: Con l'arrivo ... http://t.co/hRjfXKoJGO
# [(0.74673186483909559, 569, u'con'), (0.41013139093209022, 1227, u'ma'), (0.2720237654211079, 1963, u'un'), (-0.049318536334697509, 1282, u'mi'), (-0.048927105840437898, 495, u'chi'), (0.21548310390225603, 743, u'ego'), (0.10104716215278534, 352, u'battery'), (-0.24140700042534094, 1717, u'small'), (-0.26064039369108272, 203, u'?'), (-0.092531400513335721, 110, u'&amp;'), (-0.057027771308783712, 136, u'...')]
#
# tweet # 25 No cigarettes &amp; my ecig is empty..the struggle is real.
# [(1.2233540835797636, 1792, u'struggle'), (0.42153683129382769, 110, u'&amp;'), (0.21670229491624635, 1327, u'my'), (-0.047031354709428257, 1366, u'no'), (-0.038601158821188197, 726, u'ecig'), (0.36348362213281821, 1080, u'is'), (0.096278189797942851, 520, u'cigarettes')]
#
# tweet # 26 E-cigs are for pussies hahahahahaha sorry not sorry
# [(0.58949997381548025, 1372, u'not'), (1.0667671662764775, 1752, u'sorry'), (0.21732280197010134, 304, u'are'), (-0.038069980812935583, 712, u'e-cigs'), (-0.02770852169359098, 853, u'for')]
#
# tweet # 27 RT @VictorineDeliat: il me faut cette putain de cigarette electronique!!!!!!!!!!!
# [(1.0893980683974807, 479, u'cette'), (0.60965405629483049, 822, u'faut'), (0.42077231924159503, 1055, u'il'), (-0.048668608224938618, 625, u'de'), (-0.036114736220850666, 1259, u'me'), (0.12144845550413486, 1621, u'rt'), (0.078848590452638118, 512, u'cigarette'), (-0.086340955771058034, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 28 RT @VapeBans: @SimonCowell Just 1 #RT for your fellow #Vapers is all it takes. Show your 6.6mil followers that u care about the #EUEcigBan!
# [(0.40864500176318919, 230, u'about'), (0.36062007433908927, 464, u'care'), (0.21489159371515301, 1958, u'u'), (-0.045093819879508189, 851, u'followers'), (-0.039046126484804489, 1696, u'show'), (0.14750205917694179, 268, u'all'), (0.10594021724363258, 94, u'#vapers'), (-0.2067292235353379, 829, u'fellow'), (-0.38281336234818075, 2150, u'your'), (-0.12188966475483334, 72, u'#rt'), (-0.069446638987230011, 142, u'1'), (0.0011165736041121083, 1108, u'just'), (-0.14204842035788903, 1086, u'it'), (-0.018602025420619131, 1859, u'the'), (-0.075615345409923998, 853, u'for'), (-0.072184956447150547, 1621, u'rt'), (0.013221067105067756, 1080, u'is'), (0.089875133751315103, 1855, u'that'), (0.7353501016673627, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 29 E-Cigs in Hotels http://t.co/TfsRuQeNC5
# [(1.7553409375101539, 1007, u'hotels'), (0.5584290997104655, 712, u'e-cigs'), (0.30184257857291741, 1060, u'in')]
#
# tweet # 30 @anne_DK87 what is an electronic cigarette?
# [(1.3961070874918373, 519, u'cigarette?'), (0.36384848620434712, 756, u'electronic'), (0.44139386990620122, 2076, u'what'), (-0.047202149648097637, 288, u'an'), (-0.042416400885658019, 1080, u'is'), (0.14025924274534149, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 31 @AnisFairy1 aku sihat semenjak isap rokok electric cigarette..haha
# [(1.0799875201975562, 1614, u'rokok'), (0.68616947582720267, 1083, u'isap'), (0.51340222379513867, 266, u'aku'), (-0.044072548014834081, 752, u'electric'), (-0.018940196788317695, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 32 I like when Micah walks all over the house while tweeting and looking for his ecig charger..????
# [(0.72797521449588787, 1207, u'looking'), (0.39390874191929809, 2082, u'while'), (0.32722454053832961, 1009, u'house'), (-0.055920061694280966, 2043, u'walks'), (-0.036702858206941628, 2079, u'when'), (0.19020794708173563, 268, u'all'), (0.079773819795498496, 1179, u'like'), (-0.094469215607250703, 1859, u'the'), (-0.30926834058867131, 994, u'his'), (-0.06843191434143317, 292, u'and'), (-0.084178033987461556, 1440, u'over'), (0.0011656532025267267, 853, u'for'), (-0.1363506318594763, 1043, u'i'), (-0.037348631043892737, 726, u'ecig')]
#
# tweet # 33 spent two hours today talking to a guy smoking an e-cig, so ya that was weird
# [(0.70840623174323658, 2069, u'weird'), (0.37264435584688704, 2127, u'ya'), (0.17303434061177206, 1741, u'so'), (-0.043158387620731563, 700, u'e-cig,'), (-0.03467943031687104, 931, u'guy'), (0.23586940313848179, 1826, u'talking'), (0.1143014290958238, 1008, u'hours'), (-0.20034154218531142, 1954, u'two'), (-0.3409939498822992, 1758, u'spent'), (-0.069188846483652436, 1735, u'smoking'), (-0.033733590547127663, 1910, u'to'), (0.0014318689726147591, 2049, u'was'), (-0.13675128470589645, 288, u'an'), (-0.047049195690497668, 1913, u'today'), (-0.069043207997213543, 227, u'a'), (-0.12735347284687046, 1855, u'that')]
#
# tweet # 34 The electronic cigarette free startrer package trial get began while using the electronic cigarette http://t.co/G2lcktEvho
# [(0.63275252813095306, 1985, u'using'), (0.31496285310763017, 894, u'get'), (0.37725534048369413, 1936, u'trial'), (-0.055454154756345478, 1445, u'package'), (-0.043644924886612022, 2082, u'while'), (0.2486335125676378, 756, u'electronic'), (0.11613430813520224, 861, u'free'), (-0.19334385702451526, 1859, u'the'), (-0.38908502913148535, 512, u'cigarette')]
#
# tweet # 35 Ouh hell yes! #ejuice #watermelon #irishcream #earlgrey #vape #vapejuice #vapejuice #vapeon #livehealthy http://t.co/u5M7l2P24R
# [(0.99335333951376237, 92, u'#vapeon'), (0.60111911835680065, 103, u'#watermelon'), (0.41914405229089696, 37, u'#ejuice'), (-0.063577819110771039, 970, u'hell'), (-0.047801967132143817, 86, u'#vape')]
#
# tweet # 36 @officialKeef @jimmyfallon Electric cigarette so he doesn,t smoke
# [(0.77397457695745797, 1721, u'smoke'), (0.65089116215341547, 958, u'he'), (0.38613353288798835, 1741, u'so'), (-0.045965563654466537, 512, u'cigarette'), (-0.054628206677950292, 752, u'electric'), (0.2819362286818235, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 37 RT @RedNick_Gjerde: If you have an e cig and you haven't tried Texas Watermelon, you're missing the fuck out!
# [(0.69146189516455547, 1437, u'out!'), (0.33427516172656035, 871, u'fuck'), (0.31899944512851347, 1294, u'missing'), (-0.036954673964424423, 2143, u"you're"), (-0.048003355242294078, 1850, u'texas'), (0.22124712208663716, 1939, u'tried'), (0.12137546660655769, 956, u"haven't"), (-0.13571076083606576, 1052, u'if'), (-0.21071398573692932, 955, u'have'), (-0.049313301655383106, 1859, u'the'), (-0.049006568551320254, 505, u'cig'), (0.0011286744991333944, 697, u'e'), (-0.12500180216073545, 292, u'and'), (-0.055340331235188757, 2141, u'you'), (-0.088397953577776481, 288, u'an'), (-0.08054561058275847, 1621, u'rt'), (0.0085155431834011419, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 38 I'm gonna blow ecig vapour in the face of the law! #EUecigBan
# [(0.87471822230916441, 807, u'face'), (0.49750888560381834, 2015, u'vapour'), (0.39106254700862653, 394, u'blow'), (-0.048936039109077789, 915, u'gonna'), (-0.039062579127532596, 1859, u'the'), (0.14488961021227589, 1395, u'of'), (0.065068420159338752, 1060, u'in'), (-0.18905287931037879, 1046, u"i'm"), (-0.31709554763214687, 44, u'#euecigban'), (-0.097128768418398029, 726, u'ecig')]
#
# tweet # 39 @MikeeeDeeeLeon Nice I tried to smoke electronic cigarette last Saturday, it was my first time.
# [(0.85456172408394382, 1905, u'time.'), (0.43542466782306277, 840, u'first'), (0.309104724538177, 1144, u'last'), (-0.054055859842256318, 1356, u'nice'), (-0.047731579600972122, 1939, u'tried'), (0.16001214014787246, 1721, u'smoke'), (0.061531185149158493, 756, u'electronic'), (-0.1538171019995942, 1086, u'it'), (-0.16152880087102159, 1910, u'to'), (-0.077088220444929412, 1327, u'my'), (-0.07848589072347055, 2049, u'was'), (0.0012653994858821415, 512, u'cigarette'), (-0.14581323449614036, 1043, u'i'), (-0.018948404392342875, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 40 RT @ECigologist: https://t.co/SQbevRe6VU @Hifistud @smoke2vape @eCigsForYou @SWOFcampaign ... This is brilliant.
# [(0.76838842635023741, 136, u'...'), (0.4083334929020262, 1882, u'this'), (0.19154494749005779, 1621, u'rt'), (-0.038717766790027641, 1080, u'is'), (-0.10660813835825818, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 41 Kit 36E-cigarette electronique rechargeable  2 chargeurs USB   prise murale et allume-cigare    un cable USB  1 boi http://t.co/YiF2a9zf
# [(0.55352430221933735, 401, u'boi'), (0.3221169059067423, 442, u'cable'), (0.24101266762874382, 273, u'allume-cigare'), (-0.036557979773669917, 1322, u'murale'), (-0.03487719721088528, 1511, u'prise'), (0.3488468081454717, 1978, u'usb'), (0.091702432208761328, 487, u'chargeurs'), (-0.13308929350209206, 158, u'2'), (-0.25518482318126323, 1572, u'rechargeable'), (-0.090990115738025609, 758, u'electronique'), (-0.075354927368488422, 174, u'36e-cigarette'), (0.0014195158261808552, 1125, u'kit'), (-0.18270580208861131, 142, u'1'), (-0.039228796093733344, 1963, u'un'), (-0.12146420927418593, 776, u'et')]
#
# tweet # 42 E-cigarette explodes, burns child: A mother's e-cigarette exploded in a car charger, burning her young boy. KS... http://t.co/MfOdepePa1
# [(0.68257790640808358, 2149, u'young'), (0.32622046452742232, 978, u'her'), (0.33504104861546491, 486, u'charger,'), (-0.042019881679969215, 461, u'car'), (-0.048484143349275775, 1314, u"mother's"), (0.25208573862382322, 432, u'burns'), (0.13154750910548405, 800, u'explodes,'), (-0.26818602994853352, 703, u'e-cigarette'), (-0.15498636281902933, 1060, u'in'), (-0.10931608502869035, 227, u'a')]
#
# tweet # 43 @iNURSELISA  Less than one.  Mostly smoked when fishing or golfing.  E cig did the trick cause I can still smoke something
# [(0.63548158537898347, 1749, u'something'), (0.31508855072976077, 1778, u'still'), (0.19568459989891573, 451, u'can'), (-0.040534917117528997, 472, u'cause'), (-0.046063025958986419, 1937, u'trick'), (0.19895737579515607, 651, u'did'), (0.094231463993403264, 1727, u'smoked'), (-0.23452892984461121, 1414, u'one.'), (-0.25368476152702379, 1852, u'than'), (-0.12351558562455643, 1162, u'less'), (-0.046857777949770585, 1721, u'smoke'), (0.0015353475091904375, 2079, u'when'), (-0.19093450533341122, 1426, u'or'), (-0.01991756683022711, 1859, u'the'), (-0.091727079953370566, 505, u'cig'), (-0.11678983252061269, 697, u'e'), (0.012537642332010801, 1043, u'i'), (0.045267890207644136, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 44 always roll with 18 mg in my ecig
# [(1.0232640958128316, 1280, u'mg'), (0.55493354461195687, 155, u'18'), (0.41520954501631685, 1615, u'roll'), (-0.058747396006644283, 279, u'always'), (-0.029986266294272118, 2097, u'with'), (0.15026152282011479, 1327, u'my'), (0.069086209702136483, 1060, u'in'), (-0.17094634481814233, 726, u'ecig')]
#
# tweet # 45 Nur noch Heute, 30 % auf alle Easy e-Liquids und 20 % auf alles f?�r Stammkunden.... http://t.co/hR6k2zAYRb
# [(0.72586291196116515, 160, u'20'), (0.43924961675729129, 720, u'e-liquids'), (0.29153797066002562, 724, u'easy'), (-0.095880457452501663, 109, u'%'), (-0.040595699940427062, 171, u'30'), (0.2325557284645364, 270, u'alle')]
#
# tweet # 46 RT @Johnedwarddiver: Smoked for 34 years. Voted #labour for 32. Quit the former with #ecigs. Now quitting the latter thanks to @LindaMcAvan?
# [(0.69969905536907118, 1552, u'quitting'), (0.2828416765225209, 1378, u'now'), (0.32279958155403532, 33, u'#ecigs.'), (-0.050916112863856347, 2033, u'voted'), (-0.048575203568644663, 2132, u'years.'), (0.20980807989770414, 1727, u'smoked'), (0.061295318396796014, 2097, u'with'), (-0.1593982390649365, 1548, u'quit'), (-0.13225674190534009, 1910, u'to'), (-0.099801509892863072, 1859, u'the'), (-0.086775913700392018, 1854, u'thanks'), (0.0020413007568522265, 853, u'for'), (-0.1011565937781681, 1621, u'rt'), (-0.031029193750248318, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 47 Ecig rollercoaster
# [(2.1172212658564091, 726, u'ecig')]
#
# tweet # 48 I love my #greensmoke e-cigarette so awesomeeee :) http://t.co/Gz6YXyg4SW
# [(1.1047946334516354, 1216, u'love'), (0.47157813234816159, 703, u'e-cigarette'), (0.36438818803939904, 1741, u'so'), (-0.071955090778326819, 195, u':)'), (-0.039765583732284095, 1327, u'my'), (0.20411283405070266, 1043, u'i')]
#
# tweet # 49 RT @mrpennybags: @WarmCigarette I am using this e-cig to cut my nicotine content slowly http://t.co/8AhgvUwk I should be completely off  ...
# [(0.54199252858354874, 1398, u'off'), (0.44910554291352872, 568, u'completely'), (0.18271366126176852, 356, u'be'), (-0.03447735300539128, 1693, u'should'), (-0.046762370071562427, 577, u'content'), (0.19067664238911308, 1358, u'nicotine'), (0.12295205504845143, 601, u'cut'), (-0.20713782819914209, 280, u'am'), (-0.27642422413331919, 1985, u'using'), (-0.052243808878881998, 1910, u'to'), (-0.056677847173737833, 136, u'...'), (0.00099665754713688785, 1327, u'my'), (-0.15118999532615704, 698, u'e-cig'), (-0.032205129240392337, 1882, u'this'), (-0.063293987828919512, 1621, u'rt'), (-0.19259603890773783, 1043, u'i'), (0.017252309111970652, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 50 almost 12 hours without a real cig feeling better thank i was with the cigs.... This e-cig is really helping...... http://t.co/3Q1PZY2aSv
# [(0.51348177441064902, 1568, u'really'), (0.3595988640068849, 1853, u'thank'), (0.25785020218462684, 376, u'better'), (-0.04861281457061558, 828, u'feeling'), (-0.03378700442537276, 1567, u'real'), (0.21967045555261766, 2098, u'without'), (0.11726528782940455, 150, u'12'), (-0.20959197799258805, 274, u'almost'), (-0.34071371276755691, 1008, u'hours'), (-0.06889266936468609, 2097, u'with'), (-0.032228466171711212, 1859, u'the'), (0.0011040382127833067, 505, u'cig'), (-0.14419716947278005, 698, u'e-cig'), (-0.038177659953722382, 2049, u'was'), (-0.096286809143096744, 1882, u'this'), (-0.091844052254430097, 1043, u'i'), (0.012222800702324116, 227, u'a'), (0.078958207092694535, 1080, u'is')]
#
# tweet # 51 RT @msparker32: Hey @evercig  . Are you showing your support in the vaper's fight against the #EUecigBAN ?#ecigs #PV #vapebash#vapecommunity
# [(0.80558845343239771, 68, u'#pv'), (0.43688433688918926, 256, u'against'), (0.32688336919938843, 832, u'fight'), (-0.047197186695007227, 1807, u'support'), (-0.045027258025518935, 983, u'hey'), (0.15983352868702499, 2150, u'your'), (0.065192210884990054, 304, u'are'), (-0.20456612810899696, 134, u'.'), (-0.26429286028293464, 1859, u'the'), (-0.069513146830251366, 2141, u'you'), (-0.033872066909881544, 1621, u'rt'), (0.0010099393395505345, 1060, u'in'), (-0.22079279336353333, 44, u'#euecigban'), (-0.032424551576736668, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 52 If e-cigarettes &amp; spray tanning are the escape hatches for cigarettes &amp; tanning beds, then @v2cigs and @LiveSunless are the brands to watch.
# [(0.81468134284966243, 415, u'brands'), (0.37239530256646985, 1866, u'then'), (0.35472430554595608, 773, u'escape'), (-0.050939884027234497, 304, u'are'), (-0.026444920664311325, 708, u'e-cigarettes'), (0.15702125250116908, 1052, u'if'), (0.046849054646048764, 1910, u'to'), (-0.3218496874496547, 110, u'&amp;'), (-0.26727600352696446, 1859, u'the'), (-0.063320502720180083, 292, u'and'), (-0.046255542228295414, 853, u'for'), (0.0011905343671001838, 520, u'cigarettes'), (-0.16445616740486765, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 53 http://t.co/OstcS9tGUc how d'ya like them apples #eu_ecig_ban
# [(1.4547187740609446, 1862, u'them'), (0.68400309618139477, 1011, u'how'), (0.43211101939528257, 1179, u'like')]
#
# tweet # 54 RT @Johnedwarddiver: .@UKLabour Ed's evidence-based approach on Syria is commendable. How about doing the same with policy on ecigs? No nee�??
# [(0.80278284891421636, 740, u'ecigs?'), (0.46716996231319818, 1487, u'policy'), (0.30515285315433166, 1636, u'same'), (-0.047061322104596688, 670, u'doing'), (-0.038319731875707627, 137, u'.THIS_IS_A_MENTION'), (0.18914266720914413, 1011, u'how'), (0.085416248119336055, 230, u'about'), (-0.12951993521169766, 2097, u'with'), (-0.13693682271829488, 1859, u'the'), (-0.15819951762149986, 1408, u'on'), (-0.03509995099054266, 1621, u'rt'), (0.0015425316152595998, 1366, u'no'), (-0.14596871210292867, 1080, u'is'), (-0.016799981150571002, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 55 The Ambiguous Allure of the E-Cig http://t.co/rcALaukfll via @roomfordebate
# [(1.2745145775672422, 2020, u'via'), (0.68389789925905609, 1859, u'the'), (0.3668163943236562, 698, u'e-cig'), (-0.050256155259085777, 1395, u'of'), (-0.027348365758747419, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 56 @v2cigs Perhaps you should reword that to include the fact that it's the last sale of the YEAR, not ever.
# [(0.65374113671542222, 781, u'ever.'), (0.39560575286162092, 2130, u'year,'), (0.26865225575978707, 1633, u'sale'), (-0.028306625525811216, 1089, u"it's"), (-0.03991784365763177, 810, u'fact'), (0.22867257429128524, 1062, u'include'), (0.11621804326284579, 1466, u'perhaps'), (-0.15340213507508565, 1693, u'should'), (-0.26141418160429036, 1144, u'last'), (-0.07648919702689784, 1372, u'not'), (-0.031130493834736667, 1910, u'to'), (0.0020822489070672998, 1859, u'the'), (-0.12383188101376261, 2141, u'you'), (-0.023984672508169921, 1395, u'of'), (-0.18233915192471087, 1855, u'that'), (-0.055285200368504345, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 57 Electric cigarettes are better than regular cigarettes!!
# [(1.11897900976544, 522, u'cigarettes!!'), (0.56604916721224496, 1581, u'regular'), (0.39199826504367757, 376, u'better'), (-0.050284187361117907, 1852, u'than'), (-0.033375018446286889, 304, u'are'), (0.21301900101148105, 752, u'electric'), (0.088063852426816108, 520, u'cigarettes')]
#
# tweet # 58 Kristen Stewart starred with Blu Cigarette swindler Stephen Dorff in Cold Creek Manor in '03 b4 she was the most recognized YA on the planet
# [(0.73460030426341716, 1574, u'recognized'), (0.3439433824515355, 1313, u'most'), (0.23897860371859461, 1680, u'she'), (-0.046656981678046792, 555, u'cold'), (-0.046286675364109187, 1775, u'stephen'), (0.19166716332693878, 397, u'blu'), (0.1170348779085994, 1136, u'kristen'), (-0.21302731552058898, 2127, u'ya'), (-0.17424634496752991, 2097, u'with'), (-0.095099551826495335, 1859, u'the'), (-0.061235152061910367, 2049, u'was'), (0.0010979345796570635, 1408, u'on'), (-0.13213004990478033, 512, u'cigarette'), (-0.049150307989372616, 1060, u'in')]
#
# tweet # 59 A homeless guy just asked me if he could bum an e-cigarette
# [(0.94599968591734085, 430, u'bum'), (0.4429215859075214, 588, u'could'), (0.39610854374218496, 311, u'asked'), (-0.032637658933927685, 703, u'e-cigarette'), (-0.040556444753305158, 958, u'he'), (0.25512183091574081, 931, u'guy'), (0.083315996389226696, 1108, u'just'), (-0.168515001094317, 1052, u'if'), (-0.25384391315683913, 1259, u'me'), (-0.083189228110829266, 288, u'an'), (-0.045455581557734867, 227, u'a')]
#
# tweet # 60 I've got my green smoke right here! #bowlsforgoals #rctid
# [(1.1379012863487012, 981, u'here!'), (0.51447717498841838, 1604, u'right'), (0.34269489467731462, 924, u'green'), (-0.046774020647231164, 919, u'got'), (-0.054316148199828405, 1047, u"i've"), (0.201092367208934, 1721, u'smoke'), (0.082296334415377662, 1327, u'my')]
#
# tweet # 61 20% OFF WHOLE STORE &amp; LA idols #BOGO 50% off. Excludes E-cigs #ComeShop
# [(1.1048930843945524, 1399, u'off.'), (0.38483249961069876, 1783, u'store'), (0.41064261436797383, 2086, u'whole'), (-0.05124924369087349, 1398, u'off'), (-0.038058780945345289, 712, u'e-cigs'), (0.26527239470131198, 1138, u'la'), (0.11184448304494776, 110, u'&amp;')]
#
# tweet # 62 RT @Richo_I: http://t.co/aW3So8TTqf will make easy to do and could help prevent thousands of premature deaths (2/2) #vaping #ecigs #MEP #EU
# [(0.69886765534812267, 43, u'#eu'), (0.26495071125317143, 32, u'#ecigs'), (0.29262953608702214, 630, u'deaths'), (-0.044387478744174945, 1503, u'premature'), (-0.041037060190667232, 1893, u'thousands'), (0.24258663716114803, 1507, u'prevent'), (0.079045222045733984, 972, u'help'), (-0.15592706822497152, 1237, u'make'), (-0.22471629837381948, 2091, u'will'), (-0.11315973899533399, 588, u'could'), (-0.08439705412843905, 724, u'easy'), (0.0013000682521224736, 665, u'do'), (-0.099873705746051644, 1910, u'to'), (-0.040279886835626479, 97, u'#vaping'), (-0.071672231037275824, 292, u'and'), (-0.099640368802759852, 1395, u'of'), (0.010155297245625604, 1621, u'rt'), (0.043275053635916813, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 63 E cig... for vaped weed, not nicotine. Blessed. &gt;&gt;&gt;
# [(0.86836208013334737, 111, u'&gt;&gt;&gt;'), (0.48970445068268731, 1360, u'nicotine.'), (0.39317327113521761, 2066, u'weed,'), (-0.059638444049961999, 1995, u'vaped'), (-0.056896518553767629, 508, u'cig...'), (0.18222546309148441, 1372, u'not'), (0.072045089659351483, 697, u'e'), (-0.12563500259870311, 853, u'for')]
#
# tweet # 64 Electronic cigarettes-stylish chosen in favor of being smokers http://t.co/JV9p6mxgsM
# [(0.93841083659372149, 1731, u'smokers'), (0.63906152307915542, 367, u'being'), (0.54771274650737489, 823, u'favor'), (-0.033024840185638067, 756, u'electronic'), (-0.03432837412746078, 1395, u'of'), (0.1864650176377636, 1060, u'in')]
#
# tweet # 65 I love getting new juice in the mail. Vaping "cupcake city" &amp; "Crunk berry" from Alice in Vapeland. Luvin it!! #vapecommunity #ejuice
# [(0.76015893451892735, 88, u'#vapecommunity'), (0.4873934492978243, 1234, u'mail.'), (0.27758610978817277, 1106, u'juice'), (-0.039683661929276817, 897, u'getting'), (-0.037583306175868574, 1216, u'love'), (0.28172875125662761, 37, u'#ejuice'), (0.084780734223878898, 110, u'&amp;'), (-0.089865100809823836, 1859, u'the'), (-0.22638943596858241, 1346, u'new'), (-0.13313329160544077, 1060, u'in'), (-0.041562525150146516, 1043, u'i'), (0.001504155090782267, 868, u'from'), (-0.18999955562433637, 2004, u'vaping')]
#
# tweet # 66 RT @Queen_UK: Right. Sorry about this. Apparently Camilla unplugged Facebook to plug in an electric heater/cigarette lighter. Awkward.
# [(0.60770454627681048, 330, u'awkward.'), (0.35364645665472333, 1177, u'lighter.'), (0.26460354719936402, 969, u'heater/cigarette'), (-0.039227788269680409, 1482, u'plug'), (-0.037424259111108749, 809, u'facebook'), (0.21935340346818658, 1970, u'unplugged'), (0.10389156098452182, 450, u'camilla'), (-0.19814226720890432, 301, u'apparently'), (-0.29148373577363729, 1883, u'this.'), (-0.11953258043767888, 1605, u'right.'), (-0.054555754481801888, 230, u'about'), (0.0018476195354571779, 1752, u'sorry'), (-0.09568572821100392, 1910, u'to'), (-0.024783256840978291, 288, u'an'), (-0.054913839853861578, 1621, u'rt'), (-0.1208807427165733, 752, u'electric'), (0.012440876610030479, 1060, u'in'), (0.04146041232365761, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 67 E Cig Lewisville TX Soothing a sore throat with vaping: Wishing everyone a happy and successful 201... http://t.co/UUmTlYia Retail Store
# [(0.7818683937105203, 947, u'happy'), (0.38881020310908482, 784, u'everyone'), (0.37790012562249259, 1896, u'throat'), (-0.045556584389400627, 1956, u'tx'), (-0.043462083732204032, 1168, u'lewisville'), (0.2011981560083354, 1783, u'store'), (0.074048284820322177, 2097, u'with'), (-0.17577203774825348, 1598, u'retail'), (-0.22443617822406542, 505, u'cig'), (-0.087472432069411687, 697, u'e'), (-0.048965593400930811, 292, u'and'), (0.0020869637964968058, 227, u'a')]
#
# tweet # 68 @fullbright I don't smoke but I bought an e-cig that lit up blue just so I could be Mr.Sci-fi. Filled it with banana and apple flavor.
# [(0.62691951509020705, 843, u'flavor.'), (0.35354523623643519, 302, u'apple'), (0.27297002880378823, 833, u'filled'), (-0.043056353196347742, 398, u'blue'), (-0.039501780636344137, 1189, u'lit'), (0.13836667462659627, 435, u'but'), (0.066462814698630912, 671, u"don't"), (-0.1749764402122799, 588, u'could'), (-0.18078850003084337, 356, u'be'), (-0.06177160175314942, 1721, u'smoke'), (-0.047877724815294502, 1741, u'so'), (0.0010661236417058712, 1108, u'just'), (-0.13563026982976556, 1086, u'it'), (-0.025683299797605894, 2097, u'with'), (-0.1091405017466488, 1973, u'up'), (-0.086185068020253983, 292, u'and'), (0.014143485806748513, 698, u'e-cig'), (0.074245665775655501, 288, u'an'), (1.1141495774279548, 409, u'bought'), (0.31041327085849557, 1043, u'i'), (0.056286770315356442, 1855, u'that'), (-0.026368891094969076, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 69 DALLAS E CIG : mattie1224's blog: Transformations: I sit here today 116 days free from smoke, 30... http://t.co/7ACM9botVM RETAIL STORES
# [(0.6835792079111902, 1723, u'smoke,'), (0.39780081653448657, 623, u'days'), (0.23890762575343585, 980, u'here'), (-0.046356347911931793, 1713, u'sit'), (-0.045636489247788507, 392, u'blog:'), (0.22823140736904501, 192, u':'), (0.097081317280575785, 861, u'free'), (-0.17767445308855712, 1784, u'stores'), (-0.21731697210758408, 1598, u'retail'), (-0.07162058956611031, 505, u'cig'), (-0.047851775378712033, 697, u'e'), (0.0014639567581633736, 613, u'dallas'), (-0.24125638863516544, 1913, u'today'), (-0.023256304382829624, 1043, u'i'), (-0.11314834662631673, 868, u'from')]
#
# tweet # 70 #Cigarette http://t.co/CHv23nMUrV
# [(2.1172212658564091, 20, u'#cigarette')]
#
# tweet # 71 @kaitlin_senn hey I like e cigs. That is all.
# [(1.1152259472737185, 269, u'all.'), (0.54484868251814444, 534, u'cigs.'), (0.4307481552661917, 983, u'hey'), (-0.039037217666699278, 1179, u'like'), (-0.032794690749625599, 697, u'e'), (0.14673673723915265, 1043, u'i'), (0.078469599355212652, 1080, u'is'), (-0.1878964010097679, 1855, u'that'), (-0.13512854957844012, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 72 http://t.co/RMv8zmkEqm �??�?�?��?�????�?��??� �??????��??�?�? health e-cigarette ???��?�?�?�??��???�?
# [(0.71802580869885591, 963, u'health'), (0.51364538008200444, 212, u'??????????'), (0.74233605860470819, 214, u'????????????'), (-0.03503153583910551, 703, u'e-cigarette')]
#
# tweet # 73 E-cigarettes bad for you?: Professor Neal Benowitz discusses the health risks and benefits of electronic cigar... http://t.co/4AdvfIeLmG
# [(0.65585190810997374, 511, u'cigar...'), (0.3816652431092436, 371, u'benefits'), (0.28556762062517516, 1611, u'risks'), (-0.041976638441343105, 661, u'discusses'), (-0.04297250088646519, 372, u'benowitz'), (0.24617142363008895, 1340, u'neal'), (0.11212270654494266, 1520, u'professor'), (-0.22751736321624144, 2148, u'you?:'), (-0.25988025466978887, 334, u'bad'), (-0.097058281449041509, 963, u'health'), (-0.035491659547594756, 756, u'electronic'), (0.0011153253453808009, 708, u'e-cigarettes'), (-0.093191455920213537, 1859, u'the'), (-0.02231175133537272, 292, u'and'), (-0.075429604761413124, 1395, u'of'), (-0.097366252160482641, 853, u'for')]
#
# tweet # 74 I bought an E-cigarette and drove around listening to The XX. It lasts 10 days, so I gotta make a playlist that'll make Jesus want to dance.
# [(0.42285546292641335, 2046, u'want'), (0.37698948735164883, 1101, u'jesus'), (0.25036645139023811, 920, u'gotta'), (-0.04449158401547753, 624, u'days,'), (-0.033340864358288688, 146, u'10'), (0.2266004046512459, 1188, u'listening'), (0.091519674768083328, 307, u'around'), (-0.30059997541012567, 1237, u'make'), (-0.17947240592750777, 703, u'e-cigarette'), (-0.073136998706758646, 1741, u'so'), (-0.044909814883379674, 1086, u'it'), (0.0014386457125171522, 1910, u'to'), (-0.092049773531144491, 1859, u'the'), (-0.022038411539171968, 292, u'and'), (-0.078164197629316645, 288, u'an'), (-0.17386597873872847, 409, u'bought'), (0.023106313675217031, 1043, u'i'), (0.061971906939878967, 227, u'a')]
#
# tweet # 75 Lol i tried vaping yesterday #amicoolyet
# [(1.3394604348344255, 2135, u'yesterday'), (0.5130042889586689, 1200, u'lol'), (0.4692368328337177, 1939, u'tried'), (-0.032247755014538165, 1043, u'i'), (-0.045066470714479175, 2004, u'vaping')]
#
# tweet # 76 RT @AJMarriner: @Awaydays23 haha Newcastle using green smoke bombs still. Hahaha school boy stuff! Lets all laugh at Newcastle!
# [(0.44589817598208742, 315, u'at'), (0.46277259913434854, 1148, u'laugh'), (0.32267877791108573, 1165, u'lets'), (-0.05050755516765968, 411, u'boy'), (-0.043556310462347911, 1652, u'school'), (0.2409788439699202, 939, u'hahaha'), (0.1124069293832697, 937, u'haha'), (-0.17645725620509659, 924, u'green'), (-0.19095575759642988, 1721, u'smoke'), (-0.11239590499607294, 1985, u'using'), (-0.064794841788338969, 268, u'all'), (0.00077966946569349037, 1621, u'rt'), (-0.16052889086368838, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 77 RT @BigBudsMag: Do vapes get you higher? Our expert says HECK YES-- if you do it right... #cannabis #vaporizer #mmot http://t.co/Z7bq794juL
# [(0.72579409224805858, 99, u'#vaporizer'), (0.3972183441677683, 1650, u'says'), (0.34818901321007217, 797, u'expert'), (-0.035129930650276316, 1435, u'our'), (-0.04695622627877389, 2001, u'vapes'), (0.17339401781205416, 894, u'get'), (0.066947382624975085, 1086, u'it'), (-0.14244901875014382, 1052, u'if'), (-0.47800196431830627, 665, u'do'), (-0.13800524702141492, 2141, u'you'), (-0.033623301304709426, 1621, u'rt'), (0.00060308641991098355, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 78 RT @vaporkl: Lavatube lambo v4 rm220 complete set with flavor.cheapest price in http://t.co/RtYOwrFdPz me. #kltu #klrb #rtniaga  http:// ...
# [(0.80215279509522797, 73, u'#rtniaga'), (0.46680330996222907, 63, u'#kltu'), (0.29322195956378133, 1261, u'me.'), (-0.050947471770079245, 1508, u'price'), (-0.043142227971244458, 1673, u'set'), (0.26982700277893606, 567, u'complete'), (0.13187574574514349, 1150, u'lavatube'), (-0.12445595318140608, 2097, u'with'), (-0.220702216365671, 136, u'...'), (-0.049859574971619615, 1621, u'rt'), (-0.043126866840550442, 1060, u'in'), (0.00060495735858643663, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 79 Like smoke cigarettes in a strip club with a gun past midnight. Is there a more adult thing to do?
# [(0.62708700760604763, 1875, u'thing'), (0.43081367768218271, 246, u'adult'), (0.23373759555447104, 1311, u'more'), (-0.039246067246568983, 1868, u'there'), (-0.051394423522569718, 1457, u'past'), (0.27437176894614801, 547, u'club'), (0.065653525010181971, 1721, u'smoke'), (-0.12655219706916246, 2097, u'with'), (-0.22047756837157181, 1179, u'like'), (-0.055217197122215005, 1910, u'to'), (-0.04385326384046586, 1060, u'in'), (0.0027416994563457574, 227, u'a'), (-0.14262407705646615, 1080, u'is'), (-0.031807414522308272, 520, u'cigarettes')]
#
# tweet # 80 Combined sales of electronic cigarettes worldwide-both online and at brick-and-mortar stores - have far exceeded the $1-billion mark
# [(0.89636227463690732, 1246, u'mark'), (0.52162739977251771, 821, u'far'), (0.3276596482056513, 1417, u'online'), (-0.049701017417896939, 1634, u'sales'), (-0.031668926279551833, 315, u'at'), (0.12368045124927635, 756, u'electronic'), (0.080623995851854077, 131, u'-'), (-0.16216466273062716, 955, u'have'), (-0.14703670863461901, 1859, u'the'), (-0.12756467354944381, 1784, u'stores'), (-0.047127798026281219, 292, u'and'), (0.0011851368516790839, 1395, u'of'), (-0.17530829752852334, 520, u'cigarettes')]
#
# tweet # 81 If you once smoked cigarettes and now use one of those electric cigarettes. KILL YOURSELF. It is a fucking toy for adults. STOP IT.
# [(0.55640951819527629, 1091, u'it.'), (0.34127550130238854, 873, u'fucking'), (0.28503260341440428, 1120, u'kill'), (-0.03550741100502617, 524, u'cigarettes.'), (-0.033611166260367607, 1887, u'those'), (0.17184091775908142, 1412, u'one'), (0.083915401281201354, 1979, u'use'), (-0.23674609287212561, 1411, u'once'), (-0.23728681658258177, 1378, u'now'), (-0.1119779514673885, 1727, u'smoked'), (-0.049197481454595328, 1086, u'it'), (0.0012508895536431446, 1052, u'if'), (-0.21085992647257806, 1780, u'stop'), (-0.024142480787388166, 292, u'and'), (-0.084020854483057378, 2141, u'you'), (-0.10521420158403537, 1395, u'of'), (0.014480355271061828, 853, u'for'), (0.10144244630760753, 752, u'electric'), (0.59040010029119272, 227, u'a'), (0.1322476424952837, 1080, u'is'), (0.058077741431050336, 520, u'cigarettes')]
#
# tweet # 82 RT @Hifistud: .@DoctorChristian Please RT this video of real life folks who use e-cigs http://t.co/jbK4LcjIvS - it may prevent needless ear?
# [(0.55128510181446955, 1256, u'may'), (0.29134424560195565, 2084, u'who'), (0.32948822537584965, 849, u'folks'), (-0.040743853148997269, 1171, u'life'), (-0.037042388400659695, 2021, u'video'), (0.19182726058959906, 1478, u'please'), (0.086048721029166456, 1979, u'use'), (-0.24276471528787549, 1507, u'prevent'), (-0.28116357423519678, 137, u'.THIS_IS_A_MENTION'), (-0.11094665773494147, 1567, u'real'), (-0.050448192970417478, 1086, u'it'), (0.0012638510605957436, 131, u'-'), (-0.17575083825825993, 712, u'e-cigs'), (-0.026698369714141267, 1395, u'of'), (-0.098991577731466163, 1882, u'this'), (-0.16000806984497609, 1621, u'rt'), (0.008458286048111649, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 83 RT @ecigsproject: Want to save 10% OFF All Products at Smokeless Image visit http://t.co/qjMLO3LLy6 for the exclusive coupon code! #ecigspr�??
# [(0.6189649588248487, 35, u'#ecigspr??'), (0.36019932025016899, 549, u'code!'), (0.24460807055603795, 591, u'coupon'), (-0.04088006317808017, 794, u'exclusive'), (-0.03900056934990264, 1027, u'http://t.co/qjmlo3lly6'), (0.20820654205296313, 2025, u'visit'), (0.10581661131385162, 1059, u'image'), (-0.17625256586428692, 1728, u'smokeless'), (-0.28003108750897709, 1518, u'products'), (-0.11049978044102089, 147, u'10%'), (-0.065463376265181686, 1644, u'save'), (0.0011017350360897882, 315, u'at'), (-0.16506560357741509, 2046, u'want'), (-0.036822822394431687, 1398, u'off'), (-0.098373492513430541, 268, u'all'), (-0.071271024701492047, 1910, u'to'), (0.0093663344549680203, 1859, u'the'), (0.06728346203941242, 853, u'for'), (0.43332200759332667, 1621, u'rt'), (0.064028111148347874, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 84 Marissa being all selective with her cigarette smoke... msmith0789 hahah just came across this fine�?? http://t.co/ylLhBxOG3r
# [(0.97065626141323946, 448, u'came'), (0.58169940559489453, 367, u'being'), (0.37768374194160625, 978, u'her'), (-0.047065831539379738, 268, u'all'), (-0.038649161668029924, 1108, u'just'), (0.19987903581541083, 2097, u'with'), (0.10027612052496639, 1882, u'this'), (-0.16816434794665655, 512, u'cigarette')]
#
# tweet # 85 RT @ICoombs: @LindaMcAvanMEP The carcenogens in e-cig vapour are the same level as or less than that in nicorette inhalers. #EUecigBAN
# [(0.73009174420767187, 1357, u'nicorette'), (0.26068883329798009, 309, u'as'), (0.33056781942259222, 1167, u'level'), (-0.042095832779428931, 1636, u'same'), (-0.032548147932095657, 1852, u'than'), (0.23006232391155612, 1162, u'less'), (0.11513372794299746, 2015, u'vapour'), (-0.15570124630134713, 1426, u'or'), (-0.18328836048049627, 304, u'are'), (-0.098284438929833295, 1859, u'the'), (-0.047659872331229182, 698, u'e-cig'), (0.00074434986161156774, 1621, u'rt'), (-0.25476172725220469, 1060, u'in'), (-0.041488469015015107, 44, u'#euecigban'), (-0.1018172958603412, 1855, u'that'), (-0.12348394830623105, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 86 RT @jessievolt: Smoking electronic cigarette with @katiestives http://t.co/YBtyZKJp0Q
# [(0.77855989102441159, 756, u'electronic'), (0.55123022991053716, 2097, u'with'), (0.41387137941510549, 1735, u'smoking'), (-0.041545637336345524, 1621, u'rt'), (-0.05433139525109399, 512, u'cigarette'), (0.34930899182496011, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 87 RT @AasmaRbz: @MllCicicaps_MB En s'momnt jai pls d'argent pr mes clope &amp; ta cru j'allai economiser , en pls attendre pr une cigarette electriqe mdrrrrr
# [(0.52557440057746629, 1968, u'une'), (0.36557125705618576, 1819, u'ta'), (0.28443193241857978, 544, u'clope'), (-0.043144026140409256, 1277, u'mes'), (-0.071559194781457211, 1481, u'pls'), (0.37042190486174975, 762, u'en'), (0.085857778910661389, 130, u','), (-0.12903588380943526, 110, u'&amp;'), (-0.10289907674862547, 1621, u'rt'), (-0.055658652742419656, 512, u'cigarette'), (-0.042255338374533109, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 88 E-cigarettes threaten to undo years of gains: Our view http://t.co/aoSK7QNb6P via @usatoday
# [(0.82127820916738747, 2023, u'view'), (0.49698935251177279, 884, u'gains:'), (0.30745950438767616, 2131, u'years'), (-0.05640475977412647, 1967, u'undo'), (-0.053811505516825064, 1894, u'threaten'), (0.20504163745031553, 1435, u'our'), (0.10185393382320192, 2020, u'via'), (-0.14677384563213808, 708, u'e-cigarettes'), (-0.14651373280647462, 1910, u'to'), (-0.071585810562824786, 1395, u'of'), (-0.027621462614932479, 226, u'THIS_IS_A_MENTION')]
#
# ...
#
# tweet # 1971 RT @Trilliver: My parents logic: I found a cigarette filter in your wallet you must have been smoking weed. What?
# [(0.80315736721494246, 858, u'found'), (0.51305571297079922, 1449, u'parents'), (0.31325466940190261, 363, u'been'), (-0.056910059468284604, 1326, u'must'), (-0.03364292960069571, 2150, u'your'), (0.16363411147100232, 1735, u'smoking'), (0.090057067051106623, 955, u'have'), (-0.13183269146958793, 1327, u'my'), (-0.21241476843864698, 2141, u'you'), (-0.060377848164163077, 1621, u'rt'), (-0.055986158495187566, 512, u'cigarette'), (0.0012177782596364177, 1060, u'in'), (-0.15043233934576414, 1043, u'i'), (-0.029042682267253601, 227, u'a'), (-0.061280877689085758, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 1972 E-cigarettes will never catch on because they just aren't sexy via @Telegraph http://t.co/HGXdSrNof6 lung cancer is not sexy...
# [(0.70198255258787867, 470, u'catch'), (0.3928467683653451, 1676, u'sexy'), (0.28484323593693206, 306, u"aren't"), (-0.04320641466899864, 1224, u'lung'), (-0.044231452579486713, 1677, u'sexy...'), (0.21272298771271295, 455, u'cancer'), (0.086747870793536477, 358, u'because'), (-0.18610130885825935, 1345, u'never'), (-0.22672250913978059, 1871, u'they'), (-0.08906788042912879, 2091, u'will'), (-0.066668555051533226, 2020, u'via'), (0.0011480006773459284, 1108, u'just'), (-0.16673763142163195, 1372, u'not'), (-0.030634107484321035, 708, u'e-cigarettes'), (-0.087765298011670517, 1408, u'on'), (-0.098900563596124202, 1080, u'is'), (0.0078464274549984274, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 1973 RT @ICoombs: Demoise electronic cigarettes like you have with cigarettes and young people will want a go. #EUecigBAN
# [(0.60889107641846896, 2046, u'want'), (0.35588828639842479, 2091, u'will'), (0.37466281983425337, 2149, u'young'), (-0.024490132275755135, 756, u'electronic'), (-0.028425930776617141, 2097, u'with'), (0.18987849511749086, 955, u'have'), (0.087889768123870227, 1179, u'like'), (-0.1249762396283699, 292, u'and'), (-0.21211851836801221, 2141, u'you'), (-0.060293640545667944, 1621, u'rt'), (-0.085191391480310533, 44, u'#euecigban'), (0.0010868447519553476, 227, u'a'), (-0.37942761366050515, 520, u'cigarettes'), (-0.050313446829924995, 1464, u'people'), (-0.06119541063574762, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 1974 markten met mn girlieeee
# [(1.3432821461923456, 1299, u'mn'), (0.63850400385479078, 1251, u'markten'), (0.52869568771213926, 1278, u'met')]
#
# tweet # 1975 Stay away from e-cigarettes coz its also carcinogenic #dontsmoke
# [(0.99042177229355688, 462, u'carcinogenic'), (0.57636420940277788, 1771, u'stay'), (0.35656428709018489, 277, u'also'), (-0.05138132171888854, 1094, u'its'), (-0.032149533584375965, 708, u'e-cigarettes'), (0.20225329901419553, 868, u'from'), (0.13999820021015019, 326, u'away')]
#
# tweet # 1976 Buy your very own e cig today special deal going right now for a short time. Come get your e cig on
# [(0.61065775247223397, 1691, u'short'), (0.35536503999128211, 1756, u'special'), (0.20441734309609114, 2018, u'very'), (-0.035058938309094755, 1441, u'own'), (-0.027812977112230866, 913, u'going'), (0.18224862242665599, 558, u'come'), (0.094751742064082725, 626, u'deal'), (-0.13550227482217786, 437, u'buy'), (-0.23269412225183531, 1604, u'right'), (-0.077480546318148796, 1378, u'now'), (-0.075452629536066879, 1905, u'time.'), (0.0011644863942011068, 894, u'get'), (-0.28520792029049519, 2150, u'your'), (-0.048884344065193555, 505, u'cig'), (-0.15135648299655258, 697, u'e'), (-0.098418940875548075, 1408, u'on'), (0.011982380694891406, 853, u'for'), (0.1200050908842495, 1913, u'today'), (0.48855146379791692, 227, u'a')]
#
# tweet # 1977 Electric cigarette ? O.o
# [(1.4765705815603185, 203, u'?'), (0.55275961233193538, 512, u'cigarette'), (0.5152139569983043, 752, u'electric')]
#
# tweet # 1978 RT @MailOnline: France to ban electronic cigarettes from all public places and subject them to the same tight rules as tobacco http://t.co/�??
# [(0.75707196004841038, 1022, u'http://t.co/??'), (0.39986696764003798, 1477, u'places'), (0.26521578355111614, 1530, u'public'), (-0.046597119714066243, 860, u'france'), (-0.032456825915545447, 339, u'ban'), (0.16124165961305281, 309, u'as'), (0.10865786357577187, 1636, u'same'), (-0.19621099337137315, 1862, u'them'), (-0.14759972897250037, 756, u'electronic'), (-0.091190540449351362, 268, u'all'), (-0.069337374751961278, 1910, u'to'), (0.00077297024563037248, 1859, u'the'), (-0.12421862730476835, 292, u'and'), (-0.019807057594374185, 1621, u'rt'), (-0.092547029058730856, 520, u'cigarettes'), (-0.17739151409686646, 1911, u'tobacco'), (0.020151384986055121, 868, u'from'), (0.046879161493063995, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 1979 e-cigs are stupid
# [(1.641035835628786, 1797, u'stupid'), (0.5096032591871239, 304, u'are'), (0.44034552921024372, 712, u'e-cigs')]
#
# tweet # 1980 LMAO RT @cutestbudddhist: i licked my moms ecig liquid nd it turned my tongue numb nd my throat itches but i don't want to tell her..
# [(1.188902722249638, 1338, u'nd'), (0.34593392266578749, 1947, u'turned'), (0.24890839445932575, 1307, u'moms'), (-0.03296082207980585, 1196, u'lmao'), (-0.02976566013011759, 1185, u'liquid'), (0.17741188288537268, 1844, u'tell'), (0.063791627869184339, 2046, u'want'), (-0.11660924680696065, 435, u'but'), (-0.18079995614148306, 671, u"don't"), (-0.11148866358810479, 1896, u'throat'), (-0.039630104525091601, 1086, u'it'), (0.00063475745902850933, 1910, u'to'), (-0.30823126373138021, 1327, u'my'), (-0.015552461282677166, 1621, u'rt'), (-0.11508210277399014, 1043, u'i'), (-0.10190166338348985, 726, u'ecig'), (0.0066444948857999645, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 1981 RT @pakman80: @dlabbvapes sent 3600 tweets in a week! Obviously most are RTs but hey! All to save our e-cig so keep it up get it back trending #EUecigBAN
# [(0.63851166452976815, 1670, u'sent'), (0.35732689231289028, 1952, u'tweets'), (0.27801742211385216, 1623, u'rts'), (-0.040554063019421119, 1393, u'obviously'), (-0.032798471098461179, 1113, u'keep'), (0.16413755632344509, 333, u'back'), (0.084803542881415908, 1644, u'save'), (-0.14168293564440232, 1435, u'our'), (-0.19148708978994072, 435, u'but'), (-0.10338697570382402, 1313, u'most'), (-0.052217266018351007, 894, u'get'), (0.0010934573335095983, 1741, u'so'), (-0.16235828099159172, 268, u'all'), (-0.052973913792375912, 1086, u'it'), (-0.080260321013489039, 304, u'are'), (-0.07352173974644878, 1910, u'to'), (0.01893955900450494, 1973, u'up'), (0.076741551393543564, 698, u'e-cig'), (0.44700617119117009, 1621, u'rt'), (0.10979633822243491, 1060, u'in'), (0.070420213052466346, 44, u'#euecigban'), (-0.038369732157860666, 227, u'a'), (-0.014982758876703575, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 1982 @al_vaper Do YOU want Free coins for PS3 #FUT ? I have found a glitch...
# [(0.95099672376779765, 858, u'found'), (0.42014667587099591, 2046, u'want'), (0.29347607996589592, 665, u'do'), (-0.057275725684472735, 861, u'free'), (-0.047696190991175516, 203, u'?'), (0.22514394826108003, 955, u'have'), (0.084307860560766723, 2141, u'you'), (-0.16002741033018086, 853, u'for'), (-0.21383137752109643, 1043, u'i'), (-0.081700321363091258, 227, u'a'), (-0.037199829231798841, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 1983 #NameALegend yung yosey brown king of e cig trade
# [(1.1253964382278834, 425, u'brown'), (0.62979963285105678, 2153, u'yung'), (0.49001425344773847, 1123, u'king'), (-0.035120739613258026, 505, u'cig'), (-0.03309376745818772, 697, u'e'), (0.16919056808994748, 1395, u'of')]
#
# tweet # 1984 #myvapez #vapes #instavape #vapelife #vapelyfe #vapestagramm #vapeon  #vaping #vapor #ecig #vapehead�?? http://t.co/NXTILh4ReB
# [(1.0419633769723657, 95, u'#vapes'), (0.51757091686025991, 90, u'#vapelife'), (0.43629041534510243, 92, u'#vapeon'), (-0.054688027393901176, 98, u'#vapor'), (-0.040524688113208147, 26, u'#ecig'), (0.25589885778903659, 97, u'#vaping')]
#
# tweet # 1985 RT @CASAAmedia: CASAA launches tobacco harm reduction success stories collection - please submit your story! #snus #ecigarettes  http://t.c?
# [(0.77723811988119285, 30, u'#ecigarettes'), (0.45230451007315708, 1017, u'http://t.c?'), (0.33842097249252717, 556, u'collection'), (-0.051333347699488295, 1785, u'stories'), (-0.045174808441939558, 1576, u'reduction'), (0.24121284486292935, 950, u'harm'), (0.097038382328037145, 1478, u'please'), (-0.14820594158846243, 2150, u'your'), (-0.21687516037967564, 131, u'-'), (-0.050237211175412806, 1621, u'rt'), (-0.075315268436830188, 1911, u'tobacco'), (0.00060953930298695311, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 1986 Long time cigarette quitter. what about the E cigarettes with no nicotine
# [(0.82012686656586364, 1904, u'time'), (0.5281625616941098, 1203, u'long'), (0.32715494666001405, 1358, u'nicotine'), (-0.043390679981061303, 230, u'about'), (-0.032167029536821976, 2097, u'with'), (0.12743466902892905, 1859, u'the'), (0.087578978882801306, 697, u'e'), (-0.22696039267522652, 2076, u'what'), (-0.23701653600629971, 512, u'cigarette'), (-0.12858907887003657, 1366, u'no'), (-0.068792202860784885, 520, u'cigarettes')]
#
# tweet # 1987 RT @CNN: Should e-cigarettes be banned from restaurants? http://t.co/c2QuGMJnXP
# [(1.1844293022614365, 1595, u'restaurants?'), (0.57865829471652286, 342, u'banned'), (0.28041973450666596, 356, u'be'), (-0.052914106747678699, 1693, u'should'), (-0.038447104755373482, 708, u'e-cigarettes'), (0.13204274322341386, 1621, u'rt'), (0.11455669429460266, 868, u'from'), (-0.093872718308499178, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 1988 Didn't even notice I got my ecig in my ear in my new avatar
# [(0.87596987720265773, 652, u"didn't"), (0.42389210414629247, 779, u'even'), (0.26261021727904982, 919, u'got'), (-0.035273598942425495, 1346, u'new'), (-0.077494000009758798, 1327, u'my'), (0.28729727957615309, 1060, u'in'), (0.062797979244795119, 1043, u'i'), (-0.16834718741662746, 726, u'ecig')]
#
# tweet # 1989 RT @imraphael: ?@MelatiPagnoux: E-cigarette usage may lead to various chronic diseases | theSundaily http://t.co/LmmVTi7n via @sharethis ...
# [(0.96703703061372215, 1152, u'lead'), (0.48585037538225062, 224, u'?THIS_IS_A_MENTION'), (0.35905764162350989, 2157, u'|'), (-0.04992886769552856, 1256, u'may'), (-0.045613283301104368, 2020, u'via'), (0.1956595691556042, 703, u'e-cigarette'), (0.059673257997981399, 1910, u'to'), (-0.18675071920411926, 136, u'...'), (-0.16345679958681247, 1621, u'rt'), (-0.099228425943933316, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 1990 BlackFriday #BlackFriday  is too good for me because i used electronic cigarette which  i missed a lot
# [(0.69979281487240474, 17, u'#blackfriday'), (0.39906561651571643, 390, u'blackfriday'), (0.29319452463541007, 1293, u'missed'), (-0.040056617887499299, 1980, u'used'), (-0.040522558583291395, 2081, u'which'), (0.20135984630376325, 1922, u'too'), (0.10850728810600879, 1213, u'lot'), (-0.19023289400547128, 358, u'because'), (-0.15380147249355469, 756, u'electronic'), (-0.083530104492777507, 1259, u'me'), (-0.044790725859504492, 853, u'for'), (0.0010602245439032586, 512, u'cigarette'), (-0.24434144594417539, 1043, u'i'), (-0.042509723735644746, 916, u'good'), (-0.073938515191014492, 227, u'a'), (-0.11114362135064544, 1080, u'is')]
#
# tweet # 1991 Back at college hitting it on an e-cig hookah.. or as i like to call them hookah togos :) http://t.co/mfyuCUejKd
# [(0.76046088564258829, 557, u'college'), (0.37515742450049216, 444, u'call'), (0.24521512399782217, 333, u'back'), (-0.04540019572365759, 1002, u'hookah'), (-0.029400175988928419, 309, u'as'), (0.16004924026899645, 315, u'at'), (0.10502725158908897, 1862, u'them'), (-0.12918722515571576, 1086, u'it'), (-0.24793939164531517, 1426, u'or'), (-0.084346157652437678, 1179, u'like'), (-0.036212380684803411, 1910, u'to'), (0.0017629693518391263, 195, u':)'), (-0.15492029096739202, 698, u'e-cig'), (-0.059421488132731778, 997, u'hitting'), (-0.091755549638937298, 288, u'an'), (-0.12744935797174001, 1408, u'on'), (0.013562043593498392, 1043, u'i')]
#
# tweet # 1992 Ecigs Dallas Local New Places to Vape: ... http://t.co/MCdhV1O0WK Retail Store
# [(1.0750891598773866, 1198, u'local'), (0.56783590594922784, 1477, u'places'), (0.26325283889978313, 736, u'ecigs'), (-0.042497622912746433, 1783, u'store'), (-0.022786343590662061, 1910, u'to'), (0.21954316373323116, 1598, u'retail'), (0.099151448476395912, 136, u'...'), (-0.21960792970607793, 613, u'dallas'), (-0.29060145084370431, 1346, u'new')]
#
# tweet # 1993 @gem_got_ink oh and my ecig! I can smoke in bed without the stink! Technology is wonderful! lol
# [(0.86073545279514752, 727, u'ecig!'), (0.47973385195494789, 360, u'bed'), (0.27176004532724324, 1200, u'lol'), (-0.051787879852274184, 2098, u'without'), (-0.036734905339247358, 451, u'can'), (0.16116813803068308, 1721, u'smoke'), (0.052145320210260415, 1859, u'the'), (-0.12870787139373435, 1327, u'my'), (-0.18679685707849852, 292, u'and'), (-0.075374069045599179, 1060, u'in'), (-0.11222729669685928, 1402, u'oh'), (0.0010973835919807471, 1043, u'i'), (-0.16582495235170167, 1080, u'is'), (-0.019085295976568585, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 1994 I'm at ?RISE? Fridays?@ButterNC?sponsored? by ?@blucigs ?Meet ?the?@blucigs? team? and ?enter ?to ?win ?a ?trip?to? Vegas ?#risefromtheashes
# [(1.2568622040845863, 2017, u'vegas'), (0.58846890647806205, 224, u'?THIS_IS_A_MENTION'), (0.30685678333787242, 315, u'at'), (-0.051238393441837449, 439, u'by'), (-0.030585188850350782, 292, u'and'), (0.26676412370106595, 1046, u"i'm")]
#
# tweet # 1995 RT @chandler_torres: lol it says smoke free facility but literally everyone is smoking cigs
# [(0.87881515543183619, 1190, u'literally'), (0.34103396904180905, 532, u'cigs'), (0.35986512161797557, 1650, u'says'), (-0.042087756019027402, 1200, u'lol'), (-0.035874738443914728, 435, u'but'), (0.25073286980508802, 784, u'everyone'), (0.077936864452104057, 1721, u'smoke'), (-0.15818260588110489, 1086, u'it'), (-0.37233971936738774, 861, u'free'), (-0.090943099975623914, 1735, u'smoking'), (-0.040712189693782562, 1621, u'rt'), (0.0012650654398982234, 1080, u'is'), (-0.097730111526377964, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 1996 @LORD_BOPP e cig smoke nd shit ahaa
# [(1.4029588538445494, 1338, u'nd'), (0.60999531399121487, 1685, u'shit'), (0.28761216953303481, 1721, u'smoke'), (-0.043782751500064714, 505, u'cig'), (-0.041255856590098401, 697, u'e'), (0.12030904418713657, 226, u'THIS_IS_A_MENTION')]
#
# tweet # 1997 RSVP now for 15% discount on E-cigarette products at FEB 25th Vaping Party! https://t.co/z8zbhQ3v4e #minneapolis #event
# [(0.91303841594529378, 152, u'15%'), (0.51095884046579643, 660, u'discount'), (0.39755042984056765, 1620, u'rsvp'), (-0.053492381120256338, 1518, u'products'), (-0.032258102670243427, 315, u'at'), (0.20777714498630845, 1378, u'now'), (0.081537867599913341, 703, u'e-cigarette'), (-0.14340919524452705, 1408, u'on'), (-0.19421058372265301, 853, u'for'), (-0.098117346174848741, 2004, u'vaping')]
#
# tweet # 1998 BlackFriday #BlackFriday  is too good for me because i used electronic cigarette which  i missed a lot
# [(0.69979281487240474, 17, u'#blackfriday'), (0.39906561651571643, 390, u'blackfriday'), (0.29319452463541007, 1293, u'missed'), (-0.040056617887499299, 1980, u'used'), (-0.040522558583291395, 2081, u'which'), (0.20135984630376325, 1922, u'too'), (0.10850728810600879, 1213, u'lot'), (-0.19023289400547128, 358, u'because'), (-0.15380147249355469, 756, u'electronic'), (-0.083530104492777507, 1259, u'me'), (-0.044790725859504492, 853, u'for'), (0.0010602245439032586, 512, u'cigarette'), (-0.24434144594417539, 1043, u'i'), (-0.042509723735644746, 916, u'good'), (-0.073938515191014492, 227, u'a'), (-0.11114362135064544, 1080, u'is')]

# %%
test = []
>>> vector1 = (2,3,5)
>>> vector2 = (3,4,6)
>>> test=[p*q for p,q in zip(vector1, vector2)]
print test
# Out:
# [6, 12, 30]

# %%
# Get the learned coefficients for the Negative class.
coef = model.coef_[0]
# Sort them in descending order.
top_coef_ind = np.argsort(coef)[::-1]
# Get the names of those features.
top_coef_terms = vocab[top_coef_ind]
# Get the weights of those features
top_coef = coef[top_coef_ind]
# Print the top 10.
print 'top weighted terms for negative class:\n', \
    '\n'.join('%s %.2f' % (term, weight) for term, weight in zip(top_coef_terms, top_coef)[:10])
# Out:
# top weighted terms for negative class:
# smoking 2.58
# class 1.90
# people 1.81
# shit 1.62
# stupid 1.61
# pussy 1.57
# s 1.54
# sorry 1.52
# kid 1.48
# smoke 1.46

# %%
# Get the learned coefficients for the OTHER class.
coef = model.coef_[1]
# Sort them in descending order.
top_coef_ind = np.argsort(coef)[::-1]
# Get the names of those features.
top_coef_terms = vocab[top_coef_ind]
# Get the weights of those features
top_coef = coef[top_coef_ind]
# Print the top 10.
print 'top weighted terms for other class:\n', \
    '\n'.join('%s %.2f' % (term, weight) for term, weight in zip(top_coef_terms, top_coef)[:10])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-64-0f4fc203dbcd> in <module>()
#       1 # Get the learned coefficients for the OTHER class.
# ----> 2 coef = model.coef_[1]
#       3 # Sort them in descending order.
#       4 top_coef_ind = np.argsort(coef)[::-1]
#       5 # Get the names of those features.
#
# IndexError: index 1 is out of bounds for axis 0 with size 1

# %%
# How does tokenization affect accuracy?
# Collapse urls and mentions; ignore description prefix.
from itertools import product
def run_all(tweets, lowercase=True,
            keep_punctuation=True,
            collapse_urls=True, collapse_mentions=True):
    
    #vectorizer = TfidfVectorizer(decode_error='ignore', tokenizer=tokenize1)#lowercase, url's, mentions
    #B = vectorizer.fit_transform(t['text'] for t in tweets)
    #print B
    
    tokens_list = [tweet2tokens(t, lowercase, keep_punctuation,collapse_urls, collapse_mentions) for t in tweets]
    vocabulary = make_vocabulary(tokens_list)
    A = make_feature_matrix(tokens_list, vocabulary)
    print 'acc=', do_cross_val(A, y, 10)

# %%
# Store these in a sparse matrix.

#1) Create a vocabulary (dict from term->index)

# https://docs.python.org/2/library/collections.html#collections.defaultdict
from collections import defaultdict

def make_vocabulary(tokens_list):
    vocabulary = defaultdict(lambda: len(vocabulary))
    for tokens in tokens_list:
        for token in tokens:
            vocabulary[token]
    print '%d unique terms in vocabulary' % len(vocabulary)
    return vocabulary

# Convert features to a sparse matrix X.
# X[i,j] is the frequency of term j in tweet i
# 
from scipy.sparse import lil_matrix #list of list (LIL)

def make_feature_matrix(tokens_list, vocabulary):
    X = lil_matrix((len(tweets), len(vocabulary)))
    for i, tokens in enumerate(tokens_list):
        for token in tokens:
            j = vocabulary[token]
            X[i,j] += 1
    return X.tocsr()


# Do 5-fold cross-validation
# http://scikit-learn.org/stable/modules/generated/sklearn.cross_validation.KFold.html
from sklearn.cross_validation import KFold
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix

def do_cross_val(X, y, nfolds):
    """ Compute average cross-validation acccuracy."""
    cv = KFold(len(y), nfolds)
    accuracies = []
    for train_idx, test_idx in cv:
        clf = LogisticRegression()
        clf.fit(X[train_idx], y[train_idx])
        predicted = clf.predict(X[test_idx])
        acc = accuracy_score(y[test_idx], predicted)
        accuracies.append(acc)
    avg = np.mean(accuracies)
    return avg


argnames = ['lower', 'punct', 'url', 'mention']
lowercase_opts = [True, False]
keep_punctuation_opts = [True, False]
url_opts = [True, False]
mention_opts = [True, False]

option_iter = product(lowercase_opts, keep_punctuation_opts,url_opts, mention_opts)

for options in option_iter:
    print '\t'.join('%s=%s' % (name, opt) for name, opt in zip(argnames, options))
    run_all(tweets, *options)
    print
# Out:
# lower=True	punct=True	url=True	mention=True
# 7653 unique terms in vocabulary
# acc= 0.806
#
# lower=True	punct=True	url=True	mention=False
# 8711 unique terms in vocabulary
# acc= 0.802
#
# lower=True	punct=True	url=False	mention=True
# 8312 unique terms in vocabulary
# acc= 0.814
#
# lower=True	punct=True	url=False	mention=False
# 9370 unique terms in vocabulary
# acc= 0.81
#
# lower=True	punct=False	url=True	mention=True
# 5761 unique terms in vocabulary
# acc= 0.808
#
# lower=True	punct=False	url=True	mention=False
# 6767 unique terms in vocabulary
# acc= 0.8095
#
# lower=True	punct=False	url=False	mention=True
# 6401 unique terms in vocabulary
# acc= 0.8045
#
# lower=True	punct=False	url=False	mention=False
# 7407 unique terms in vocabulary
# acc= 0.811
#
# lower=False	punct=True	url=True	mention=True
# 8638 unique terms in vocabulary
# acc= 0.8035
#
# lower=False	punct=True	url=True	mention=False
# 9701 unique terms in vocabulary
# acc= 0.8075
#
# lower=False	punct=True	url=False	mention=True
# 9297 unique terms in vocabulary
# acc= 0.804
#
# lower=False	punct=True	url=False	mention=False
# 10360 unique terms in vocabulary
# acc= 0.8035
#
# lower=False	punct=False	url=True	mention=True
# 6833 unique terms in vocabulary
# acc= 0.802
#
# lower=False	punct=False	url=True	mention=False
# 7859 unique terms in vocabulary
# acc= 0.804
#
# lower=False	punct=False	url=False	mention=True
# 7474 unique terms in vocabulary
# acc= 0.7995
#
# lower=False	punct=False	url=False	mention=False
# 8500 unique terms in vocabulary
# acc= 0.806
