# %%
#seach for organic tweets and save them in one list
from collections import Counter
import csv
tweets=[]
positive_tweets = 0
negative_tweets = 0
other_tweets = 0

with open( 'D:\AllSamplesPositiveandNeutral.csv', "rb" ) as theFile:
    reader = csv.DictReader( theFile )
    for row in reader:
        if row['sent']== '1':
            positive_tweets += 1
        elif row['sent']== '-1':
            negative_tweets += 1
        else:
            other_tweets += 1
        
        tweets.append(row) 
print 'We have', len(tweets), 'sampled tweets'
print positive_tweets, 'are positive'
print negative_tweets, 'are negative'
print other_tweets, 'are nothing'
# Out:
# We have 2000 sampled tweets
# 676 are positive
# 0 are negative
# 1324 are nothing

# %%
# Create label vector (y) that show the class labels of each tweet
#print the count of each class label
from collections import Counter
import numpy as np
y = np.array([int(t['sent']) for t in tweets])#savind labels of the class in y
print 'label counts=', Counter(y)
# Out:
# label counts= Counter({0: 1324, 1: 676})

# %%
# %pylab inline
# What is the distribution of scores?
from collections import Counter
import matplotlib.pyplot as plt

counts = Counter(y).values()
vals = [1,2]

plt.bar(vals, counts)
plt.xticks(vals)
plt.xlabel('sentiment')
plt.ylabel('count')
plt.title('1:Other, 2:Positive')
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
"""Best tokenization configuration: lower=True, punct=True,url=False,mention=True
8312 unique terms in vocabulary
acc= 0.814"""

import re
def tokenize1(string, lowercase=True, keep_punctuation=True,collapse_urls=False, collapse_mentions=True):
    if not string:
        return []
    if lowercase:
        string = string.lower()
    tokens = []
    if collapse_urls:
        string = re.sub('http\S+', 'THIS_IS_A_URL', string)
    if collapse_mentions:
        string = re.sub('@\S+', 'THIS_IS_A_MENTION', string)
    if keep_punctuation:
        tokens = string.split()
    else:
        tokens = re.sub('\W+', ' ', string).split()
    return tokens

def tweet2tokens(tweet, lowercase=True,keep_punctuation=True,collapse_urls=True, collapse_mentions=True):
    #print('tweet:', tweet)
    tokens = tokenize1(tweet['text'], lowercase, keep_punctuation, collapse_urls, collapse_mentions)
    return tokens

# %%
# Let's tokenize all tweets.
tokens_list = [tweet2tokens(t, lowercase=True,keep_punctuation=False,collapse_urls=True, collapse_mentions=True) for t in tweets]

# %%
tokens_list[1]
# Out:
# ['THIS_IS_A_MENTION',
#  'anything',
#  'that',
#  'attracts',
#  'people',
#  'away',
#  'from',
#  'tobacco',
#  'cigarettes',
#  'is',
#  'a',
#  'good',
#  'thing',
#  'inc',
#  'ecig',
#  'flavours',
#  'euecigban']

# %%
for t in range(len(tokens_list)):
    print tokens_list[t]
    break
# Out:
# ['vaping', 'kush', 'gt', 'smoking', 'kush']

# %%
for t in tweets:
    print t['text']
    break
# Out:
# Vaping kush&gt;Smoking kush

# %%
#use after pre processing 
# Create feature vectors (X)
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(decode_error='ignore')# CountVectorizer(decode_error='ignore',lowercase =False)
X = vectorizer.fit_transform(t['text'] for t in tweets)
print 'default - vectorized %d tweets. found %d terms.' % (X.shape[0], X.shape[1])
# Out:
# default - vectorized 2000 tweets. found 7370 terms.

# %%
#use after pre processing 
# Create feature vectors (X)
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(decode_error='ignore', lowercase=False)
X = vectorizer.fit_transform(t['text'] for t in tweets)
print 'no lower case vectorized %d tweets. found %d terms.' % (X.shape[0], X.shape[1])
# Out:
# no lower case vectorized 2000 tweets. found 8439 terms.

# %%
#use after pre processing 
# Create feature vectors (X)
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(decode_error='ignore', lowercase=True, stop_words='english')# CountVectorizer(decode_error='ignore',lowercase =False)
X = vectorizer.fit_transform(t['text'] for t in tweets)
print 'lower case, stop words - vectorized %d tweets. found %d terms.' % (X.shape[0], X.shape[1])
# Out:
# lower case, stop words - vectorized 2000 tweets. found 7140 terms.

# %%
tweets_text=[]
for t in tweets:
    tweets_text.append(t['text'])
    
for t in tweets_text:
    print t
    break
# Out:
# Vaping kush&gt;Smoking kush

# %%
# Create feature vectors (X)
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(decode_error='ignore', ngram_range=(1, 1),max_df=1.0, min_df=2, tokenizer=tokenize1,binary=False)#lowercase, url's, mentions
X = vectorizer.fit_transform(t['text'] for t in tweets)
print 'vectorized %d tweet. found %d terms.' % (X.shape[0], X.shape[1])
# Out:
# vectorized 2000 tweet. found 2159 terms.

# %%
print vectorizer.vocabulary_.items()[:20]
# Out:
# [(u"friend's", 866), (u'straight', 1788), (u'her.', 979), (u'#suryaray', 80), (u'whose', 2087), (u'#euecigban', 44), (u'here', 980), (u'china', 499), (u'kids', 1118), (u"i'd", 1044), (u"i'm", 1046), (u'music', 1324), (u'care', 464), (u'until', 1971), (u'thuis', 1899), (u'glass', 908), (u'http://t.co/rgylakkdpq', 1028), (u'wana', 2044), (u'want', 2046), (u'absolute', 231)]

# %%
# What are the most frequent terms?
# Sum columns:
col_sums = X.sum(axis=0).tolist()[0]
# Sort sums in descending order, and return the indices
top_indices = np.argsort(col_sums)[::-1]
print 'top_indices=', top_indices
vocab = np.array(vectorizer.get_feature_names())
top_terms = vocab[top_indices]
print 'top_terms:\n', '\n'.join('%s %d' % (term, count) for term, count in zip(top_terms, top_indices)[:10])
# Out:
# top_indices= [ 226 1859 1621 ..., 1642  587  379]
# top_terms:
# THIS_IS_A_MENTION 226
# the 1859
# rt 1621
# to 1910
# i 1043
# a 227
# electronic 756
# my 1327
# in 1060
# and 292

# %%
from sklearn.cross_validation import cross_val_score
from sklearn.cross_validation import KFold
from sklearn.linear_model import LogisticRegression

def do_cv(X, y, nfolds=10):
    cv = KFold(len(y), nfolds)
    return np.mean(cross_val_score(LogisticRegression(), X, y, cv=cv))
  
print do_cv(X, y)
# Out:
# 0.796

# %%
# Fit a LogisticRegression model
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X, y)

# Compute accuracy
def accuracy(truth, predicted):
    return (1. * len([1 for tr, pr in zip(truth, predicted) if tr == pr]) / len(truth))

predicted = model.predict(X)
print 'accuracy on training data=%.3f' % accuracy(y, predicted)


# 5 Cross-validation accuracy
from sklearn.cross_validation import KFold

cv = KFold(len(y), 10)
accuracies = []
print 'Fitting in the labeled data:'
#print 'Train set:',X[train_ind].shape[0], '\f Test set:', X[test_ind].shape[0]
for train_ind, test_ind in cv:
    model.fit(X[train_ind], y[train_ind])
    
    predictions = model.predict(X[test_ind])
    accuracies.append(accuracy(y[test_ind], predictions))
    
print 'Average 5-fold cross validation accuracy=%.2f (std=%.2f)' % (np.mean(accuracies), np.std(accuracies))
# Out:
# accuracy on training data=0.864
# Fitting in the labeled data:
# Average 5-fold cross validation accuracy=0.81 (std=0.03)

# %%
p=0
n=0
o=0
for i in model.predict(X):
    if i==1:
        p+=1
    elif i==-1:
        n+=1
    else:
        o+=1

print n
print o
print p
print len(model.predict(X))
# Out:
# 0
# 1495
# 505
# 2000

# %%
from sklearn.metrics import confusion_matrix as sk_confusion_matrix
import pandas as pd


y_pred = model.predict(X)

def confusion_matrix(y_test, y_pred):
    cm = sk_confusion_matrix(y, y_pred)
    cm = pd.DataFrame(data=cm, columns=[0,1], index=[0,1])
    cm.columns.name = 'Predicted'
    cm.index.name = 'Expected'
    error_rate = (y_pred != y).mean()
    print('error rate: %.2f' % error_rate)
    return cm
    
confusion_matrix(y, y_pred)
# Out:
# error rate: 0.14
# Predicted     0    1
# Expected
# 0          1267   57
# 1           228  448

# %%
#precision, recall and F1 measures for both classes
from sklearn.metrics import precision_recall_fscore_support
y_true = y
y_pred = model.predict(X)
print '1',precision_recall_fscore_support(y_true, y_pred)
# Out:
# 1 (array([ 0.84749164,  0.88712871]), array([ 0.95694864,  0.66272189]), array([ 0.89890032,  0.75867909]), array([1324,  676], dtype=int64))

# %%
#confusion matrix again
y_pred = model.predict(X)
def create_conf_matrix(expected, predicted, n_classes):
    m = [[0] * n_classes for i in range(n_classes)]
    for pred, exp in zip(predicted, expected):#combining predicted and expected values like (1,0) and 
        m[pred][exp] += 1 #adding to those same positions a count
    return m

print create_conf_matrix(y, y_pred,2)
# Out:
# [[1267, 228], [57, 448]]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

def tokenizing(tweets, vectorizer):
    X = vectorizer.fit_transform(t['text'] for t in tweets)
    print 'X dimensions=', X.shape
    return X

# %%
# How does using ngrams help?
import matplotlib.pyplot as plt

def compare_ngrams(tweets, y):
    accuracies = []
    ngrams = [(1,1), (1,2), (2,2), (1,3), (2, 3), (3,3)]
    for ngram in ngrams:
        print ngram
        accuracies.append(do_cv(tokenizing(tweets, TfidfVectorizer(decode_error='ignore', ngram_range=ngram, tokenizer=tokenize1)), y))
    plt.figure()
    plt.plot(accuracies, 'bo-')
    plt.xticks(range(len(ngrams)), ngrams)
    plt.xlabel('ngrams')
    plt.ylabel('accuracy')
    plt.show()
        
compare_ngrams(tweets, y)
# Out:
# (1, 1)
# X dimensions= (2000, 5760)
# (1, 2)
# X dimensions= (2000, 23826)
# (2, 2)
# X dimensions= (2000, 18066)
# (1, 3)
# X dimensions= (2000, 46211)
# (2, 3)
# X dimensions= (2000, 40451)
# (3, 3)
# X dimensions= (2000, 22385)

# %%
def compare_mindDF(tweets, y):
    accuracies = []
    for freq in range(20):
        accuracies.append(do_cv(tokenizing(tweets, TfidfVectorizer(decode_error='ignore', tokenizer=tokenize1,ngram_range=(1,1),
                                                                   min_df=freq)), y))
    plt.figure()
    plt.plot(accuracies, 'bo-')
    plt.xticks(range(20))
    plt.xlabel('minDF')
    plt.ylabel('accuracy')
    plt.show()
        
compare_mindDF(tweets, y)
# Out:
# X dimensions= (2000, 5760)
# X dimensions= (2000, 5760)
# X dimensions= (2000, 1996)
# X dimensions= (2000, 1271)
# X dimensions= (2000, 928)
# X dimensions= (2000, 723)
# X dimensions= (2000, 599)
# X dimensions= (2000, 503)
# X dimensions= (2000, 437)
# X dimensions= (2000, 397)
# X dimensions= (2000, 355)
# X dimensions= (2000, 317)
# X dimensions= (2000, 285)
# X dimensions= (2000, 263)
# X dimensions= (2000, 236)
# X dimensions= (2000, 220)
# X dimensions= (2000, 213)
# X dimensions= (2000, 205)
# X dimensions= (2000, 198)
# X dimensions= (2000, 193)

# %%
# How does filtering common words affect accuracy?
import matplotlib.pyplot as plt

def compare_maxdf(tweets, y):
    accuracies = []
    maxdfs = [1., .1, .05, .04, .03, .02, .01, .005, .001]
    for freq in maxdfs:
        print freq
        accuracies.append(do_cv(tokenizing(tweets, TfidfVectorizer(decode_error='ignore',max_df=freq, tokenizer=tokenize1, 
                                                                   ngram_range=(1,1))), y))
    plt.figure()
    plt.plot(maxdfs, accuracies, 'bo-')
    plt.xlabel('maxdf (fraction)')
    plt.ylabel('accuracy')
    plt.show()
        
compare_maxdf(tweets, y)
# Out:
# 1.0
# X dimensions= (2000, 5760)
# 0.1
# X dimensions= (2000, 5737)
# 0.05
# X dimensions= (2000, 5719)
# 0.04
# X dimensions= (2000, 5714)
# 0.03
# X dimensions= (2000, 5697)
# 0.02
# X dimensions= (2000, 5673)
# 0.01
# X dimensions= (2000, 5586)
# 0.005
# X dimensions= (2000, 5443)
# 0.001
# X dimensions= (2000, 4489)

# %%
# Does binary/freq help?
def compare_binary(tweets, y):
    accuracies = []
    choices = [True, False]
    for choice in choices:
        print choice
        accuracies.append(do_cv(tokenizing(tweets, TfidfVectorizer(decode_error='ignore',binary=choice, 
                                                                   min_df=3, ngram_range=(1,1), max_df=1.0, tokenizer=tokenize1)), y))
    plt.figure()
    plt.plot(accuracies, 'bo-')
    plt.xticks([0,1], [str(c) for c in choices])
    plt.xlabel('binary')
    plt.ylabel('accuracy')
    plt.show()
        
compare_binary(tweets, y)
# Out:
# True
# X dimensions= (2000, 1271)
# False
# X dimensions= (2000, 1271)

# %%
# Does idf help?
def compare_idf(tweets, y):
    accuracies = []
    choices = [True, False]
    for choice in choices:
        print choice
        accuracies.append(do_cv(tokenizing(tweets, TfidfVectorizer(decode_error='ignore',use_idf=choice, 
                                                                   binary=False, min_df=3, ngram_range=(1,1), max_df=1.)), y))
    plt.figure()
    plt.plot(accuracies, 'bo-')
    plt.xticks([0,1], [str(c) for c in choices])
    plt.xlabel('binary')
    plt.ylabel('use idf?')
    plt.show()
        
compare_idf(tweets, y)
# Out:
# True
# X dimensions= (2000, 1285)
# False
# X dimensions= (2000, 1285)

# %%
# Do stop words help?
def compare_stopwords(tweets, y):
    accuracies = []
    choices = [None, 'english']
    for choice in choices:
        print choice
        accuracies.append(do_cv(tokenizing(tweets, TfidfVectorizer(decode_error='ignore',stop_words=choice,
                                                                 use_idf=False, binary=False, min_df=3, ngram_range=(1,1),
                                                                   tokenizer=tokenize1, max_df=1.0)), y))
    plt.figure()
    plt.plot(accuracies, 'bo-')
    plt.xticks([0,1], [str(c) for c in choices])
    plt.xlabel('binary')
    plt.ylabel('use stopwords')
    plt.show()
        
compare_stopwords(tweets, y)
# Out:
# None
# X dimensions= (2000, 1271)
# english
# X dimensions= (2000, 1092)

# %%
# Do GridSearch on all parameters.
from sklearn.grid_search import GridSearchCV
from sklearn.pipeline import Pipeline
from pprint import pprint

pipeline = Pipeline([
    ('vect', TfidfVectorizer(decode_error='ignore',tokenizer=tokenize1)),
    ('clf', LogisticRegression()),
])

parameters = {
    'vect__min_df': (1, 2, 3, 4, 5),
    'vect__ngram_range': ((1, 1), (1, 2), (1, 3)),  # unigrams or bigrams or trigrams
    'vect__use_idf': (True, False),
    'vect__max_df':(1., .1, .05, .04, .03),
    'vect__tokenizer':(None, tokenize1)
}

data = [t['text'] for t in tweets]
grid_search = GridSearchCV(pipeline, parameters, verbose=1, cv=KFold(len(y), 10))

print "Performing grid search..."
print "pipeline:", [name for name, _ in pipeline.steps]
print "parameters:"
pprint(parameters)
grid_search.fit(data, y)
print "done."

print("Best score: %0.3f" % grid_search.best_score_)
print("Best parameters set:")
best_parameters = grid_search.best_estimator_.get_params()
for param_name in sorted(parameters.keys()):
    print("\t%s: %r" % (param_name, best_parameters[param_name]))
# Out:
# [Parallel(n_jobs=1)]: Done   1 jobs       | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  50 jobs       | elapsed:    5.3s
# [Parallel(n_jobs=1)]: Done 200 jobs       | elapsed:   34.8s
# [Parallel(n_jobs=1)]: Done 450 jobs       | elapsed:  1.3min
# [Parallel(n_jobs=1)]: Done 800 jobs       | elapsed:  2.5min
# [Parallel(n_jobs=1)]: Done 1250 jobs       | elapsed:  4.0min
# [Parallel(n_jobs=1)]: Done 1800 jobs       | elapsed:  6.1min
# [Parallel(n_jobs=1)]: Done 2450 jobs       | elapsed:  8.2min
# Performing grid search...
# pipeline: ['vect', 'clf']
# parameters:
# {'vect__max_df': (1.0, 0.1, 0.05, 0.04, 0.03),
#  'vect__min_df': (1, 2, 3, 4, 5),
#  'vect__ngram_range': ((1, 1), (1, 2), (1, 3)),
#  'vect__tokenizer': (None, <function tokenize1 at 0x000000000ABD3CF8>),
#  'vect__use_idf': (True, False)}
# Fitting 10 folds for each of 300 candidates, totalling 3000 fits
# done.
# Best score: 0.812
# Best parameters set:
# 	vect__max_df: 1.0
# 	vect__min_df: 2
# 	vect__ngram_range: (1, 1)
# 	vect__tokenizer: <function tokenize1 at 0x000000000ABD3CF8>
# 	vect__use_idf: True
# [Parallel(n_jobs=1)]: Done 3000 out of 3000 | elapsed: 10.2min finished

# %%
print '\n'.join(str(x) for x in grid_search.grid_scores_)
# Out:
# mean: 0.79450, std: 0.03751, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 1, 'vect__max_df': 1.0}
# mean: 0.79400, std: 0.03353, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 1, 'vect__max_df': 1.0}
# mean: 0.81150, std: 0.02967, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 1, 'vect__max_df': 1.0}
# mean: 0.80800, std: 0.03084, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 1, 'vect__max_df': 1.0}
# mean: 0.78750, std: 0.04429, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 1, 'vect__max_df': 1.0}
# mean: 0.78550, std: 0.03602, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 1, 'vect__max_df': 1.0}
# mean: 0.80550, std: 0.03343, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 1, 'vect__max_df': 1.0}
# mean: 0.80250, std: 0.02857, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 1, 'vect__max_df': 1.0}
# mean: 0.78350, std: 0.04117, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 1, 'vect__max_df': 1.0}
# mean: 0.77950, std: 0.03738, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 1, 'vect__max_df': 1.0}
# mean: 0.80100, std: 0.03231, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 1, 'vect__max_df': 1.0}
# mean: 0.79850, std: 0.03131, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 1, 'vect__max_df': 1.0}
# mean: 0.79050, std: 0.03990, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 2, 'vect__max_df': 1.0}
# mean: 0.79600, std: 0.03308, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 2, 'vect__max_df': 1.0}
# mean: 0.81250, std: 0.02839, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 2, 'vect__max_df': 1.0}
# mean: 0.80700, std: 0.03084, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 2, 'vect__max_df': 1.0}
# mean: 0.79300, std: 0.03932, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 2, 'vect__max_df': 1.0}
# mean: 0.79500, std: 0.03834, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 2, 'vect__max_df': 1.0}
# mean: 0.80850, std: 0.03241, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 2, 'vect__max_df': 1.0}
# mean: 0.80300, std: 0.02610, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 2, 'vect__max_df': 1.0}
# mean: 0.78800, std: 0.03995, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 2, 'vect__max_df': 1.0}
# mean: 0.79300, std: 0.03716, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 2, 'vect__max_df': 1.0}
# mean: 0.80800, std: 0.03211, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 2, 'vect__max_df': 1.0}
# mean: 0.80150, std: 0.02775, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 2, 'vect__max_df': 1.0}
# mean: 0.79150, std: 0.03847, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 3, 'vect__max_df': 1.0}
# mean: 0.79800, std: 0.03473, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 3, 'vect__max_df': 1.0}
# mean: 0.80900, std: 0.02931, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 3, 'vect__max_df': 1.0}
# mean: 0.80600, std: 0.02965, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 3, 'vect__max_df': 1.0}
# mean: 0.79400, std: 0.03974, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 3, 'vect__max_df': 1.0}
# mean: 0.79500, std: 0.03708, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 3, 'vect__max_df': 1.0}
# mean: 0.81100, std: 0.02764, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 3, 'vect__max_df': 1.0}
# mean: 0.80450, std: 0.02832, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 3, 'vect__max_df': 1.0}
# mean: 0.79250, std: 0.03823, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 3, 'vect__max_df': 1.0}
# mean: 0.79450, std: 0.03602, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 3, 'vect__max_df': 1.0}
# mean: 0.80900, std: 0.03097, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 3, 'vect__max_df': 1.0}
# mean: 0.80200, std: 0.02821, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 3, 'vect__max_df': 1.0}
# mean: 0.79350, std: 0.04019, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 4, 'vect__max_df': 1.0}
# mean: 0.79350, std: 0.03241, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 4, 'vect__max_df': 1.0}
# mean: 0.80600, std: 0.02922, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 4, 'vect__max_df': 1.0}
# mean: 0.80700, std: 0.03043, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 4, 'vect__max_df': 1.0}
# mean: 0.79600, std: 0.04067, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 4, 'vect__max_df': 1.0}
# mean: 0.79500, std: 0.03578, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 4, 'vect__max_df': 1.0}
# mean: 0.81150, std: 0.02811, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 4, 'vect__max_df': 1.0}
# mean: 0.80800, std: 0.02821, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 4, 'vect__max_df': 1.0}
# mean: 0.79450, std: 0.03863, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 4, 'vect__max_df': 1.0}
# mean: 0.79350, std: 0.03543, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 4, 'vect__max_df': 1.0}
# mean: 0.80850, std: 0.02811, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 4, 'vect__max_df': 1.0}
# mean: 0.80550, std: 0.02761, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 4, 'vect__max_df': 1.0}
# mean: 0.79200, std: 0.03750, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 5, 'vect__max_df': 1.0}
# mean: 0.79350, std: 0.03294, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 5, 'vect__max_df': 1.0}
# mean: 0.80700, std: 0.03356, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 5, 'vect__max_df': 1.0}
# mean: 0.80750, std: 0.02977, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 5, 'vect__max_df': 1.0}
# mean: 0.79400, std: 0.03872, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 5, 'vect__max_df': 1.0}
# mean: 0.79200, std: 0.03429, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 5, 'vect__max_df': 1.0}
# mean: 0.80950, std: 0.03453, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 5, 'vect__max_df': 1.0}
# mean: 0.80650, std: 0.02702, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 5, 'vect__max_df': 1.0}
# mean: 0.79400, std: 0.03942, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 5, 'vect__max_df': 1.0}
# mean: 0.79150, std: 0.03362, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 5, 'vect__max_df': 1.0}
# mean: 0.80800, std: 0.03226, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 5, 'vect__max_df': 1.0}
# mean: 0.80550, std: 0.02583, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 5, 'vect__max_df': 1.0}
# mean: 0.74600, std: 0.04836, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 1, 'vect__max_df': 0.1}
# mean: 0.74450, std: 0.04687, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 1, 'vect__max_df': 0.1}
# mean: 0.74550, std: 0.04671, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 1, 'vect__max_df': 0.1}
# mean: 0.74500, std: 0.04642, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 1, 'vect__max_df': 0.1}
# mean: 0.75600, std: 0.04398, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 1, 'vect__max_df': 0.1}
# mean: 0.77150, std: 0.04301, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 1, 'vect__max_df': 0.1}
# mean: 0.76750, std: 0.03913, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 1, 'vect__max_df': 0.1}
# mean: 0.78250, std: 0.03579, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 1, 'vect__max_df': 0.1}
# mean: 0.74550, std: 0.04585, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 1, 'vect__max_df': 0.1}
# mean: 0.77150, std: 0.04278, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 1, 'vect__max_df': 0.1}
# mean: 0.75600, std: 0.04482, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 1, 'vect__max_df': 0.1}
# mean: 0.77800, std: 0.03348, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 1, 'vect__max_df': 0.1}
# mean: 0.74950, std: 0.05373, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 2, 'vect__max_df': 0.1}
# mean: 0.74400, std: 0.04918, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 2, 'vect__max_df': 0.1}
# mean: 0.74500, std: 0.05381, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 2, 'vect__max_df': 0.1}
# mean: 0.74600, std: 0.04737, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 2, 'vect__max_df': 0.1}
# mean: 0.77000, std: 0.04858, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 2, 'vect__max_df': 0.1}
# mean: 0.77350, std: 0.04615, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 2, 'vect__max_df': 0.1}
# mean: 0.78050, std: 0.04645, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 2, 'vect__max_df': 0.1}
# mean: 0.78550, std: 0.04095, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 2, 'vect__max_df': 0.1}
# mean: 0.76950, std: 0.04972, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 2, 'vect__max_df': 0.1}
# mean: 0.77250, std: 0.04573, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 2, 'vect__max_df': 0.1}
# mean: 0.78150, std: 0.04231, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 2, 'vect__max_df': 0.1}
# mean: 0.78250, std: 0.04020, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 2, 'vect__max_df': 0.1}
# mean: 0.75100, std: 0.04954, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 3, 'vect__max_df': 0.1}
# mean: 0.75000, std: 0.04528, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 3, 'vect__max_df': 0.1}
# mean: 0.74950, std: 0.05160, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 3, 'vect__max_df': 0.1}
# mean: 0.75050, std: 0.04671, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 3, 'vect__max_df': 0.1}
# mean: 0.77500, std: 0.04817, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 3, 'vect__max_df': 0.1}
# mean: 0.77200, std: 0.04638, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 3, 'vect__max_df': 0.1}
# mean: 0.78450, std: 0.04693, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 3, 'vect__max_df': 0.1}
# mean: 0.78200, std: 0.03964, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 3, 'vect__max_df': 0.1}
# mean: 0.77450, std: 0.04596, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 3, 'vect__max_df': 0.1}
# mean: 0.77400, std: 0.04630, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 3, 'vect__max_df': 0.1}
# mean: 0.78450, std: 0.04275, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 3, 'vect__max_df': 0.1}
# mean: 0.78100, std: 0.04128, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 3, 'vect__max_df': 0.1}
# mean: 0.75500, std: 0.04588, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 4, 'vect__max_df': 0.1}
# mean: 0.75100, std: 0.04346, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 4, 'vect__max_df': 0.1}
# mean: 0.75900, std: 0.04737, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 4, 'vect__max_df': 0.1}
# mean: 0.75000, std: 0.04410, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 4, 'vect__max_df': 0.1}
# mean: 0.78100, std: 0.04188, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 4, 'vect__max_df': 0.1}
# mean: 0.77750, std: 0.04082, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 4, 'vect__max_df': 0.1}
# mean: 0.78550, std: 0.04216, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 4, 'vect__max_df': 0.1}
# mean: 0.78050, std: 0.03902, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 4, 'vect__max_df': 0.1}
# mean: 0.78050, std: 0.04491, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 4, 'vect__max_df': 0.1}
# mean: 0.77500, std: 0.04319, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 4, 'vect__max_df': 0.1}
# mean: 0.78500, std: 0.03808, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 4, 'vect__max_df': 0.1}
# mean: 0.78200, std: 0.03558, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 4, 'vect__max_df': 0.1}
# mean: 0.75150, std: 0.04456, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 5, 'vect__max_df': 0.1}
# mean: 0.75000, std: 0.04353, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 5, 'vect__max_df': 0.1}
# mean: 0.75700, std: 0.04302, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 5, 'vect__max_df': 0.1}
# mean: 0.74650, std: 0.04517, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 5, 'vect__max_df': 0.1}
# mean: 0.77550, std: 0.04424, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 5, 'vect__max_df': 0.1}
# mean: 0.77450, std: 0.04601, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 5, 'vect__max_df': 0.1}
# mean: 0.78250, std: 0.03810, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 5, 'vect__max_df': 0.1}
# mean: 0.78250, std: 0.03862, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 5, 'vect__max_df': 0.1}
# mean: 0.77650, std: 0.04489, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 5, 'vect__max_df': 0.1}
# mean: 0.77450, std: 0.04480, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 5, 'vect__max_df': 0.1}
# mean: 0.78350, std: 0.03854, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 5, 'vect__max_df': 0.1}
# mean: 0.78250, std: 0.03743, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 5, 'vect__max_df': 0.1}
# mean: 0.72950, std: 0.04922, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 1, 'vect__max_df': 0.05}
# mean: 0.73750, std: 0.04844, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 1, 'vect__max_df': 0.05}
# mean: 0.73400, std: 0.04253, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 1, 'vect__max_df': 0.05}
# mean: 0.73700, std: 0.04389, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 1, 'vect__max_df': 0.05}
# mean: 0.73000, std: 0.04177, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 1, 'vect__max_df': 0.05}
# mean: 0.74900, std: 0.04011, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 1, 'vect__max_df': 0.05}
# mean: 0.74850, std: 0.04219, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 1, 'vect__max_df': 0.05}
# mean: 0.76350, std: 0.03788, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 1, 'vect__max_df': 0.05}
# mean: 0.72250, std: 0.04686, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 1, 'vect__max_df': 0.05}
# mean: 0.74300, std: 0.04490, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 1, 'vect__max_df': 0.05}
# mean: 0.73600, std: 0.04460, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 1, 'vect__max_df': 0.05}
# mean: 0.75450, std: 0.03798, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 1, 'vect__max_df': 0.05}
# mean: 0.74250, std: 0.05524, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 2, 'vect__max_df': 0.05}
# mean: 0.74100, std: 0.05458, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 2, 'vect__max_df': 0.05}
# mean: 0.74050, std: 0.04703, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 2, 'vect__max_df': 0.05}
# mean: 0.73850, std: 0.04637, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 2, 'vect__max_df': 0.05}
# mean: 0.76050, std: 0.04089, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 2, 'vect__max_df': 0.05}
# mean: 0.76150, std: 0.04749, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 2, 'vect__max_df': 0.05}
# mean: 0.76600, std: 0.04061, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 2, 'vect__max_df': 0.05}
# mean: 0.77350, std: 0.03925, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 2, 'vect__max_df': 0.05}
# mean: 0.76100, std: 0.04110, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 2, 'vect__max_df': 0.05}
# mean: 0.76150, std: 0.04680, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 2, 'vect__max_df': 0.05}
# mean: 0.76400, std: 0.03865, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 2, 'vect__max_df': 0.05}
# mean: 0.76950, std: 0.04028, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 2, 'vect__max_df': 0.05}
# mean: 0.74600, std: 0.04913, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 3, 'vect__max_df': 0.05}
# mean: 0.73900, std: 0.04939, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 3, 'vect__max_df': 0.05}
# mean: 0.74050, std: 0.04639, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 3, 'vect__max_df': 0.05}
# mean: 0.74350, std: 0.04484, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 3, 'vect__max_df': 0.05}
# mean: 0.75750, std: 0.04474, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 3, 'vect__max_df': 0.05}
# mean: 0.76150, std: 0.04754, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 3, 'vect__max_df': 0.05}
# mean: 0.77150, std: 0.03702, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 3, 'vect__max_df': 0.05}
# mean: 0.76900, std: 0.03942, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 3, 'vect__max_df': 0.05}
# mean: 0.76050, std: 0.04741, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 3, 'vect__max_df': 0.05}
# mean: 0.76250, std: 0.04512, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 3, 'vect__max_df': 0.05}
# mean: 0.77400, std: 0.03980, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 3, 'vect__max_df': 0.05}
# mean: 0.76950, std: 0.03876, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 3, 'vect__max_df': 0.05}
# mean: 0.74550, std: 0.05336, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 4, 'vect__max_df': 0.05}
# mean: 0.74150, std: 0.05477, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 4, 'vect__max_df': 0.05}
# mean: 0.74600, std: 0.05147, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 4, 'vect__max_df': 0.05}
# mean: 0.74200, std: 0.05001, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 4, 'vect__max_df': 0.05}
# mean: 0.76750, std: 0.04633, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 4, 'vect__max_df': 0.05}
# mean: 0.76600, std: 0.04721, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 4, 'vect__max_df': 0.05}
# mean: 0.77300, std: 0.04124, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 4, 'vect__max_df': 0.05}
# mean: 0.76750, std: 0.04094, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 4, 'vect__max_df': 0.05}
# mean: 0.76950, std: 0.04819, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 4, 'vect__max_df': 0.05}
# mean: 0.76450, std: 0.04952, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 4, 'vect__max_df': 0.05}
# mean: 0.77550, std: 0.03971, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 4, 'vect__max_df': 0.05}
# mean: 0.77100, std: 0.04241, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 4, 'vect__max_df': 0.05}
# mean: 0.73900, std: 0.04630, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 5, 'vect__max_df': 0.05}
# mean: 0.73700, std: 0.04920, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 5, 'vect__max_df': 0.05}
# mean: 0.74050, std: 0.04590, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 5, 'vect__max_df': 0.05}
# mean: 0.74100, std: 0.04426, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 5, 'vect__max_df': 0.05}
# mean: 0.75700, std: 0.04445, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 5, 'vect__max_df': 0.05}
# mean: 0.75850, std: 0.04594, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 5, 'vect__max_df': 0.05}
# mean: 0.76800, std: 0.03868, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 5, 'vect__max_df': 0.05}
# mean: 0.76200, std: 0.03868, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 5, 'vect__max_df': 0.05}
# mean: 0.75500, std: 0.04433, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 5, 'vect__max_df': 0.05}
# mean: 0.75750, std: 0.04729, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 5, 'vect__max_df': 0.05}
# mean: 0.77200, std: 0.03451, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 5, 'vect__max_df': 0.05}
# mean: 0.76550, std: 0.03844, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 5, 'vect__max_df': 0.05}
# mean: 0.72950, std: 0.05002, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 1, 'vect__max_df': 0.04}
# mean: 0.73600, std: 0.04636, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 1, 'vect__max_df': 0.04}
# mean: 0.73300, std: 0.04490, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 1, 'vect__max_df': 0.04}
# mean: 0.73700, std: 0.04600, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 1, 'vect__max_df': 0.04}
# mean: 0.73150, std: 0.04313, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 1, 'vect__max_df': 0.04}
# mean: 0.75000, std: 0.04266, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 1, 'vect__max_df': 0.04}
# mean: 0.75250, std: 0.04423, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 1, 'vect__max_df': 0.04}
# mean: 0.76200, std: 0.04045, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 1, 'vect__max_df': 0.04}
# mean: 0.72450, std: 0.04596, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 1, 'vect__max_df': 0.04}
# mean: 0.74250, std: 0.04529, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 1, 'vect__max_df': 0.04}
# mean: 0.73800, std: 0.04496, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 1, 'vect__max_df': 0.04}
# mean: 0.75400, std: 0.03961, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 1, 'vect__max_df': 0.04}
# mean: 0.73850, std: 0.05692, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 2, 'vect__max_df': 0.04}
# mean: 0.73900, std: 0.05522, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 2, 'vect__max_df': 0.04}
# mean: 0.73500, std: 0.04945, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 2, 'vect__max_df': 0.04}
# mean: 0.73850, std: 0.04970, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 2, 'vect__max_df': 0.04}
# mean: 0.76350, std: 0.04231, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 2, 'vect__max_df': 0.04}
# mean: 0.76250, std: 0.04792, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 2, 'vect__max_df': 0.04}
# mean: 0.76550, std: 0.04186, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 2, 'vect__max_df': 0.04}
# mean: 0.77150, std: 0.03944, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 2, 'vect__max_df': 0.04}
# mean: 0.76250, std: 0.04082, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 2, 'vect__max_df': 0.04}
# mean: 0.76050, std: 0.04655, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 2, 'vect__max_df': 0.04}
# mean: 0.76700, std: 0.03689, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 2, 'vect__max_df': 0.04}
# mean: 0.76750, std: 0.04203, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 2, 'vect__max_df': 0.04}
# mean: 0.73950, std: 0.05106, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 3, 'vect__max_df': 0.04}
# mean: 0.73500, std: 0.05362, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 3, 'vect__max_df': 0.04}
# mean: 0.73750, std: 0.04885, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 3, 'vect__max_df': 0.04}
# mean: 0.73900, std: 0.04928, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 3, 'vect__max_df': 0.04}
# mean: 0.76150, std: 0.04539, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 3, 'vect__max_df': 0.04}
# mean: 0.76300, std: 0.05016, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 3, 'vect__max_df': 0.04}
# mean: 0.77400, std: 0.03686, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 3, 'vect__max_df': 0.04}
# mean: 0.77400, std: 0.04005, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 3, 'vect__max_df': 0.04}
# mean: 0.76400, std: 0.04603, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 3, 'vect__max_df': 0.04}
# mean: 0.76450, std: 0.04819, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 3, 'vect__max_df': 0.04}
# mean: 0.77700, std: 0.03906, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 3, 'vect__max_df': 0.04}
# mean: 0.76850, std: 0.04038, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 3, 'vect__max_df': 0.04}
# mean: 0.73650, std: 0.05287, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 4, 'vect__max_df': 0.04}
# mean: 0.73350, std: 0.05505, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 4, 'vect__max_df': 0.04}
# mean: 0.73750, std: 0.05105, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 4, 'vect__max_df': 0.04}
# mean: 0.73800, std: 0.04981, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 4, 'vect__max_df': 0.04}
# mean: 0.77200, std: 0.04691, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 4, 'vect__max_df': 0.04}
# mean: 0.76650, std: 0.04930, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 4, 'vect__max_df': 0.04}
# mean: 0.77400, std: 0.04116, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 4, 'vect__max_df': 0.04}
# mean: 0.77150, std: 0.04301, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 4, 'vect__max_df': 0.04}
# mean: 0.77300, std: 0.04766, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 4, 'vect__max_df': 0.04}
# mean: 0.76150, std: 0.04930, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 4, 'vect__max_df': 0.04}
# mean: 0.77550, std: 0.04114, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 4, 'vect__max_df': 0.04}
# mean: 0.76850, std: 0.04484, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 4, 'vect__max_df': 0.04}
# mean: 0.73200, std: 0.05173, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 5, 'vect__max_df': 0.04}
# mean: 0.73150, std: 0.05455, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 5, 'vect__max_df': 0.04}
# mean: 0.73600, std: 0.04847, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 5, 'vect__max_df': 0.04}
# mean: 0.73400, std: 0.04684, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 5, 'vect__max_df': 0.04}
# mean: 0.76100, std: 0.04306, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 5, 'vect__max_df': 0.04}
# mean: 0.75800, std: 0.04670, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 5, 'vect__max_df': 0.04}
# mean: 0.76800, std: 0.04148, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 5, 'vect__max_df': 0.04}
# mean: 0.76200, std: 0.04173, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 5, 'vect__max_df': 0.04}
# mean: 0.76000, std: 0.04387, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 5, 'vect__max_df': 0.04}
# mean: 0.75650, std: 0.04669, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 5, 'vect__max_df': 0.04}
# mean: 0.77100, std: 0.03904, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 5, 'vect__max_df': 0.04}
# mean: 0.76250, std: 0.04220, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 5, 'vect__max_df': 0.04}
# mean: 0.72250, std: 0.04724, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 1, 'vect__max_df': 0.03}
# mean: 0.72900, std: 0.04335, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 1, 'vect__max_df': 0.03}
# mean: 0.72400, std: 0.04679, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 1, 'vect__max_df': 0.03}
# mean: 0.72650, std: 0.04680, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 1, 'vect__max_df': 0.03}
# mean: 0.72750, std: 0.04617, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 1, 'vect__max_df': 0.03}
# mean: 0.74400, std: 0.04810, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 1, 'vect__max_df': 0.03}
# mean: 0.73850, std: 0.03918, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 1, 'vect__max_df': 0.03}
# mean: 0.75550, std: 0.04257, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 1, 'vect__max_df': 0.03}
# mean: 0.72050, std: 0.04783, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 1, 'vect__max_df': 0.03}
# mean: 0.73550, std: 0.04480, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 1, 'vect__max_df': 0.03}
# mean: 0.72850, std: 0.04728, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 1, 'vect__max_df': 0.03}
# mean: 0.74550, std: 0.03984, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 1, 'vect__max_df': 0.03}
# mean: 0.73250, std: 0.05081, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 2, 'vect__max_df': 0.03}
# mean: 0.73500, std: 0.05301, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 2, 'vect__max_df': 0.03}
# mean: 0.72800, std: 0.04885, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 2, 'vect__max_df': 0.03}
# mean: 0.72750, std: 0.04875, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 2, 'vect__max_df': 0.03}
# mean: 0.75600, std: 0.04592, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 2, 'vect__max_df': 0.03}
# mean: 0.76150, std: 0.04472, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 2, 'vect__max_df': 0.03}
# mean: 0.76050, std: 0.03791, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 2, 'vect__max_df': 0.03}
# mean: 0.76750, std: 0.04179, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 2, 'vect__max_df': 0.03}
# mean: 0.75500, std: 0.04427, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 2, 'vect__max_df': 0.03}
# mean: 0.76200, std: 0.04273, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 2, 'vect__max_df': 0.03}
# mean: 0.76000, std: 0.04123, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 2, 'vect__max_df': 0.03}
# mean: 0.76050, std: 0.04373, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 2, 'vect__max_df': 0.03}
# mean: 0.73900, std: 0.04821, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 3, 'vect__max_df': 0.03}
# mean: 0.73300, std: 0.05478, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 3, 'vect__max_df': 0.03}
# mean: 0.73250, std: 0.04839, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 3, 'vect__max_df': 0.03}
# mean: 0.73050, std: 0.05017, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 3, 'vect__max_df': 0.03}
# mean: 0.76200, std: 0.04750, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 3, 'vect__max_df': 0.03}
# mean: 0.76350, std: 0.04583, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 3, 'vect__max_df': 0.03}
# mean: 0.77300, std: 0.04226, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 3, 'vect__max_df': 0.03}
# mean: 0.76850, std: 0.04313, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 3, 'vect__max_df': 0.03}
# mean: 0.76450, std: 0.04693, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 3, 'vect__max_df': 0.03}
# mean: 0.76450, std: 0.04703, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 3, 'vect__max_df': 0.03}
# mean: 0.77050, std: 0.04180, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 3, 'vect__max_df': 0.03}
# mean: 0.76900, std: 0.04346, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 3, 'vect__max_df': 0.03}
# mean: 0.73150, std: 0.05688, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 4, 'vect__max_df': 0.03}
# mean: 0.72700, std: 0.06108, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 4, 'vect__max_df': 0.03}
# mean: 0.72500, std: 0.05381, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 4, 'vect__max_df': 0.03}
# mean: 0.72500, std: 0.05568, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 4, 'vect__max_df': 0.03}
# mean: 0.76600, std: 0.04504, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 4, 'vect__max_df': 0.03}
# mean: 0.76600, std: 0.04460, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 4, 'vect__max_df': 0.03}
# mean: 0.77200, std: 0.04665, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 4, 'vect__max_df': 0.03}
# mean: 0.76450, std: 0.04441, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 4, 'vect__max_df': 0.03}
# mean: 0.76900, std: 0.04549, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 4, 'vect__max_df': 0.03}
# mean: 0.76250, std: 0.04808, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 4, 'vect__max_df': 0.03}
# mean: 0.77350, std: 0.04696, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 4, 'vect__max_df': 0.03}
# mean: 0.76700, std: 0.04797, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 4, 'vect__max_df': 0.03}
# mean: 0.72100, std: 0.05243, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 5, 'vect__max_df': 0.03}
# mean: 0.72050, std: 0.05443, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 5, 'vect__max_df': 0.03}
# mean: 0.71750, std: 0.04739, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 5, 'vect__max_df': 0.03}
# mean: 0.72050, std: 0.04937, params: {'vect__ngram_range': (1, 1), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 5, 'vect__max_df': 0.03}
# mean: 0.75750, std: 0.04143, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 5, 'vect__max_df': 0.03}
# mean: 0.75650, std: 0.04572, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 5, 'vect__max_df': 0.03}
# mean: 0.76150, std: 0.04136, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 5, 'vect__max_df': 0.03}
# mean: 0.75950, std: 0.04239, params: {'vect__ngram_range': (1, 2), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 5, 'vect__max_df': 0.03}
# mean: 0.75700, std: 0.04167, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': True, 'vect__min_df': 5, 'vect__max_df': 0.03}
# mean: 0.75850, std: 0.04555, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': None, 'vect__use_idf': False, 'vect__min_df': 5, 'vect__max_df': 0.03}
# mean: 0.76750, std: 0.04291, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': True, 'vect__min_df': 5, 'vect__max_df': 0.03}
# mean: 0.75950, std: 0.04580, params: {'vect__ngram_range': (1, 3), 'vect__tokenizer': <function tokenize1 at 0x000000000ABD3CF8>, 'vect__use_idf': False, 'vect__min_df': 5, 'vect__max_df': 0.03}

# %%
# What are the top weighted features?

# Get the learned coefficients for the Positive class.
coef = model.coef_[0]
print coef
# Sort them in descending order.
top_coef_ind = np.argsort(coef)[::-1]
print '..',top_coef_ind
# Get the names of those features.
top_coef_terms = vocab[top_coef_ind]
print top_coef_terms
# Get the weights of those features
top_coef = coef[top_coef_ind]
# Print the top 10.
print 'top weighted terms for positive class:\n', \
    '\n'.join('%s %.2f' % (term, weight) for term, weight in zip(top_coef_terms, top_coef)[:10])
# Out:
# [ 0.35752895 -0.1472319   0.31811443 ...,  0.23925308 -0.07574558
#  -0.07574558]
# .. [5170 1608 1022 ..., 4197 1033  200]
# [u'vaping' u'ecig' u'cig' ..., u's' u'cigarettes' u'THIS_IS_A_URL']
# top weighted terms for positive class:
# vaping 2.88
# ecig 2.29
# cig 2.15
# vape 2.02
# m 1.79
# need 1.57
# got 1.56
# green 1.52
# good 1.33
# love 1.25

# %%
import numpy as np

vocabWords = []
coefValues = []
test = []

for x in range(0,1999):#for each tweet in X
    for i in X[x].indices:#for each word in that tweet
        coefValues.append(model.coef_[0][i])#get the model coeficient from logistic regression for each term 
    #for each coeficient, and tfidf value for that tweet make a dot product and keeps in a vector
    test.append([(p*q,value,term) for p,q,value,term in zip(coefValues, X[x].data,X[x].indices,vocab[X[x].indices])])
    
for t in range(len(test)):#print final result of dot product 
    print 'tweet #', t, tweets[t]['text'], '\n', test[t], '\n'


#for t in range(len(test)):
#    print test[t].data, test[t].indices
#    for i in test[t].indices:
#        vocabWords.append(vocab[i])
#    print '\n'.join('%s %.4f' % (term, weight) for term, weight in zip(vocabWords, test[t].data))
#    break
#for x in range(0,1999):
#    print 'tweet #',x,'\n', X[x], '\n'"""
# Out:
# tweet # 0 Vaping kush&gt;Smoking kush
# [(-0.0093223357976018641, 4462, u'smoking'), (0.070775870236291907, 2223, u'gt'), (0.33385682048028614, 2776, u'kush'), (0.58138419722705315, 5170, u'vaping')]
#
# tweet # 1 @LindaMcAvanMEP anything that attracts people away from tobacco cigarettes is a good thing, inc. ecig flavours. #EUecigBAN
# [(-0.014421528442987774, 1786, u'euecigban'), (0.081438507998999141, 1969, u'flavours'), (0.070726749440861866, 1608, u'ecig'), (0.9201089974978599, 4843, u'thing'), (0.20327316607467752, 2162, u'good'), (0.015988679940467362, 1033, u'cigarettes'), (0.66146245498319767, 4901, u'tobacco'), (0.016023035264097409, 495, u'away'), (0.3653014331933368, 3666, u'people'), (-0.95962252385348634, 465, u'attracts'), (-0.015038736974491122, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 2 I bought a Ecig today
# [(-0.031340308248520299, 4905, u'today'), (0.14287244730439061, 725, u'bought'), (0.14305307322975286, 1608, u'ecig')]
#
# tweet # 3 Oh no I'm secondhand ecig high from a man in tennis shoes
# [(-0.020977391757872364, 4365, u'shoes'), (0.090961584637166332, 4804, u'tennis'), (0.12194834637849916, 3043, u'man'), (1.0345063277015836, 2356, u'high'), (0.32359039494276043, 4282, u'secondhand'), (0.023821275439540379, 3004, u'm'), (0.81002509404985434, 3503, u'oh'), (0.0076863196165582693, 1608, u'ecig')]
#
# tweet # 4 testing le syafiq ikmal's electric cigarette T.T rasa mcm ubat antibiotic tho.
# [(-0.013848431587777706, 4853, u'tho'), (0.067693930992334353, 381, u'antibiotic'), (0.12037358723398632, 5040, u'ubat'), (0.88566499112170316, 3101, u'mcm'), (0.22847014606513016, 3989, u'rasa'), (0.030266129195898901, 4734, u't'), (0.24063296085758709, 1029, u'cigarette'), (0.007088842171478856, 1673, u'electric'), (0.18489126611824355, 4197, u's'), (-0.65783635281571251, 2460, u'ikmal'), (-0.046666440640083059, 4730, u'syafiq'), (0.021982891404266749, 2825, u'le'), (-0.32243302141909153, 4814, u'testing')]
#
# tweet # 5 RT @Vapor4Life: Read this blog post for tips on troubleshooting ecigs! http://t.co/N3ezGFb08w
# [(-0.0064647369816619102, 200, u'THIS_IS_A_URL'), (0.045764516562845879, 1623, u'ecigs'), (0.17922714660280581, 4985, u'troubleshooting'), (1.2681251237165247, 4891, u'tips'), (0.29570416189592313, 3782, u'post'), (0.040309887570471735, 658, u'blog'), (0.91406605971190558, 3999, u'read'), (0.0061760777865988549, 4180, u'rt'), (0.14179100081045479, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 6 An electric cigarette commercial! Thinking of you @Christian_Abbey �??
# [(-0.034008514366269844, 4849, u'thinking'), (0.12029034101143252, 1138, u'commercial'), (0.088146129374700052, 1029, u'cigarette'), (1.0555695514841601, 1673, u'electric'), (0.12051354875951641, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 7 This kid was hitting an e-cig during class. I look over and smokes coming out his nose.
# [(-0.021431606334399979, 3439, u'nose'), (0.082239857002013347, 1132, u'coming'), (0.12933769379019117, 4460, u'smokes'), (0.94308165970012348, 2958, u'look'), (0.23180090104293768, 1061, u'class'), (0.016403518799860566, 1022, u'cig'), (0.27418432963951761, 1584, u'e'), (0.017606572956480715, 2372, u'hitting'), (0.49114424536828, 2711, u'kid')]
#
# tweet # 8 My new baby. Stop smoking, start vaping :) http://t.co/HjdE74lk
# [(-0.02306279926712337, 4561, u'start'), (0.084928548349779934, 4603, u'stop'), (0.21714880273207962, 509, u'baby'), (0.92811982274729055, 3365, u'new'), (0.12564019476378907, 200, u'THIS_IS_A_URL'), (0.026517352771175194, 4462, u'smoking'), (0.66101051911315534, 5170, u'vaping')]
#
# tweet # 9 @MajorXIII ask me for anything ecig related thats what I know
# [(-0.019016411642956324, 2747, u'know'), (0.11248626292059134, 4830, u'thats'), (0.19383729137935007, 4062, u'related'), (1.3542326642565938, 440, u'ask'), (0.17666269997412204, 1608, u'ecig'), (0.013208490980300169, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 10 @DhesiBahaRaja wahh bestnya tgk Dr bring up psl e-cig lagi. Thanks Dr! We owe you a lot.
# [(-0.01080356312182097, 2972, u'lot'), (0.061543451754926877, 3579, u'owe'), (0.083534228935391724, 4825, u'thanks'), (0.80519597330370163, 2788, u'lagi'), (0.2189371473568241, 3890, u'psl'), (0.024168867998861383, 763, u'bring'), (1.2841380588827449, 1534, u'dr'), (0.012911370409707971, 4819, u'tgk'), (0.39190795057577948, 602, u'bestnya'), (-0.59806720113115353, 5292, u'wahh'), (-0.014391207141673596, 1022, u'cig'), (0.0064609290741410403, 1584, u'e'), (-0.064758346592115379, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 11 DALLAS E CIG Evic Venders: ... http://t.co/WZtLbSS9 RETAIL STORES
# [(-0.019149917902521456, 4611, u'stores'), (0.063027520860545527, 4103, u'retail'), (0.20880746913997877, 5205, u'venders'), (1.4774212648873617, 1802, u'evic'), (0.24267163718122781, 1325, u'dallas'), (0.01931597993697547, 1022, u'cig'), (0.32286603106127504, 1584, u'e'), (0.0065002826052977247, 200, u'THIS_IS_A_URL')]
#
# tweet # 12 @Kelbyjohnson14 Try the new E-cigarette. . Worth a try anyway.
# [(-0.025931573071931689, 5431, u'worth'), (0.16037334448720683, 4993, u'try'), (0.10454648494466187, 3365, u'new'), (0.40317446390368367, 1584, u'e'), (0.13446231518530574, 1029, u'cigarette'), (0.012526542824345111, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 13 In me beveiligingspakkie met Sport &amp; Bewegen tas bij me, jatok van alle markten thuis.
# [(-0.013622765175005646, 4869, u'thuis'), (0.048168516207066643, 3067, u'markten'), (0.097854450517498706, 321, u'alle'), (0.72479640887442587, 5128, u'van'), (0.24174305911628169, 2616, u'jatok'), (0.032954001970891995, 618, u'bij'), (0.74726417136764811, 4765, u'tas'), (0.01425630240417471, 608, u'bewegen'), (0.23897395454570591, 355, u'amp'), (-0.66036575567015676, 4533, u'sport'), (-0.038633927707181652, 3162, u'met'), (0.028531820858590982, 607, u'beveiligingspakkie')]
#
# tweet # 14 RT @TowerOfVape: Morning #vaping shows @TVN Live 8:30A Kisses &amp; Kerosene @Case1320 &amp; @Myzy36 11A  Out To Lunch w/Diana #vape #va ...
# [(-0.011888899890250847, 5122, u'va'), (0.034032611623622394, 5134, u'vape'), (0.10334091041171074, 1430, u'diana'), (0.619855470502364, 5286, u'w'), (0.20674185994092725, 2995, u'lunch'), (0.028182698129430313, 31, u'11a'), (0.63907019800494547, 2701, u'kerosene'), (0.012192178280914637, 2726, u'kisses'), (0.37007780363384823, 98, u'30a'), (-0.49931830360235568, 175, u'8'), (-0.033040245706347587, 2924, u'live'), (0.021011040349332714, 4378, u'shows'), (-0.23835499408566219, 3259, u'morning'), (-0.060231760262172612, 355, u'amp'), (-0.076689337267441551, 4180, u'rt'), (0.15126994452397641, 199, u'THIS_IS_A_MENTION'), (0.10602428393718799, 5170, u'vaping')]
#
# tweet # 15 Arr�te de vaper esp�ce de.... De mec accro � la vap' http://t.co/2LSm7w5q
# [(-0.018822303592590097, 5133, u'vap'), (0.054971539963885818, 2778, u'la'), (0.15573432874250365, 227, u'accro'), (1.2077596322288093, 3111, u'mec'), (0.31155913618918946, 1770, u'espce'), (0.027751554831762667, 5160, u'vaper'), (0.96307617098717502, 429, u'arrte'), (0.0048480887793050376, 200, u'THIS_IS_A_URL')]
#
# tweet # 16 Merci � @dressinghomme qui parle d'AlterSmoke: nombreuses saveurs, plein de qualit�s par rapport au #tabac http://t.co/RBrnJK12 #ecig
# [(-0.014781324662800988, 4737, u'tabac'), (0.051175431135626247, 466, u'au'), (0.10812932055586812, 3988, u'rapport'), (0.76507108775868526, 3609, u'par'), (0.21632146220511358, 3935, u'qualits'), (0.029488573189704569, 3733, u'plein'), (0.66868219006853347, 4245, u'saveurs'), (0.01275711572850549, 3425, u'nombreuses'), (0.38722574922468744, 338, u'altersmoke'), (-0.38857059106482872, 1308, u'd'), (-0.041919582485851516, 3620, u'parle'), (0.021055841148760895, 3950, u'qui'), (-0.26424936084058431, 3151, u'merci'), (-0.015056083003118696, 200, u'THIS_IS_A_URL'), (-0.11065630446162852, 1608, u'ecig'), (0.039569799261338474, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 17 my mom tries to convince my dad to switch to e-cigs like daily
# [(-0.017446120496534274, 1321, u'daily'), (0.045988595804431077, 2895, u'like'), (0.070773622261821115, 1045, u'cigs'), (1.0769676158360415, 4723, u'switch'), (0.30117941294926409, 1313, u'dad'), (0.042693267168232372, 1202, u'convince'), (1.0204301153216728, 4978, u'tries'), (0.014058850691406588, 3241, u'mom'), (0.14775009986601462, 1584, u'e')]
#
# tweet # 18 RT @jaymer: @RepJimLyons?�Stop #H3639 by @jeffrey_sanchez , Millions have quit smoking with the #Ecig. #H3639 promotes #cigarettes and #canc�??
# [(-0.019876107817135794, 868, u'canc'), (0.068814426991103447, 3858, u'promotes'), (0.082865530256921519, 3956, u'quit'), (0.83110732772009355, 3189, u'millions'), (0.5009463954308998, 2246, u'h3639'), (0.011581683505810023, 4180, u'rt'), (0.3621659995701253, 1608, u'ecig'), (0.0057274201072342349, 1033, u'cigarettes'), (0.34508620130910012, 199, u'THIS_IS_A_MENTION'), (-0.32461809985974044, 4462, u'smoking')]
#
# tweet # 19 RT @DrStrangeLOL: On a le droit de dire d'une musulmane voil??e qui fume la cigarette ??lectronique qu'elle est ?� voile et ?� vapeur ?
# [(-0.013141080589735203, 5168, u'vapeur'), (0.042960965865821883, 1777, u'et'), (0.10132557480989335, 5257, u'voile'), (0.5998136979080716, 1775, u'est'), (0.18494277659430589, 1705, u'elle'), (0.026216305074296439, 3932, u'qu'), (0.53955909922344902, 2839, u'lectronique'), (0.011341492708211835, 2048, u'fume'), (0.3628606137510198, 5256, u'voil'), (-0.55373980381865939, 3296, u'musulmane'), (-0.029616175837757726, 5070, u'une'), (0.023924930614840637, 1449, u'dire'), (-0.27141096301694201, 1551, u'droit'), (-0.035160108157140123, 1308, u'd'), (-0.21231434727713303, 3950, u'qui'), (0.10535383362341841, 2778, u'la'), (0.05787824757917049, 1584, u'e'), (0.18301863147697359, 4180, u'rt'), (-0.02353077904838646, 1029, u'cigarette'), (-0.042610675999153698, 2825, u'le'), (-0.014665766826369744, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 20 #vapor #smoking  #vaping - Vapor Joes - Daily Vaping Deals: Boge ViVi Nova - $6.99 Free Shipping http://t.co/E41xVkHw  - #ecig #VapeDeal
# [(-0.014713943652455132, 5144, u'vapedeal'), (0.05493881402533015, 4356, u'shipping'), (0.072807486342957778, 2015, u'free'), (0.70079593668824991, 196, u'99'), (0.17804501955730787, 151, u'6'), (0.029354148846791616, 3459, u'nova'), (0.6656339868394624, 5248, u'vivi'), (0.012698962121403617, 685, u'boge'), (0.34984969802262289, 1354, u'deals'), (-0.52179901768125891, 2643, u'joes'), (-0.052616203472611846, 5173, u'vapor'), (0.020719090979452345, 1321, u'daily'), (-0.080186744783633551, 200, u'THIS_IS_A_URL'), (-0.024114505286135433, 1608, u'ecig'), (-0.11776180269432629, 4462, u'smoking'), (0.16880299316215083, 5170, u'vaping')]
#
# tweet # 21 I left my e cig in my room .. greeat ..
# [(-0.031973936981800663, 2207, u'greeat'), (0.098022659687211189, 4172, u'room'), (0.2067972548224257, 2843, u'left'), (0.61529419486164738, 1022, u'cig'), (0.11699907056895359, 1584, u'e')]
#
# tweet # 22 @NewYorkEDM do you know if e-cigarettes are allowed in? Or do i need to sneak it
# [(-0.031232479432032674, 4468, u'sneak'), (0.082454443193497692, 3349, u'need'), (0.17670896419259319, 326, u'allowed'), (1.1242751905121198, 2747, u'know'), (0.11428592816679754, 1584, u'e'), (0.020803452850581952, 1033, u'cigarettes'), (0.31213105863578661, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 23 In a rather... quaint theater in Connecticut, there's a dude smoking an electric cigarette in the theater. This place is amazing.
# [(-0.014712295448694563, 341, u'amazing'), (0.057967281661393914, 3716, u'place'), (0.10307762503222058, 1570, u'dude'), (0.96931079070101367, 1170, u'connecticut'), (0.50009558953772804, 4833, u'theater'), (0.03408608938661091, 3933, u'quaint'), (0.2498565878428059, 1029, u'cigarette'), (0.0073605623702154947, 1673, u'electric'), (0.19197827558453517, 4197, u's'), (-0.27904751697503272, 4462, u'smoking')]
#
# tweet # 24 Nuovo Argomento Small battery &amp; Ego ? Chi mi consiglia un buon PCC tipo emini ma pi� economico?: Con l'arrivo ... http://t.co/hRjfXKoJGO
# [(-0.013035572903543104, 428, u'arrivo'), (0.041476373116165387, 2777, u'l'), (0.095358682206869425, 1629, u'economico'), (0.7395310197947369, 3694, u'pi'), (0.16055205966992625, 3005, u'ma'), (0.02600581845030786, 1716, u'emini'), (0.5897073257497526, 4890, u'tipo'), (0.011250433632404726, 3650, u'pcc'), (0.34149236278198336, 813, u'buon'), (-0.52113099853327483, 1177, u'consiglia'), (-0.033728410645944576, 3166, u'mi'), (0.021361609519087586, 991, u'chi'), (-0.17384974381779172, 1656, u'ego'), (-0.034509480337123609, 557, u'battery'), (-0.21421088407985092, 4437, u'small'), (0.15796340665166603, 412, u'argomento'), (0.21784946337767111, 3469, u'nuovo'), (0.32566303116168061, 355, u'amp'), (-0.018076195447135252, 200, u'THIS_IS_A_URL')]
#
# tweet # 25 No cigarettes &amp; my ecig is empty..the struggle is real.
# [(-0.02520672433545566, 4002, u'real'), (0.13900221421043649, 4635, u'struggle'), (0.14961425120535574, 355, u'amp'), (0.84626642707441846, 1608, u'ecig'), (0.18096130436546048, 1033, u'cigarettes')]
#
# tweet # 26 E-cigs are for pussies hahahahahaha sorry not sorry
# [(-0.036926900969637584, 4500, u'sorry'), (0.095363719301696057, 2256, u'hahahahahaha'), (0.16957610255519076, 3923, u'pussies'), (0.56405992159579377, 1045, u'cigs'), (0.084824406296236193, 1584, u'e')]
#
# tweet # 27 RT @VictorineDeliat: il me faut cette putain de cigarette electronique!!!!!!!!!!!
# [(-0.017575074785729929, 1694, u'electronique'), (0.10199971811712076, 3925, u'putain'), (0.17207689493775932, 949, u'cette'), (1.2833312104770498, 1890, u'faut'), (0.30537682881621458, 2461, u'il'), (0.014447432403755111, 4180, u'rt'), (0.36258042364154408, 1029, u'cigarette'), (0.0047273045732799121, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 28 RT @VapeBans: @SimonCowell Just 1 #RT for your fellow #Vapers is all it takes. Show your 6.6mil followers that u care about the #EUEcigBan!
# [(-0.016485866936480263, 892, u'care'), (0.051791270421742953, 5038, u'u'), (0.13287410917730294, 1986, u'followers'), (1.086161487941659, 161, u'6mil'), (0.2197915486669787, 4748, u'takes'), (0.025624744031695769, 5163, u'vapers'), (0.74579280678455051, 1911, u'fellow'), (0.010212750216438521, 16, u'1'), (0.24458414881459598, 2668, u'just'), (-0.60040115590482268, 151, u'6'), (-0.031717698085023768, 4180, u'rt'), (0.019868153122019963, 1786, u'euecigban'), (-0.16575272368802679, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 29 E-Cigs in Hotels http://t.co/TfsRuQeNC5
# [(-0.043164919259837495, 2409, u'hotels'), (0.083479888294136037, 1045, u'cigs'), (0.086536421609131886, 1584, u'e'), (0.70822659529679655, 200, u'THIS_IS_A_URL')]
#
# tweet # 30 @anne_DK87 what is an electronic cigarette?
# [(-0.034104059663977865, 1682, u'electronic'), (0.12743273790213303, 1029, u'cigarette'), (0.15485990044423947, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 31 @AnisFairy1 aku sihat semenjak isap rokok electric cigarette..haha
# [(-0.016640831036464288, 2251, u'haha'), (0.073167847091217611, 4161, u'rokok'), (0.14442485737048302, 2578, u'isap'), (1.2668335753627222, 4306, u'semenjak'), (0.32679811769093614, 4397, u'sihat'), (0.039386939223220757, 308, u'aku'), (0.32654822121181293, 1029, u'cigarette'), (0.009619832600230081, 1673, u'electric'), (0.12923147103293733, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 32 I like when Micah walks all over the house while tweeting and looking for his ecig charger..????
# [(-0.017182922070035717, 967, u'charger'), (0.074408158970911284, 2960, u'looking'), (0.16002489118330276, 5026, u'tweeting'), (1.0261200708174834, 2413, u'house'), (0.29056628347754965, 5303, u'walks'), (0.045999774812075775, 3168, u'micah'), (0.51694737583251416, 2895, u'like'), (0.0080153847386543343, 1608, u'ecig')]
#
# tweet # 33 spent two hours today talking to a guy smoking an e-cig, so ya that was weird
# [(-0.020935276681775, 5351, u'weird'), (0.075187133392326758, 5460, u'ya'), (0.11424893639341926, 2239, u'guy'), (1.0955755223816253, 4753, u'talking'), (0.28916548881817183, 2412, u'hours'), (0.039418546796184652, 4519, u'spent'), (0.35211406570543913, 1022, u'cig'), (0.0049517159730971521, 1584, u'e'), (0.38803735651977483, 4905, u'today'), (-0.3747640561199172, 4462, u'smoking')]
#
# tweet # 34 The electronic cigarette free startrer package trial get began while using the electronic cigarette http://t.co/G2lcktEvho
# [(-0.014430952179714822, 5112, u'using'), (0.089697792362701256, 578, u'began'), (0.14102034076067646, 4973, u'trial'), (1.0936488844120333, 3586, u'package'), (0.3190945295414373, 4566, u'startrer'), (0.030961703584240965, 1682, u'electronic'), (0.63299234300514662, 2015, u'free'), (0.004965345029291874, 200, u'THIS_IS_A_URL'), (0.36928494529606309, 1029, u'cigarette')]
#
# tweet # 35 Ouh hell yes! #ejuice #watermelon #irishcream #earlgrey #vape #vapejuice #vapejuice #vapeon #livehealthy http://t.co/u5M7l2P24R
# [(-0.014612390949203764, 2925, u'livehealthy'), (0.054844375282181002, 5156, u'vapeon'), (0.21378705103615689, 5148, u'vapejuice'), (0.82898668591442237, 1587, u'earlgrey'), (0.21384915415595349, 2573, u'irishcream'), (0.026596460766086162, 5326, u'watermelon'), (0.50457860531661125, 1665, u'ejuice'), (0.0097539926256586962, 5476, u'yes'), (0.33844701836380459, 2331, u'hell'), (-0.58416840921869839, 3570, u'ouh'), (-0.024267740289407511, 5134, u'vape'), (0.0066597848542503486, 200, u'THIS_IS_A_URL')]
#
# tweet # 36 @officialKeef @jimmyfallon Electric cigarette so he doesn,t smoke
# [(-0.017702283038971502, 4452, u'smoke'), (0.126937276478015, 1496, u'doesn'), (0.13962858075479956, 4734, u't'), (0.7593337626405201, 1029, u'cigarette'), (0.30246849473744969, 1673, u'electric'), (0.036496677524525192, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 37 RT @RedNick_Gjerde: If you have an e cig and you haven't tried Texas Watermelon, you're missing the fuck out!
# [(-0.016167161737474837, 2037, u'fuck'), (0.08150340592279838, 3212, u'missing'), (0.15968189733509669, 4817, u'texas'), (0.99634757270474372, 4977, u'tried'), (0.29770644467968288, 2299, u'haven'), (0.041878007556794564, 5326, u'watermelon'), (0.35306143042735388, 1022, u'cig'), (0.0049650385906314888, 1584, u'e'), (0.17604928425782207, 4180, u'rt'), (-0.42401930262060006, 4734, u't'), (-0.014414884295925941, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 38 I'm gonna blow ecig vapour in the face of the law! #EUecigBan
# [(-0.022915334494388095, 2820, u'law'), (0.081946468137499909, 1849, u'face'), (0.1487009363575868, 5188, u'vapour'), (1.211515262486387, 663, u'blow'), (0.25527256754630617, 2160, u'gonna'), (0.026021943103349127, 3004, u'm'), (0.65647489554981131, 1786, u'euecigban'), (0.0083964006143952604, 1608, u'ecig')]
#
# tweet # 39 @MikeeeDeeeLeon Nice I tried to smoke electronic cigarette last Saturday, it was my first time.
# [(-0.019613004107289427, 4884, u'time'), (0.10972457951991668, 4240, u'saturday'), (0.17636838698480609, 3388, u'nice'), (1.2659616091871517, 4977, u'tried'), (0.18291521843991329, 4452, u'smoke'), (0.020756535290310733, 1682, u'electronic'), (0.42751085273441775, 1029, u'cigarette'), (0.0055738641070599898, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 40 RT @ECigologist: https://t.co/SQbevRe6VU @Hifistud @smoke2vape @eCigsForYou @SWOFcampaign ... This is brilliant.
# [(-0.031891424587796965, 762, u'brilliant'), (0.036488636571845888, 200, u'THIS_IS_A_URL'), (0.071822722326747857, 4180, u'rt'), (2.1064550617053763, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 41 Kit 36E-cigarette electronique rechargeable  2 chargeurs USB   prise murale et allume-cigare    un cable USB  1 boi http://t.co/YiF2a9zf
# [(-0.013171824203752156, 687, u'boi'), (0.054186933569220497, 848, u'cable'), (0.096355396699822501, 1026, u'cigare'), (0.74726079613349461, 327, u'allume'), (0.19276677406559548, 3292, u'murale'), (0.026277638231691762, 3829, u'prise'), (1.0403955704773431, 5103, u'usb'), (0.011016444228412055, 968, u'chargeurs'), (0.23260747356803776, 57, u'2'), (-0.47599025250017701, 4019, u'rechargeable'), (-0.037355066869473173, 114, u'36e'), (0.017676340237567069, 2728, u'kit'), (-0.17484677866916612, 16, u'1'), (-0.03950500128224186, 1694, u'electronique'), (-0.2023080050965344, 1777, u'et'), (0.046162287360948705, 200, u'THIS_IS_A_URL'), (0.077993384264807217, 1029, u'cigarette')]
#
# tweet # 42 E-cigarette explodes, burns child: A mother's e-cigarette exploded in a car charger, burning her young boy. KS... http://t.co/MfOdepePa1
# [(-0.016128365033701863, 2768, u'ks'), (0.057132424737519706, 736, u'boy'), (0.099293305110285862, 5489, u'young'), (0.91499056690890868, 819, u'burning'), (0.1851540456453635, 883, u'car'), (0.032175903281760745, 1831, u'exploded'), (0.66566987902225061, 3264, u'mother'), (0.013206009458289281, 996, u'child'), (0.35558278056931092, 821, u'burns'), (-0.61171516765502287, 1832, u'explodes'), (-0.034085969806607878, 967, u'charger'), (0.013930994220809944, 1584, u'e'), (-0.083388461192216518, 200, u'THIS_IS_A_URL'), (-0.040252181864736176, 1029, u'cigarette'), (-0.12857237226443896, 4197, u's')]
#
# tweet # 43 @iNURSELISA  Less than one.  Mostly smoked when fishing or golfing.  E cig did the trick cause I can still smoke something
# [(-0.018153970875535989, 919, u'cause'), (0.088957807301051406, 4975, u'trick'), (0.11818715464806161, 1433, u'did'), (1.293062664750668, 2157, u'golfing'), (0.33356429219674977, 1951, u'fishing'), (0.032231503370277664, 4453, u'smoked'), (0.44082901510313799, 4452, u'smoke'), (0.0066725658675454175, 1022, u'cig'), (0.14929463997247125, 1584, u'e'), (-0.20129556512158747, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 44 always roll with 18 mg in my ecig
# [(-0.03010991858920762, 3164, u'mg'), (0.10987923188312672, 46, u'18'), (0.20526557277590993, 4163, u'roll'), (0.72520980170372096, 1608, u'ecig')]
#
# tweet # 45 Nur noch Heute, 30 % auf alle Easy e-Liquids und 20 % auf alles f?�r Stammkunden.... http://t.co/hR6k2zAYRb
# [(-0.013178030697227958, 4551, u'stammkunden'), (0.041380936299987806, 3969, u'r'), (0.079502016343592136, 1846, u'f'), (0.74761290144435988, 324, u'alles'), (0.15905022185739948, 58, u'20'), (0.026290020114999771, 5064, u'und'), (0.52707868246139389, 2913, u'liquids'), (0.0095717017752509903, 1592, u'easy'), (0.69044864739112721, 469, u'auf'), (-0.40213182795908109, 97, u'30'), (-0.037372668378210856, 2348, u'heute'), (0.022762095631131116, 3418, u'noch'), (-0.2582194446029818, 3470, u'nur'), (-0.041195964604597624, 321, u'alle'), (-0.061241163383717635, 1584, u'e'), (0.042136074266106417, 200, u'THIS_IS_A_URL')]
#
# tweet # 46 RT @Johnedwarddiver: Smoked for 34 years. Voted #labour for 32. Quit the former with #ecigs. Now quitting the latter thanks to @LindaMcAvan?
# [(-0.016044756948958766, 3964, u'quitting'), (0.080035798331095379, 104, u'32'), (0.13502303648393998, 2781, u'labour'), (1.0471382527091684, 5269, u'voted'), (0.21733167871409217, 5471, u'years'), (0.03541100047395903, 109, u'34'), (0.62386251470822174, 4453, u'smoked'), (0.0095694554104143008, 3956, u'quit'), (0.38903408502540177, 4825, u'thanks'), (-0.35314980715613664, 1623, u'ecigs'), (-0.01611532875831426, 4180, u'rt'), (0.014847436585473803, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 47 Ecig rollercoaster
# [(-0.047031123903637423, 4166, u'rollercoaster'), (0.077929867611506637, 1608, u'ecig')]
#
# tweet # 48 I love my #greensmoke e-cigarette so awesomeeee :) http://t.co/Gz6YXyg4SW
# [(-0.03093286426233853, 497, u'awesomeeee'), (0.12725322134284017, 2210, u'greensmoke'), (0.15181030704226353, 2975, u'love'), (0.43877962400722903, 1584, u'e'), (0.11944929123144926, 200, u'THIS_IS_A_URL'), (0.019948404640279038, 1029, u'cigarette')]
#
# tweet # 49 RT @mrpennybags: @WarmCigarette I am using this e-cig to cut my nicotine content slowly http://t.co/8AhgvUwk I should be completely off  ...
# [(-0.021815697026914587, 1150, u'completely'), (0.09459662070656473, 4435, u'slowly'), (0.15346850150439115, 1190, u'content'), (0.80628520154340855, 3395, u'nicotine'), (0.29753068594576182, 1300, u'cut'), (0.030361921916384982, 5112, u'using'), (0.35285299143949439, 1022, u'cig'), (0.0049621073511096243, 1584, u'e'), (0.15894798740685848, 200, u'THIS_IS_A_URL'), (-0.26849963688513356, 4180, u'rt'), (-0.028812748188976851, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 50 almost 12 hours without a real cig feeling better thank i was with the cigs.... This e-cig is really helping...... http://t.co/3Q1PZY2aSv
# [(-0.017751148870924733, 2338, u'helping'), (0.057057849377053452, 4004, u'really'), (0.12103575603035291, 4823, u'thank'), (0.83378201765190507, 605, u'better'), (0.29285681556483456, 1909, u'feeling'), (0.034076114574448084, 33, u'12'), (0.82163139250081252, 2412, u'hours'), (0.012390008521483904, 4002, u'real'), (0.23699668579764274, 1045, u'cigs'), (-0.57205023976847946, 1022, u'cig'), (-0.014956521416276061, 1584, u'e'), (0.0096131535162929972, 200, u'THIS_IS_A_URL')]
#
# tweet # 51 RT @msparker32: Hey @evercig  . Are you showing your support in the vaper's fight against the #EUecigBAN ?#ecigs #PV #vapebash#vapecommunity
# [(-0.01591213745164213, 5142, u'vapecommunity'), (0.077781742124694658, 5138, u'vapebash'), (0.13122036918080832, 3929, u'pv'), (0.94836130590956946, 1923, u'fight'), (0.23287066070678589, 4687, u'support'), (0.037719803390839281, 4377, u'showing'), (0.68126135103313046, 2349, u'hey'), (0.010662543979069065, 5160, u'vaper'), (0.22489844185922989, 1623, u'ecigs'), (-0.22077289189384647, 4180, u'rt'), (-0.022998369537790466, 4197, u's'), (0.019620875757920979, 1786, u'euecigban'), (-0.16368977921834801, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 52 If e-cigarettes &amp; spray tanning are the escape hatches for cigarettes &amp; tanning beds, then @v2cigs and @LiveSunless are the brands to watch.
# [(-0.012436979576158292, 5320, u'watch'), (0.058858363152001131, 744, u'brands'), (0.11031829179050218, 575, u'beds'), (0.85554662608337007, 2294, u'hatches'), (0.20938510530585444, 1765, u'escape'), (0.060171080423030793, 4757, u'tanning'), (0.64724086716320073, 4535, u'spray'), (0.014375351851239698, 355, u'amp'), (0.098779841845799618, 1584, u'e'), (-0.40258051141783541, 1033, u'cigarettes'), (-0.018896228029724411, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 53 http://t.co/OstcS9tGUc how d'ya like them apples #eu_ecig_ban
# [(-0.027570456134604876, 1782, u'eu_ecig_ban'), (0.11342077239486462, 395, u'apples'), (0.16063952221467923, 5460, u'ya'), (0.77516625165113662, 2895, u'like'), (0.26532000238956649, 1308, u'd'), (0.014513145270154551, 200, u'THIS_IS_A_URL')]
#
# tweet # 54 RT @Johnedwarddiver: .@UKLabour Ed's evidence-based approach on Syria is commendable. How about doing the same with policy on ecigs? No nee�??
# [(-0.0172620471293186, 3348, u'nee'), (0.064789273308529433, 3751, u'policy'), (0.1005774801027156, 1499, u'doing'), (0.97930634976695274, 1136, u'commendable'), (0.25262629438518674, 4731, u'syria'), (0.034437586061422859, 398, u'approach'), (0.65720098075269484, 548, u'based'), (0.013171946980372889, 1803, u'evidence'), (0.4522131328069765, 1637, u'ed'), (-0.31333985593645236, 1623, u'ecigs'), (-0.014298676338413547, 4180, u'rt'), (0.012788466362242066, 4197, u's'), (-0.14944618880426619, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 55 The Ambiguous Allure of the E-Cig http://t.co/rcALaukfll via @roomfordebate
# [(-0.033461530189174027, 328, u'allure'), (0.13765577838252147, 343, u'ambiguous'), (0.083030250036442724, 1022, u'cig'), (0.47464850039730339, 1584, u'e'), (0.12921390113501274, 200, u'THIS_IS_A_URL'), (0.01474722557864778, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 56 @v2cigs Perhaps you should reword that to include the fact that it's the last sale of the YEAR, not ever.
# [(-0.020360533988203634, 5470, u'year'), (0.087454863279592066, 4210, u'sale'), (0.15967624384733503, 1852, u'fact'), (1.2383301941320886, 2488, u'include'), (0.36130827393105486, 4120, u'reword'), (0.021124989196135889, 4197, u's'), (0.24673012340023517, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 57 Electric cigarettes are better than regular cigarettes!!
# [(-0.030654293395468372, 4051, u'regular'), (0.10654712581872791, 605, u'better'), (0.13572473422921638, 1673, u'electric'), (1.408116618386831, 1033, u'cigarettes')]
#
# tweet # 58 Kristen Stewart starred with Blu Cigarette swindler Stephen Dorff in Cold Creek Manor in '03 b4 she was the most recognized YA on the planet
# [(-0.013245769604794552, 3722, u'planet'), (0.054491133995224685, 4024, u'recognized'), (0.10213278960130524, 506, u'b4'), (0.666593160726768, 7, u'03'), (0.20432491642473904, 3049, u'manor'), (0.027853224506952122, 1262, u'creek'), (0.57624031330404335, 1112, u'cold'), (0.012049643981123161, 1515, u'dorff'), (0.34699887704802113, 4582, u'stephen'), (-0.55815119710287797, 4721, u'swindler'), (-0.025872080151402896, 666, u'blu'), (0.024115529660659395, 4560, u'starred'), (-0.27357317077455579, 4586, u'stewart'), (-0.047651334695233923, 2767, u'kristen'), (-0.20668372724357814, 5460, u'ya'), (0.054690144925548745, 1029, u'cigarette')]
#
# tweet # 59 A homeless guy just asked me if he could bum an e-cigarette
# [(-0.0253507455829169, 808, u'bum'), (0.10029041469286201, 441, u'asked'), (0.19546937944014081, 2386, u'homeless'), (1.0317640536801016, 2239, u'guy'), (0.19069713899713539, 2668, u'just'), (0.013328738980108036, 1584, u'e'), (0.39075329241659401, 1029, u'cigarette')]
#
# tweet # 60 I've got my green smoke right here! #bowlsforgoals #rctid
# [(-0.02613688915227845, 3997, u'rctid'), (0.10752329019067443, 732, u'bowlsforgoals'), (0.1265452640617781, 4133, u'right'), (0.92584134154638442, 2208, u'green'), (0.21641206332520091, 2171, u'got'), (0.03428736313670086, 5199, u've'), (0.50551118346627055, 4452, u'smoke')]
#
# tweet # 61 20% OFF WHOLE STORE &amp; LA idols #BOGO 50% off. Excludes E-cigs #ComeShop
# [(-0.019378559813311456, 1130, u'comeshop'), (0.079720524433658166, 1815, u'excludes'), (0.13449115900106667, 136, u'50'), (1.0993798436734843, 686, u'bogo'), (0.28360099584271115, 2445, u'idols'), (0.021872741346100056, 4610, u'store'), (0.7229785434316387, 58, u'20'), (0.0071734004503366013, 1045, u'cigs'), (0.31864520474751784, 2778, u'la'), (-0.42782900050333728, 355, u'amp'), (-0.013741214958969534, 1584, u'e')]
#
# tweet # 62 RT @Richo_I: http://t.co/aW3So8TTqf will make easy to do and could help prevent thousands of premature deaths (2/2) #vaping #ecigs #MEP #EU
# [(-0.012120383881618504, 1781, u'eu'), (0.063544699557468193, 3147, u'mep'), (0.112995409238452, 1358, u'deaths'), (0.92848619906672258, 3811, u'premature'), (0.23210890844747833, 4860, u'thousands'), (0.032650481021401279, 3821, u'prevent'), (0.49201437749219412, 2335, u'help'), (0.0098234954881543969, 3029, u'make'), (0.39549172055789311, 1592, u'easy'), (-0.8821101639610498, 57, u'2'), (-0.013423562793081942, 200, u'THIS_IS_A_URL'), (0.014068743270529723, 1623, u'ecigs'), (-0.10266570455260984, 4180, u'rt'), (-0.015297927486513624, 199, u'THIS_IS_A_MENTION'), (-0.14973271652949416, 5170, u'vaping')]
#
# tweet # 63 E cig... for vaped weed, not nicotine. Blessed. &gt;&gt;&gt;
# [(-0.017869238801462999, 651, u'blessed'), (0.054181895834782397, 5341, u'weed'), (0.11926096860609076, 5143, u'vaped'), (0.62656736181184813, 3395, u'nicotine'), (0.088705947063808688, 1022, u'cig'), (0.0089134636883939945, 1584, u'e'), (1.8283954710862642, 2223, u'gt')]
#
# tweet # 64 Electronic cigarettes-stylish chosen in favor of being smokers http://t.co/JV9p6mxgsM
# [(-0.017446526721368337, 4459, u'smokers'), (0.10083322457852832, 1892, u'favor'), (0.19652733409941811, 1010, u'chosen'), (1.5241198435270933, 4644, u'stylish'), (0.13992665201246923, 1682, u'electronic'), (0.014141987079768671, 200, u'THIS_IS_A_URL'), (0.40577735025737344, 1033, u'cigarettes')]
#
# tweet # 65 I love getting new juice in the mail. Vaping "cupcake city" &amp; "Crunk berry" from Alice in Vapeland. Luvin it!! #vapecommunity #ejuice
# [(-0.015268735546850652, 3000, u'luvin'), (0.06281331620926936, 5150, u'vapeland'), (0.11169486078491536, 317, u'alice'), (0.86622227143307962, 596, u'berry'), (0.2234546141747511, 1276, u'crunk'), (0.028899185137240404, 1052, u'city'), (0.69073183614861677, 1289, u'cupcake'), (0.011347125941774516, 3024, u'mail'), (0.25975868722170231, 2661, u'juice'), (-0.41545631236564173, 2113, u'getting'), (-0.036442332841014904, 5142, u'vapecommunity'), (0.017693583781519761, 2975, u'love'), (-0.22837189197648097, 1665, u'ejuice'), (-0.032550410338514822, 355, u'amp'), (-0.14269493684625892, 3365, u'new'), (0.08309334698434824, 5170, u'vaping')]
#
# tweet # 66 RT @Queen_UK: Right. Sorry about this. Apparently Camilla unplugged Facebook to plug in an electric heater/cigarette lighter. Awkward.
# [(-0.015588003562613232, 499, u'awkward'), (0.061932693684592796, 2890, u'lighter'), (0.1190602434852561, 2322, u'heater'), (0.90244088548963874, 3739, u'plug'), (0.22812703194383613, 1850, u'facebook'), (0.032469608483158878, 5083, u'unplugged'), (0.7362800760657634, 863, u'camilla'), (0.013728770014525889, 392, u'apparently'), (0.32772210883507291, 4133, u'right'), (-0.60184977790902416, 4500, u'sorry'), (-0.015656566372205985, 4180, u'rt'), (0.010553641663952855, 1029, u'cigarette'), (-0.18487002348486034, 1673, u'electric'), (-0.016119017433004659, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 67 E Cig Lewisville TX Soothing a sore throat with vaping: Wishing everyone a happy and successful 201... http://t.co/UUmTlYia Retail Store
# [(-0.017468724642251139, 62, u'201'), (0.071863745452890537, 4656, u'successful'), (0.098835580569753265, 2275, u'happy'), (0.99103152924610671, 5395, u'wishing'), (0.2260299503251316, 4865, u'throat'), (0.034849905329540624, 4499, u'sore'), (0.79025563120749109, 4498, u'soothing'), (0.010593773312750457, 5033, u'tx'), (0.32156028803439179, 2870, u'lewisville'), (-0.39511116258936496, 4610, u'store'), (-0.026590741954917365, 4103, u'retail'), (0.010234894218635188, 1022, u'cig'), (-0.085585397151724474, 1584, u'e'), (-0.017793436932906043, 200, u'THIS_IS_A_URL'), (-0.14581120003356882, 5170, u'vaping')]
#
# tweet # 68 @fullbright I don't smoke but I bought an e-cig that lit up blue just so I could be Mr.Sci-fi. Filled it with banana and apple flavor.
# [(-0.013213065258289946, 1964, u'flavor'), (0.058764839903882878, 394, u'apple'), (0.12135435416855099, 528, u'banana'), (0.85864506750521163, 1928, u'filled'), (0.24277921292527269, 1919, u'fi'), (0.033095248692880455, 4265, u'sci'), (0.66351413960398753, 3279, u'mr'), (0.013062507301506179, 668, u'blue'), (0.39649551546172629, 2920, u'lit'), (-0.37255523911886995, 1503, u'don'), (-0.020114040008551395, 4452, u'smoke'), (0.013973213075463555, 2668, u'just'), (-0.11026155265736458, 1022, u'cig'), (-0.016012042914177141, 1584, u'e'), (-0.14213581260438435, 4734, u't'), (0.14379848356146466, 725, u'bought'), (0.061245719312004149, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 69 DALLAS E CIG : mattie1224's blog: Transformations: I sit here today 116 days free from smoke, 30... http://t.co/7ACM9botVM RETAIL STORES
# [(-0.013908072267728697, 1350, u'days'), (0.072938861475328562, 29, u'116'), (0.11467242201853506, 4417, u'sit'), (1.0058578351826963, 4959, u'transformations'), (0.25947563562819798, 3092, u'mattie1224'), (0.026999261369564931, 97, u'30'), (0.34291556852185678, 4452, u'smoke'), (0.0098199306648159568, 2015, u'free'), (0.31161058973288286, 4611, u'stores'), (-0.38044578695266751, 4103, u'retail'), (-0.0292099476024151, 1325, u'dallas'), (0.010388013134064199, 1022, u'cig'), (-0.086865795650086355, 1584, u'e'), (-0.018059635264488248, 200, u'THIS_IS_A_URL'), (-0.27176950006146156, 658, u'blog'), (0.092151230310254337, 4197, u's'), (0.19126822333830021, 4905, u'today')]
#
# tweet # 70 #Cigarette http://t.co/CHv23nMUrV
# [(-0.032061741213024221, 200, u'THIS_IS_A_URL'), (0.16158691728989863, 1029, u'cigarette')]
#
# tweet # 71 @kaitlin_senn hey I like e cigs. That is all.
# [(-0.037251067396255368, 2349, u'hey'), (0.095352848013886313, 2895, u'like'), (0.14674217224682914, 1045, u'cigs'), (0.66341716311931365, 1584, u'e'), (0.15120660533999183, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 72 http://t.co/RMv8zmkEqm �??�?�?��?�????�?��??� �??????��??�?�? health e-cigarette ???��?�?�?�??��???�?
# [(-0.040156540046555833, 2310, u'health'), (0.065455018149934555, 1584, u'e'), (0.12282918226702449, 200, u'THIS_IS_A_URL'), (1.1669927477450548, 1029, u'cigarette')]
#
# tweet # 73 E-cigarettes bad for you?: Professor Neal Benowitz discusses the health risks and benefits of electronic cigar... http://t.co/4AdvfIeLmG
# [(-0.016215516307769504, 1025, u'cigar'), (0.070080705057764967, 591, u'benefits'), (0.12461775730892941, 4143, u'risks'), (0.96644264595937013, 1464, u'discusses'), (0.26752209128341525, 592, u'benowitz'), (0.036468155717224691, 3341, u'neal'), (0.79524296926760363, 3850, u'professor'), (0.011404001237536061, 512, u'bad'), (0.31852548110289342, 2310, u'health'), (-0.2741381042028917, 1682, u'electronic'), (-0.013662649031712727, 1584, u'e'), (0.0087815300714347653, 200, u'THIS_IS_A_URL'), (-0.12605447300248335, 1033, u'cigarettes')]
#
# tweet # 74 I bought an E-cigarette and drove around listening to The XX. It lasts 10 days, so I gotta make a playlist that'll make Jesus want to dance.
# [(-0.015042056821713223, 1332, u'dance'), (0.03653866827173613, 5310, u'want'), (0.10039209203687513, 2632, u'jesus'), (0.62897443320014113, 2931, u'll'), (0.22013722047755943, 3729, u'playlist'), (0.024301346242933699, 2173, u'gotta'), (0.46314729230911034, 17, u'10'), (0.012982142267145644, 2807, u'lasts'), (0.3595176854470955, 5458, u'xx'), (-0.53167047795739064, 2918, u'listening'), (-0.042659014403597137, 1556, u'drove'), (0.020381003405163755, 1350, u'days'), (-0.37403784005476864, 3029, u'make'), (-0.014518733209582083, 1584, u'e'), (-0.09037487895304093, 1029, u'cigarette'), (0.13038759825723778, 725, u'bought')]
#
# tweet # 75 Lol i tried vaping yesterday #amicoolyet
# [(-0.029297889800086963, 350, u'amicoolyet'), (0.10996314489241808, 5477, u'yesterday'), (0.13181216293590337, 2949, u'lol'), (1.2687140882049766, 4977, u'tried'), (0.1925570420360421, 5170, u'vaping')]
#
# tweet # 76 RT @AJMarriner: @Awaydays23 haha Newcastle using green smoke bombs still. Hahaha school boy stuff! Lets all laugh at Newcastle!
# [(-0.01441926816583014, 2814, u'laugh'), (0.055280031806652613, 2863, u'lets'), (0.093568727018808445, 4640, u'stuff'), (0.65007550216270793, 4261, u'school'), (0.16978077078038506, 2253, u'hahaha'), (0.030320859069105335, 698, u'bombs'), (1.375110170075464, 3367, u'newcastle'), (0.0081902401944755013, 2208, u'green'), (0.34284327388199343, 736, u'boy'), (-0.25976961727442732, 4452, u'smoke'), (-0.02852768780421909, 5112, u'using'), (0.019563409488431389, 2251, u'haha'), (-0.086984019310051161, 4180, u'rt'), (-0.025922487469197165, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 77 RT @BigBudsMag: Do vapes get you higher? Our expert says HECK YES-- if you do it right... #cannabis #vaporizer #mmot http://t.co/Z7bq794juL
# [(-0.018089036158120599, 3225, u'mmot'), (0.059271021300516008, 5178, u'vaporizer'), (0.1207279166917528, 872, u'cannabis'), (1.0262228945444187, 2326, u'heck'), (0.20766260061095321, 4253, u'says'), (0.034237177222942207, 1826, u'expert'), (0.81831747765351337, 2357, u'higher'), (0.012434630959928068, 5164, u'vapes'), (0.31363764334774785, 4133, u'right'), (-0.55931209610140975, 5476, u'yes'), (-0.013536182679377225, 200, u'THIS_IS_A_URL'), (0.009125929321998431, 4180, u'rt'), (-0.078302923538605823, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 78 RT @vaporkl: Lavatube lambo v4 rm220 complete set with flavor.cheapest price in http://t.co/RtYOwrFdPz me. #kltu #klrb #rtniaga  http:// ...
# [(-0.014722994667473833, 4181, u'rtniaga'), (0.063841441348655104, 2736, u'klrb'), (0.10770262112894699, 2738, u'kltu'), (0.77839285974719241, 3823, u'price'), (0.22711210784344074, 976, u'cheapest'), (0.025071316684624742, 4326, u'set'), (0.62069603494336878, 1149, u'complete'), (0.013393471981787964, 4149, u'rm220'), (0.40654152029671081, 5121, u'v4'), (-0.58859008109841371, 2796, u'lambo'), (-0.037038819076622716, 2819, u'lavatube'), (0.021349814088324884, 1964, u'flavor'), (-0.16047214040466054, 200, u'THIS_IS_A_URL'), (-0.017497477198586464, 4180, u'rt'), (-0.063719305110513505, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 79 Like smoke cigarettes in a strip club with a gun past midnight. Is there a more adult thing to do?
# [(-0.017460859569908654, 265, u'adult'), (0.079143039709918289, 3177, u'midnight'), (0.13533628047978424, 3639, u'past'), (1.1503982947493956, 2236, u'gun'), (0.26237759520539844, 1092, u'club'), (0.040454082922850569, 4629, u'strip'), (0.39219208865526367, 4452, u'smoke'), (0.0086733271704119447, 2895, u'like'), (0.35892374116988079, 4843, u'thing'), (-0.27066200702268167, 1033, u'cigarettes')]
#
# tweet # 80 Combined sales of electronic cigarettes worldwide-both online and at brick-and-mortar stores - have far exceeded the $1-billion mark
# [(-0.015563892588805845, 3061, u'mark'), (0.067487719605042934, 621, u'billion'), (0.1200069014166185, 1811, u'exceeded'), (0.84911113963694418, 1881, u'far'), (0.22777417310146669, 3263, u'mortar'), (0.031049787227576637, 759, u'brick'), (0.5664787895401987, 3533, u'online'), (0.012917468324279978, 5425, u'worldwide'), (0.34229874875330407, 4211, u'sales'), (-0.62220716694887124, 1125, u'combined'), (-0.016557739325566288, 1682, u'electronic'), (0.017513513302397289, 16, u'1'), (-0.21565798205043132, 4611, u'stores'), (-0.021143949741874762, 1033, u'cigarettes')]
#
# tweet # 81 If you once smoked cigarettes and now use one of those electric cigarettes. KILL YOURSELF. It is a fucking toy for adults. STOP IT.
# [(-0.022444610940809705, 266, u'adults'), (0.084240879523373863, 4945, u'toy'), (0.12378802357830786, 2041, u'fucking'), (1.071612717244774, 2715, u'kill'), (0.20617374147135306, 5105, u'use'), (0.031739446184380932, 4453, u'smoked'), (0.64425585451935996, 4603, u'stop'), (0.0096691056079796171, 1673, u'electric'), (0.3926282159884173, 1033, u'cigarettes')]
#
# tweet # 82 RT @Hifistud: .@DoctorChristian Please RT this video of real life folks who use e-cigs http://t.co/jbK4LcjIvS - it may prevent needless ear?
# [(-0.01904903350910896, 1586, u'ear'), (0.082599891053890234, 3352, u'needless'), (0.1393487456350615, 1983, u'folks'), (0.8074282813014052, 2879, u'life'), (0.21432650757181806, 5231, u'video'), (0.025142371873508478, 5105, u'use'), (0.82870390811077554, 3821, u'prevent'), (0.01179438958135506, 4002, u'real'), (0.22560365773280536, 1045, u'cigs'), (-0.20070012961308645, 1584, u'e'), (-0.015024900519957285, 200, u'THIS_IS_A_URL'), (0.020259209477733811, 4180, u'rt'), (-0.17382945612603135, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 83 RT @ecigsproject: Want to save 10% OFF All Products at Smokeless Image visit http://t.co/qjMLO3LLy6 for the exclusive coupon code! #ecigspr�??
# [(-0.017307306427825617, 1626, u'ecigspr'), (0.064621892782568677, 1103, u'code'), (0.11491087803674319, 1235, u'coupon'), (0.98187398951917182, 1816, u'exclusive'), (0.23604355831452153, 5246, u'visit'), (0.033203963486460659, 2472, u'image'), (0.65731281154373888, 4455, u'smokeless'), (0.012540210777609273, 3845, u'products'), (0.35223923575731991, 4242, u'save'), (-0.43062673318736383, 5310, u'want'), (-0.03521246750774995, 17, u'10'), (0.0083143112564128298, 200, u'THIS_IS_A_URL'), (-0.10440606688281842, 4180, u'rt'), (-0.015557253975761524, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 84 Marissa being all selective with her cigarette smoke... msmith0789 hahah just came across this fine�?? http://t.co/ylLhBxOG3r
# [(-0.018845394303704653, 1943, u'fine'), (0.065722445796028567, 859, u'came'), (0.15110303412906301, 2252, u'hahah'), (1.1718427555566095, 3282, u'msmith0789'), (0.30229385626759309, 4299, u'selective'), (0.041208183480622898, 3060, u'marissa'), (0.39950290258158239, 4452, u'smoke'), (0.0086934370502521272, 2668, u'just'), (0.14278123274862439, 200, u'THIS_IS_A_URL'), (-0.26693620448913297, 1029, u'cigarette')]
#
# tweet # 85 RT @ICoombs: @LindaMcAvanMEP The carcenogens in e-cig vapour are the same level as or less than that in nicorette inhalers. #EUecigBAN
# [(-0.022107899294870236, 2518, u'inhalers'), (0.08297710688438685, 3392, u'nicorette'), (0.15343333188277189, 2868, u'level'), (1.2542200816207238, 888, u'carcenogens'), (0.27229096818613707, 5188, u'vapour'), (0.014960575896050156, 1022, u'cig'), (0.25006558185031041, 1584, u'e'), (0.0055729681645247074, 4180, u'rt'), (0.34795733218833669, 1786, u'euecigban'), (-0.39049761005259398, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 86 RT @jessievolt: Smoking electronic cigarette with @katiestives http://t.co/YBtyZKJp0Q
# [(-0.020861461952020741, 1682, u'electronic'), (0.063628140688634094, 200, u'THIS_IS_A_URL'), (0.12524299919644347, 4180, u'rt'), (1.0749723607077757, 1029, u'cigarette'), (0.37902143179287573, 199, u'THIS_IS_A_MENTION'), (0.047773647687481997, 4462, u'smoking')]
#
# tweet # 87 RT @AasmaRbz: @MllCicicaps_MB En s'momnt jai pls d'argent pr mes clope &amp; ta cru j'allai economiser , en pls attendre pr une cigarette electriqe mdrrrrr
# [(-0.010557452268289197, 3106, u'mdrrrrr'), (0.043431794706084832, 1678, u'electriqe'), (0.077230570778546018, 459, u'attendre'), (0.59894286965170906, 1632, u'economiser'), (0.15450601106032688, 320, u'allai'), (0.016521753488022609, 2599, u'j'), (0.47760132906558261, 1273, u'cru'), (0.008313050665599309, 4736, u'ta'), (0.26239292433456346, 1085, u'clope'), (-0.40042209305229998, 3159, u'mes'), (-0.0598815060621401, 3803, u'pr'), (0.018235633508005923, 411, u'argent'), (-0.34121260052355579, 3738, u'pls'), (-0.040754970510537128, 2605, u'jai'), (-0.19622394404323543, 3245, u'momnt'), (0.1906765164177894, 1724, u'en'), (0.13302152659336777, 5070, u'une'), (0.31405471226672316, 1308, u'd'), (-0.030640142625248598, 355, u'amp'), (-0.01226497132703867, 4180, u'rt'), (-0.016356804059564477, 1029, u'cigarette'), (-0.024911794582053535, 4197, u's'), (-0.018553280485036027, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 88 E-cigarettes threaten to undo years of gains: Our view http://t.co/aoSK7QNb6P via @usatoday
# [(-0.022033721728834162, 5237, u'view'), (0.094257619730620468, 2069, u'gains'), (0.16760923239036876, 5069, u'undo'), (1.2998525534126268, 4863, u'threaten'), (0.26978208157622002, 5471, u'years'), (0.012046645920169885, 1584, u'e'), (0.28827653036467754, 200, u'THIS_IS_A_URL'), (0.0069591050865788345, 1033, u'cigarettes'), (0.13976572894807279, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 89 kok siang ni x habis2 tanye aq pasal vaper memang aq ada beli vaper pon kan -.-'
# [(-0.011910497123634211, 2683, u'kan'), (0.047119272757498637, 3760, u'pon'), (0.087128453696865282, 583, u'beli'), (0.64979475594463387, 243, u'ada'), (0.18372743917293896, 3131, u'memang'), (0.023761305171785468, 3631, u'pasal'), (1.1358583207555626, 404, u'aq'), (0.010834949894193762, 4759, u'tanye'), (0.32888089125163428, 2249, u'habis2'), (-0.40643140374732473, 5452, u'x'), (-0.027176436490507171, 3383, u'ni'), (0.021684504202325226, 4382, u'siang'), (-0.24599495241366734, 2752, u'kok'), (-0.063333268228069298, 5160, u'vaper')]
#
# tweet # 90 #IHatePeopleThat smoke ecigs
# [(-0.043021822931016099, 2455, u'ihatepeoplethat'), (0.075667246347284681, 4452, u'smoke'), (0.14289778055448102, 1623, u'ecigs')]
#
# tweet # 91 @kcavo got a 650 an 1100 and now an 1800 mah vaping good picking up a mod stick soon I'm gonna see if I could work at the vape bar I dig it
# [(-0.015377891175364602, 1441, u'dig'), (0.055932466237158071, 538, u'bar'), (0.078383777912645544, 5417, u'work'), (0.75121926756881929, 4494, u'soon'), (0.1856011007513573, 4590, u'stick'), (0.024843906811949319, 3233, u'mod'), (0.66000207932914734, 3698, u'picking'), (0.012108715741472549, 3023, u'mah'), (0.38219920233240734, 48, u'1800'), (-0.56088745834060727, 28, u'1100'), (-0.043611434853768338, 156, u'650'), (0.015027952993526919, 2171, u'got'), (-0.21760507677432131, 2160, u'gonna'), (-0.034763436606775965, 5134, u'vape'), (-0.15434938243936475, 3004, u'm'), (0.10782843468478139, 2162, u'good'), (0.056773710315596353, 199, u'THIS_IS_A_MENTION'), (0.31242083898514666, 5170, u'vaping')]
#
# ...
#
# tweet # 1967 RT @WarmCigarette: eCigarettes were responsible for 9/11
# [(-0.028347362992546921, 4095, u'responsible'), (0.098143336662682212, 186, u'9'), (0.16266697511210662, 1613, u'ecigarettes'), (1.3847857955246361, 27, u'11'), (0.12117104797724296, 4180, u'rt'), (0.012493300642483876, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 1968 I just bought 'Traditional Tobacco from $13.99 to' on electronic cigarette retailer The ecigforlife Team http://t.co/iz4kZPGu8U
# [(-0.020086217893697182, 1620, u'ecigforlife'), (0.08263172494760522, 4104, u'retailer'), (0.13940245046567645, 4954, u'traditional'), (0.90761732348789714, 36, u'13'), (0.25989801349041575, 4787, u'team'), (0.014261326321929309, 1682, u'electronic'), (0.44311237311668583, 2668, u'just'), (0.013807518803410808, 196, u'99'), (0.13884371638518245, 200, u'THIS_IS_A_URL'), (-0.25957483315946034, 1029, u'cigarette'), (-0.040747827067736393, 725, u'bought'), (0.021133676146062569, 4901, u'tobacco')]
#
# tweet # 1969 @PamBondi Thank You for NOT signing the #NAAG letter to the FDA. It took courage to say no to the NAAG. #Ecigs help me to quit smoking!!!
# [(-0.015539933654511043, 1237, u'courage'), (0.12785797010063529, 3305, u'naag'), (0.11367874705940834, 4395, u'signing'), (0.78204693281809967, 4926, u'took'), (0.19092888137239625, 2865, u'letter'), (0.025633272312250752, 4248, u'say'), (0.52067146498185413, 1900, u'fda'), (0.0085709814262983318, 2335, u'help'), (0.33660031675107216, 4823, u'thank'), (-0.37319539489061387, 3956, u'quit'), (-0.0210919721530092, 1623, u'ecigs'), (0.0062501852722051544, 199, u'THIS_IS_A_MENTION'), (-0.13112034120844024, 4462, u'smoking')]
#
# tweet # 1970 RT @SocialNetAdd: What's your favorite e cigarette? - http://t.co/xd45IOusq1 - let everyone know what your fav e cig is!
# [(-0.027348117054180672, 1891, u'fav'), (0.091108476423453683, 1893, u'favorite'), (0.14447455329506326, 2862, u'let'), (0.98444984421256554, 2747, u'know'), (0.13576071430106898, 1022, u'cig'), (0.027283361201533685, 1584, u'e'), (0.32644574913153396, 200, u'THIS_IS_A_URL'), (0.0068939243692867878, 4180, u'rt'), (0.23159326868004532, 1029, u'cigarette'), (-0.46893068598939441, 4197, u's'), (-0.017133857280740572, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 1971 RT @Trilliver: My parents logic: I found a cigarette filter in your wallet you must have been smoking weed. What?
# [(-0.023976487500139008, 5304, u'wallet'), (0.098635717824352792, 1930, u'filter'), (0.15102865018639006, 3612, u'parents'), (1.2026253926695296, 2946, u'logic'), (0.25862547963111993, 5341, u'weed'), (0.013970949059162217, 4180, u'rt'), (0.35062234499389966, 1029, u'cigarette'), (0.0045713957701765855, 199, u'THIS_IS_A_MENTION'), (0.25660259024303111, 4462, u'smoking')]
#
# tweet # 1972 E-cigarettes will never catch on because they just aren't sexy via @Telegraph http://t.co/HGXdSrNof6 lung cancer is not sexy...
# [(-0.018662759278836462, 913, u'catch'), (0.071548563676677085, 410, u'aren'), (0.12391033025633569, 2997, u'lung'), (1.9219127357229639, 4333, u'sexy'), (0.20593145121958162, 869, u'cancer'), (0.019137422494052547, 2668, u'just'), (0.22250520630530463, 1584, u'e'), (0.004479711654336466, 200, u'THIS_IS_A_URL'), (0.23755818788455979, 4734, u't'), (-0.26256635481396134, 1033, u'cigarettes'), (-0.012324276940342554, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 1973 RT @ICoombs: Demoise electronic cigarettes like you have with cigarettes and young people will want a go. #EUecigBAN
# [(-0.026331980956682325, 1395, u'demoise'), (0.063963029027057319, 5310, u'want'), (0.16211125019967271, 5489, u'young'), (0.53165652587948897, 1682, u'electronic'), (0.19098287154961474, 2895, u'like'), (0.015343480339666329, 4180, u'rt'), (0.71567784742365403, 1786, u'euecigban'), (0.015175437624119718, 1033, u'cigarettes'), (0.40072944946713385, 3666, u'people'), (-0.23255433486438856, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 1974 markten met mn girlieeee
# [(-0.029200509944563541, 2124, u'girlieeee'), (0.10959765115769549, 3226, u'mn'), (0.15141448131018972, 3067, u'markten'), (1.3661998047484365, 3162, u'met')]
#
# tweet # 1975 Stay away from e-cigarettes coz its also carcinogenic #dontsmoke
# [(-0.023711646346496289, 1509, u'dontsmoke'), (0.097546200550447354, 1244, u'coz'), (0.16456366364094366, 889, u'carcinogenic'), (1.2762333872182865, 4572, u'stay'), (0.086765686245608972, 1584, u'e'), (0.015793946742284157, 1033, u'cigarettes'), (0.82964081536507572, 495, u'away')]
#
# tweet # 1976 Buy your very own e cig today special deal going right now for a short time. Come get your e cig on
# [(-0.019637427675125246, 4371, u'short'), (0.080785468469831548, 4515, u'special'), (0.10305714343187808, 2154, u'going'), (0.92113939906482789, 1127, u'come'), (0.25493427959935522, 1353, u'deal'), (0.026058229984960803, 837, u'buy'), (0.61974175915112961, 4133, u'right'), (0.011984850531595872, 4884, u'time'), (0.36786102520377206, 1022, u'cig'), (-0.41379887098005352, 1584, u'e'), (-0.03789240685932313, 4905, u'today')]
#
# tweet # 1977 Electric cigarette ? O.o
# [(-0.047167143742813174, 3479, u'o'), (0.041597710845525861, 1029, u'cigarette'), (0.11421900001894671, 1673, u'electric')]
#
# tweet # 1978 RT @MailOnline: France to ban electronic cigarettes from all public places and subject them to the same tight rules as tobacco http://t.co/�??
# [(-0.020536711547077698, 4878, u'tight'), (0.084484989103843472, 4649, u'subject'), (0.12936139308163522, 3717, u'places'), (0.86823820862732815, 3894, u'public'), (0.25879794268984829, 2013, u'france'), (0.026292401652699859, 527, u'ban'), (0.84761662217415168, 4189, u'rules'), (0.0063079956712815671, 1682, u'electronic'), (0.1419577029691334, 200, u'THIS_IS_A_URL'), (-0.23979914638802974, 4180, u'rt'), (-0.019445676310498369, 1033, u'cigarettes'), (0.021607662190960938, 4901, u'tobacco'), (-0.088898299497473271, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 1979 e-cigs are stupid
# [(-0.043226126649069038, 4642, u'stupid'), (0.094183907548781837, 1045, u'cigs'), (0.097632357912599124, 1584, u'e')]
#
# tweet # 1980 LMAO RT @cutestbudddhist: i licked my moms ecig liquid nd it turned my tongue numb nd my throat itches but i don't want to tell her..
# [(-0.014134127747395633, 2591, u'itches'), (0.058145707797165366, 4921, u'tongue'), (0.19618746083603222, 3339, u'nd'), (0.80185397176517859, 2876, u'licked'), (0.19624445144104707, 3467, u'numb'), (0.026751709286735509, 5013, u'turned'), (0.58336124511278908, 3246, u'moms'), (0.0095689604448582939, 2933, u'lmao'), (0.24841103810263396, 2910, u'liquid'), (-0.44324352949305235, 4796, u'tell'), (-0.023668429684961013, 5310, u'want'), (0.01371448129193575, 1503, u'don'), (-0.24486458473484018, 4865, u'throat'), (-0.015936407056041588, 4180, u'rt'), (-0.1211008756973521, 4734, u't'), (0.068986690752436644, 1608, u'ecig'), (0.052181854140039223, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 1981 RT @pakman80: @dlabbvapes sent 3600 tweets in a week! Obviously most are RTs but hey! All to save our e-cig so keep it up get it back trending #EUecigBAN
# [(-0.017702844388214477, 4970, u'trending'), (0.07282687940651135, 113, u'3600'), (0.12286135204696845, 4314, u'sent'), (0.91628691754528302, 5027, u'tweets'), (0.24579408421941748, 4182, u'rts'), (0.032221489820249492, 3488, u'obviously'), (0.68959342911707822, 5344, u'week'), (0.011261122585747966, 4242, u'save'), (0.36937904914176189, 2349, u'hey'), (-0.24006025698975617, 1022, u'cig'), (-0.012552975683804131, 1584, u'e'), (0.008931095348198307, 4180, u'rt'), (-0.20840547390795716, 1786, u'euecigban'), (-0.030193859285228903, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 1982 @al_vaper Do YOU want Free coins for PS3 #FUT ? I have found a glitch...
# [(-0.023364175945492633, 2138, u'glitch'), (0.09611675879316274, 3888, u'ps3'), (0.1709151600391913, 1108, u'coins'), (1.2575314666366937, 2059, u'fut'), (0.20189871841525284, 5310, u'want'), (0.029912301043671888, 2015, u'free'), (0.23349683101175342, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 1983 #NameALegend yung yosey brown king of e cig trade
# [(-0.021344965926026992, 5484, u'yosey'), (0.087810027888272496, 3315, u'namealegend'), (0.14813841863819563, 777, u'brown'), (1.1488514026297285, 4952, u'trade'), (0.28499935766141571, 5501, u'yung'), (0.038850626894564241, 2723, u'king'), (0.3275384552570193, 1022, u'cig'), (0.0046061136394833207, 1584, u'e')]
#
# tweet # 1984 #myvapez #vapes #instavape #vapelife #vapelyfe #vapestagramm #vapeon  #vaping #vapor #ecig #vapehead�?? http://t.co/NXTILh4ReB
# [(-0.018163182632189672, 5165, u'vapestagramm'), (0.074720642750130059, 5152, u'vapelyfe'), (0.13286851090507407, 2535, u'instavape'), (1.0304293546661354, 3301, u'myvapez'), (0.25218562303813896, 5147, u'vapehead'), (0.028860954350790183, 5151, u'vapelife'), (0.65445032008168491, 5164, u'vapes'), (0.014301883980423041, 5156, u'vapeon'), (0.28460450790483743, 5173, u'vapor'), (-0.19159577225697047, 200, u'THIS_IS_A_URL'), (-0.020747485713169193, 1608, u'ecig'), (0.014089334812517708, 5170, u'vaping')]
#
# tweet # 1985 RT @CASAAmedia: CASAA launches tobacco harm reduction success stories collection - please submit your story! #snus #ecigarettes  http://t.c?
# [(-0.016291723667254863, 4470, u'snus'), (0.067021737796512687, 4651, u'submit'), (0.11917829091850875, 4655, u'success'), (0.92425819003200815, 2817, u'launches'), (0.23842582217353173, 910, u'casaa'), (0.025137925761033849, 4613, u'story'), (0.67241221909250803, 1116, u'collection'), (0.012828277204968099, 4612, u'stories'), (0.33479157130255777, 1613, u'ecigarettes'), (-0.51875483081631679, 4035, u'reduction'), (-0.03573490469287189, 2285, u'harm'), (0.0074251623095759056, 200, u'THIS_IS_A_URL'), (-0.093240674879885924, 4180, u'rt'), (-0.038309249276148316, 4901, u'tobacco'), (-0.066893517274618869, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 1986 Long time cigarette quitter. what about the E cigarettes with no nicotine
# [(-0.030977384761440054, 3962, u'quitter'), (0.096079299634447154, 2954, u'long'), (0.14005877106543282, 3395, u'nicotine'), (1.1790223215980062, 4884, u'time'), (0.11335248542612354, 1584, u'e'), (0.019977115622984435, 1029, u'cigarette'), (0.46788562978319509, 1033, u'cigarettes')]
#
# tweet # 1987 RT @CNN: Should e-cigarettes be banned from restaurants? http://t.co/c2QuGMJnXP
# [(-0.034786187258136078, 4096, u'restaurants'), (0.12014112483480671, 534, u'banned'), (0.06706483667848552, 1584, u'e'), (0.54886832690487997, 200, u'THIS_IS_A_URL'), (0.15672955807982805, 4180, u'rt'), (0.024422699746582784, 1033, u'cigarettes'), (0.3664335522279224, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 1988 Didn't even notice I got my ecig in my ear in my new avatar
# [(-0.023827816927996869, 485, u'avatar'), (0.098024109113839533, 3449, u'notice'), (0.14375133389545172, 1434, u'didn'), (1.28248604351035, 1586, u'ear'), (0.1972930671236148, 2171, u'got'), (0.023902166897164873, 3365, u'new'), (0.49690807245097779, 4734, u't'), (0.0082831080371207639, 1608, u'ecig')]
#
# tweet # 1989 RT @imraphael: ?@MelatiPagnoux: E-cigarette usage may lead to various chronic diseases | theSundaily http://t.co/LmmVTi7n via @sharethis ...
# [(-0.019822019571581279, 4839, u'thesundaily'), (0.081544852187375394, 1466, u'diseases'), (0.145003344234376, 1015, u'chronic'), (1.1245380971463386, 5194, u'various'), (0.29009093267357405, 5102, u'usage'), (0.03496285111784897, 2827, u'lead'), (0.22420967236655795, 1584, u'e'), (0.0045140277793647519, 200, u'THIS_IS_A_URL'), (0.15166966186755051, 4180, u'rt'), (-0.25616058983365408, 1029, u'cigarette'), (-0.037256055363811769, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 1990 BlackFriday #BlackFriday  is too good for me because i used electronic cigarette which  i missed a lot
# [(-0.037415832224954634, 640, u'blackfriday'), (0.075571711378898024, 3211, u'missed'), (0.12103663171868936, 5106, u'used'), (0.45801059015150586, 1682, u'electronic'), (0.23974412267279133, 2972, u'lot'), (0.014629043670930706, 1029, u'cigarette'), (0.59380582349205036, 2162, u'good')]
#
# tweet # 1991 Back at college hitting it on an e-cig hookah.. or as i like to call them hookah togos :) http://t.co/mfyuCUejKd
# [(-0.021414492332411304, 4909, u'togos'), (0.077888792143834165, 1118, u'college'), (0.25371760407776955, 2394, u'hookah'), (0.6020862212537772, 2895, u'like'), (0.10630518984847243, 1022, u'cig'), (0.01068189316462166, 1584, u'e'), (0.81529295209016794, 2372, u'hitting'), (0.0048766783283821936, 200, u'THIS_IS_A_URL')]
#
# tweet # 1992 Ecigs Dallas Local New Places to Vape: ... http://t.co/MCdhV1O0WK Retail Store
# [(-0.025865112519708085, 2941, u'local'), (0.096574965898240106, 3717, u'places'), (0.11283496160711011, 4610, u'store'), (0.90573883055400251, 5134, u'vape'), (0.21415300326381767, 4103, u'retail'), (0.031595811186739729, 1325, u'dallas'), (0.62014217474867439, 3365, u'new'), (0.0062085270599109505, 200, u'THIS_IS_A_URL'), (0.32428710619244938, 1623, u'ecigs')]
#
# tweet # 1993 @gem_got_ink oh and my ecig! I can smoke in bed without the stink! Technology is wonderful! lol
# [(-0.023367658227709531, 4791, u'technology'), (0.087705333217633352, 4595, u'stink'), (0.15595793336560917, 5408, u'wonderful'), (1.0399155502438822, 574, u'bed'), (0.2103247945029387, 2949, u'lol'), (0.019930861327841894, 4452, u'smoke'), (0.85606018168856624, 3503, u'oh'), (0.008123146080042663, 1608, u'ecig'), (0.13523533690933065, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 1994 I'm at ?RISE? Fridays?@ButterNC?sponsored? by ?@blucigs ?Meet ?the?@blucigs? team? and ?enter ?to ?win ?a ?trip?to? Vegas ?#risefromtheashes
# [(-0.017503452003079376, 4140, u'risefromtheashes'), (0.072006608671008651, 4979, u'trip'), (0.12804240591766938, 2027, u'fridays'), (0.90596650631921605, 4139, u'rise'), (0.22647929186572374, 5202, u'vegas'), (0.030873271223556775, 4787, u'team'), (0.75122879891211203, 3124, u'meet'), (0.011530920982173723, 5380, u'win'), (0.40540874947224004, 1743, u'enter'), (-0.37788158754852846, 3004, u'm'), (-0.032898240995557951, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 1995 RT @chandler_torres: lol it says smoke free facility but literally everyone is smoking cigs
# [(-0.025960053685986056, 1851, u'facility'), (0.091959774614311721, 2922, u'literally'), (0.14896776846430174, 4253, u'says'), (0.90577616060409816, 2949, u'lol'), (0.16242852924053872, 4452, u'smoke'), (0.033235708495634078, 2015, u'free'), (0.50370518926941887, 1045, u'cigs'), (0.0065440207959931249, 4180, u'rt'), (0.15023827258161468, 199, u'THIS_IS_A_MENTION'), (-0.42398156506961504, 4462, u'smoking')]
#
# tweet # 1996 @LORD_BOPP e cig smoke nd shit ahaa
# [(-0.030621494723367372, 292, u'ahaa'), (0.11951355247844, 3339, u'nd'), (0.14729781055857652, 4361, u'shit'), (0.74271659950583835, 4452, u'smoke'), (0.1520103189691176, 1022, u'cig'), (0.015274494024823084, 1584, u'e'), (0.306025001499305, 199, u'THIS_IS_A_MENTION')]
#
# tweet # 1997 RSVP now for 15% discount on E-cigarette products at FEB 25th Vaping Party! https://t.co/z8zbhQ3v4e #minneapolis #event
# [(-0.017647198689993329, 1797, u'event'), (0.072597961247091697, 3200, u'minneapolis'), (0.12909395115754083, 81, u'25th'), (1.0011566764498636, 1902, u'feb'), (0.23562653173593617, 1462, u'discount'), (0.033400910018444502, 4179, u'rsvp'), (0.67186447816511652, 3628, u'party'), (0.013114706547928609, 41, u'15'), (0.36821797272675144, 3845, u'products'), (-0.17639757203106993, 1584, u'e'), (-0.013205551869040801, 200, u'THIS_IS_A_URL'), (0.00985337777609596, 1029, u'cigarette'), (-0.15529269048964067, 5170, u'vaping')]
#
# tweet # 1998 BlackFriday #BlackFriday  is too good for me because i used electronic cigarette which  i missed a lot
# [(-0.037415832224954634, 640, u'blackfriday'), (0.075571711378898024, 3211, u'missed'), (0.12103663171868936, 5106, u'used'), (0.45801059015150586, 1682, u'electronic'), (0.23974412267279133, 2972, u'lot'), (0.014629043670930706, 1029, u'cigarette'), (0.59380582349205036, 2162, u'good')]

# %%
test = []
>>> vector1 = (2,3,5)
>>> vector2 = (3,4,6)
>>> test=[p*q for p,q in zip(vector1, vector2)]
print test
# Out:
# [6, 12, 30]

# %%
# Get the learned coefficients for the Negative class.
coef = model.coef_[0]
# Sort them in descending order.
top_coef_ind = np.argsort(coef)[::-1]
# Get the names of those features.
top_coef_terms = vocab[top_coef_ind]
# Get the weights of those features
top_coef = coef[top_coef_ind]
# Print the top 10.
print 'top weighted terms for negative class:\n', \
    '\n'.join('%s %.2f' % (term, weight) for term, weight in zip(top_coef_terms, top_coef)[:10])
# Out:
# top weighted terms for negative class:
# smoking 2.58
# class 1.90
# people 1.81
# shit 1.62
# stupid 1.61
# pussy 1.57
# s 1.54
# sorry 1.52
# kid 1.48
# smoke 1.46

# %%
# Get the learned coefficients for the OTHER class.
coef = model.coef_[1]
# Sort them in descending order.
top_coef_ind = np.argsort(coef)[::-1]
# Get the names of those features.
top_coef_terms = vocab[top_coef_ind]
# Get the weights of those features
top_coef = coef[top_coef_ind]
# Print the top 10.
print 'top weighted terms for other class:\n', \
    '\n'.join('%s %.2f' % (term, weight) for term, weight in zip(top_coef_terms, top_coef)[:10])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-64-0f4fc203dbcd> in <module>()
#       1 # Get the learned coefficients for the OTHER class.
# ----> 2 coef = model.coef_[1]
#       3 # Sort them in descending order.
#       4 top_coef_ind = np.argsort(coef)[::-1]
#       5 # Get the names of those features.
#
# IndexError: index 1 is out of bounds for axis 0 with size 1

# %%
# How does tokenization affect accuracy?
# Collapse urls and mentions; ignore description prefix.
from itertools import product
def run_all(tweets, lowercase=True,
            keep_punctuation=True,
            collapse_urls=True, collapse_mentions=True):
    
    #vectorizer = TfidfVectorizer(decode_error='ignore', tokenizer=tokenize1)#lowercase, url's, mentions
    #B = vectorizer.fit_transform(t['text'] for t in tweets)
    #print B
    
    tokens_list = [tweet2tokens(t, lowercase, keep_punctuation,collapse_urls, collapse_mentions) for t in tweets]
    vocabulary = make_vocabulary(tokens_list)
    A = make_feature_matrix(tokens_list, vocabulary)
    print 'acc=', do_cross_val(A, y, 10)

# %%
# Store these in a sparse matrix.

#1) Create a vocabulary (dict from term->index)

# https://docs.python.org/2/library/collections.html#collections.defaultdict
from collections import defaultdict

def make_vocabulary(tokens_list):
    vocabulary = defaultdict(lambda: len(vocabulary))
    for tokens in tokens_list:
        for token in tokens:
            vocabulary[token]
    print '%d unique terms in vocabulary' % len(vocabulary)
    return vocabulary

# Convert features to a sparse matrix X.
# X[i,j] is the frequency of term j in tweet i
# 
from scipy.sparse import lil_matrix #list of list (LIL)

def make_feature_matrix(tokens_list, vocabulary):
    X = lil_matrix((len(tweets), len(vocabulary)))
    for i, tokens in enumerate(tokens_list):
        for token in tokens:
            j = vocabulary[token]
            X[i,j] += 1
    return X.tocsr()


# Do 5-fold cross-validation
# http://scikit-learn.org/stable/modules/generated/sklearn.cross_validation.KFold.html
from sklearn.cross_validation import KFold
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix

def do_cross_val(X, y, nfolds):
    """ Compute average cross-validation acccuracy."""
    cv = KFold(len(y), nfolds)
    accuracies = []
    for train_idx, test_idx in cv:
        clf = LogisticRegression()
        clf.fit(X[train_idx], y[train_idx])
        predicted = clf.predict(X[test_idx])
        acc = accuracy_score(y[test_idx], predicted)
        accuracies.append(acc)
    avg = np.mean(accuracies)
    return avg


argnames = ['lower', 'punct', 'url', 'mention']
lowercase_opts = [True, False]
keep_punctuation_opts = [True, False]
url_opts = [True, False]
mention_opts = [True, False]

option_iter = product(lowercase_opts, keep_punctuation_opts,url_opts, mention_opts)

for options in option_iter:
    print '\t'.join('%s=%s' % (name, opt) for name, opt in zip(argnames, options))
    run_all(tweets, *options)
    print
# Out:
# lower=True	punct=True	url=True	mention=True
# 7653 unique terms in vocabulary
# acc= 0.806
#
# lower=True	punct=True	url=True	mention=False
# 8711 unique terms in vocabulary
# acc= 0.802
#
# lower=True	punct=True	url=False	mention=True
# 8312 unique terms in vocabulary
# acc= 0.814
#
# lower=True	punct=True	url=False	mention=False
# 9370 unique terms in vocabulary
# acc= 0.81
#
# lower=True	punct=False	url=True	mention=True
# 5761 unique terms in vocabulary
# acc= 0.808
#
# lower=True	punct=False	url=True	mention=False
# 6767 unique terms in vocabulary
# acc= 0.8095
#
# lower=True	punct=False	url=False	mention=True
# 6401 unique terms in vocabulary
# acc= 0.8045
#
# lower=True	punct=False	url=False	mention=False
# 7407 unique terms in vocabulary
# acc= 0.811
#
# lower=False	punct=True	url=True	mention=True
# 8638 unique terms in vocabulary
# acc= 0.8035
#
# lower=False	punct=True	url=True	mention=False
# 9701 unique terms in vocabulary
# acc= 0.8075
#
# lower=False	punct=True	url=False	mention=True
# 9297 unique terms in vocabulary
# acc= 0.804
#
# lower=False	punct=True	url=False	mention=False
# 10360 unique terms in vocabulary
# acc= 0.8035
#
# lower=False	punct=False	url=True	mention=True
# 6833 unique terms in vocabulary
# acc= 0.802
#
# lower=False	punct=False	url=True	mention=False
# 7859 unique terms in vocabulary
# acc= 0.804
#
# lower=False	punct=False	url=False	mention=True
# 7474 unique terms in vocabulary
# acc= 0.7995
#
# lower=False	punct=False	url=False	mention=False
# 8500 unique terms in vocabulary
# acc= 0.806
