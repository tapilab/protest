# %%
import io 
from TwitterAPI import TwitterAPI
from TwitterAPI import TwitterRequestError
from TwitterAPI import TwitterConnectionError
import json

"""api = TwitterAPI("IwwzYhMQOY42t6pseaNKeTuMm", 
"qbmPysSls2lQ5ikuB3ruPKai9wSPacIjd8iVCsf95nQTchdwRd", 
"2775525967-hlnZ74NVMwDOoh1ceYvsJKVWPxPNLpx7c7Np8gp", 
"fHu3p5psMq5hLJRmhUkaMP1ngjiJZNPsgKNp3MpuFJw9S")"""

api = TwitterAPI("420P5d0Q1ptYHhugHAJmY9XHO",
"FoW4I0LEguVa8KkxGizf94UBDis5cfxG0kERtd823t8EwdEJZV",
"2775525967-jpumdnG9FaLpEbmJWfWvWlqItsrNr07ILJebhx3",
"YMMKnvJOS1JByaA0JMPnHnfpGvkopcbE4wXUU6YqoYhgi")

def get_timeline(screen_name, limit=16):
    
    max_id = None
    lim = 0
    user = 'C:/Users/Elaine/Desktop/TCC/Before election/foraDilma/'+screen_name + ".txt"
    file = io.open(user, mode='w+', encoding='utf-8')
    while (lim<limit):
            
            try:
                if max_id:
                    response = api.request('statuses/user_timeline', {'screen_name': screen_name, 'count': 200, 'max_id': max_id})
                else:
                    response = api.request('statuses/user_timeline', {'screen_name': screen_name, 'count': 200})
                if response.status_code == 200:
                    items = [t for t in response]
                #response.content.partition('(')[-1].rpartition(')')[0]
                 
                    if len(items) == 0:
                        return
                    else:
                        for item in items:
                            file.write(json.dumps(item, ensure_ascii=False, encoding='utf-8') + u"\n")
                            
                                         
                    max_id = min(t['id'] for t in response) - 1
                    lim += 1
                elif response.status_code == 429:
                    print "something wrong, sleeping"
                    time.sleep(300)
                    print "sleep time is over"
                elif response.status_code == 401 or response.status_code == 404 or response.status_code == 34:
                    print "unauthorized"
                    return
               
                 
            except TwitterRequestError as e:
                print str(e) 
            except TwitterConnectionError as er:
                print str(er)

# %% [markdown]
# Here we get the name of each user who mentioned "vem pra rua" (come to the street) and collect his/her timeline
#  - "Vem pra rua" is an expression meaning come to the street, which protestants used in the day of the main protest (August 16th)

# %%
DIR = 'D:/TCC/Data/Before election/'
data = []
count=0
count2=0
user = []

import glob, os
import time

os.chdir(DIR)

#for file in glob.glob("*.txt"):
    #print 'file ', file, '\n'
with io.open(DIR+'2014_data.txt','r',encoding="utf-8") as f:
    for line in f:
        try:
            tweet= json.loads(line)
        except ValueError:
            print "{} failed the JSON load".format(line)
            #return False
            
        if 'foraDILMA' in tweet['text'] or 'foradilma' in tweet['text'] or 'Fora Dilma' in tweet['text'] or 'foraDilma' in tweet['text'] or 'FORADILMA' in tweet['text'] or 'fora Dilma' in tweet['text'] or 'FORA DILMA' in tweet['text'] or 'ForaDilma' in tweet['text']:
            count2 +=1 #total number of tweets mentioning "vem pra rua"
            if tweet['user']['screen_name'] not in set(user):#and  tweet['user']['screen_name']!="Chacoalhada":
                user.append(tweet['user']['screen_name'])
                get_timeline(tweet['user']['screen_name'])
        count+=1 #total number of tweets
print count
# Out:
# unauthorized
# unauthorized
# something wrong, sleeping
# sleep time is over
# something wrong, sleeping
# sleep time is over
# unauthorized
# unauthorized
# something wrong, sleeping
# sleep time is over
# something wrong, sleeping
# sleep time is over
# something wrong, sleeping
# sleep time is over
# something wrong, sleeping
# sleep time is over
# unauthorized
# unauthorized
# unauthorized
# unauthorized
# something wrong, sleeping
# sleep time is over
# something wrong, sleeping
# sleep time is over
# unauthorized
# unauthorized
# unauthorized
# something wrong, sleeping
# sleep time is over
# something wrong, sleeping
# sleep time is over
# unauthorized
# something wrong, sleeping
# sleep time is over
# something wrong, sleeping
# sleep time is over
# unauthorized
# something wrong, sleeping
# sleep time is over
# something wrong, sleeping
# sleep time is over
# unauthorized
# unauthorized
# something wrong, sleeping
# sleep time is over
# something wrong, sleeping
# ...

# %%
DIR = 'D:/TCC/Data/Before election/'

original_file= open(DIR+'test1.txt','r')# r when we only wanna read file
revised_file = open(DIR+'test21.txt','w')# w when u wanna write sth on the file

for line in original_file:
    line = line.replace("\n", "")
    if line != '\n':
        revised_file.write(line)#for writing your new data

original_file.close()
revised_file.close()

# %%
DIR = 'D:/TCC/Data/Before election/'
data = []
count=0
count2=0
user = []
import glob, os
import time

os.chdir(DIR)

#for file in glob.glob("*.json"):
#    print 'file ', file, '\n'
with io.open(DIR+'2014_data.txt','r',encoding="utf-8") as f:
    for line in f:
            try:
                tweet= json.loads(line)
            except ValueError:
                print "{} failed the JSON load".format(line)
                #return False
            
            if 'foraPT' in tweet['text'] or 'FORAPT' in tweet['text'] or 'fora pt' in tweet['text']or 'FORA PT' in tweet['text'] or 'ForaPT' in tweet['text']:
                count2 +=1 #total number of tweets mentioning "vem pra rua"
                if tweet['user']['screen_name'] not in set(user):#and  tweet['user']['screen_name']!="Chacoalhada":
                    user.append(tweet['user']['screen_name'])
                    get_timeline(tweet['user']['screen_name'])
            count+=1 #total number of tweets
    print count
# Out:
# Erivelto_AP @AecioNeves engraçado... tudo o que vc pretende fazer a #Dilma13 já faz!!!
# missIraneide @ferrisss @iralidia @MiriamLeitaoCom @realwbonner @AecioNeves @iralidia Infelizmente a rede globo está de compassa com Dilma e Lula!!!
# GabyCDantas #ForaDilma A mudança é @AecioNeves  45 para um Brasil melhor http://t.co/Tc11k1ymdn
# letrin45 RT @YeaahRighttt: Conheça o plano de governo COMPLETO de @AecioNeves  Coisa que Dilma NEM SEQUER TEM 👉 http://t.co/1Oz7U7ZMod #AecioPeloBR4…
# FabinhoBN @AecioNeves Pessoal, imagino as bombas que a Didilma vai soltar na última hora. Mas força, que o povo quer troca no poder. #EuVotoAecio45
# GraziVadilletti RT @everaldoacoelho: #AecioPeloBR45IL @AecioNeves é necessário pra fazer aquilo que a Dilma não pode: mudar o Brasil. A continuidade destes…
# paulomarquest domingo dia 26 meu voto vai ser para presidente do Brasil @dilmabr  @aecioneves  em quando isso @podever @pptms
# ...
